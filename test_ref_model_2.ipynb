# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,UpSampling2D,Flatten,Dropout,Dense,BatchNormalization,Reshape,UpSampling2D

# %%
import os

x_train=[]
y_train=[]
x_test=[]
y_test=[]

path_train_low='../dataSets/ref/our485/low/'
path_train_high='../dataSets/ref/our485/high/'
path_test_low='../dataSets/ref/eval15/low/'
path_test_high='../dataSets/ref/eval15/high/'

print('\nLoding Train dataset :')
i=0;
for img in os.listdir(path_train_low):
    img_low_path=os.path.join(path_train_low, img)
    img_high_path=os.path.join(path_train_high, img)
    
    img_low=load_img(img_low_path, target_size=(40, 40))
    img_low=img_to_array(img_low)/255.
    
    i=i+1
    print("{:.2f}".format(i/4.85)+' %',end='\r')
    
    img_high=load_img(img_high_path, target_size=(40, 40))
    img_high=img_to_array(img_high)/255.
    
    x_train.append(img_low)
    y_train.append(img_high)
    
print('\nLoding Test dataset :')
i=0;
for img in os.listdir(path_test_low):
    img_low_path=os.path.join(path_test_low, img)
    img_high_path=os.path.join(path_test_high, img)
    
    img_low=load_img(img_low_path, target_size=(40, 40))
    img_low=img_to_array(img_low)/255.
    
    i=i+1
    print("{:.2f}".format(i/0.15)+' %',end='\r')
    
    img_high=load_img(img_high_path, target_size=(40, 40))
    img_high=img_to_array(img_high)/255.
    
    x_test.append(img_low)
    y_test.append(img_high)

x_train=np.array(x_train, dtype="float32")
y_train=np.array(y_train, dtype="float32")

x_test=np.array(x_test, dtype="float32")
y_test=np.array(y_test, dtype="float32")
# Out:
# Loding Train dataset :
# 100.00 %
# Loding Test dataset :
# 100.00 %

# %%
model=Sequential()

model.add(UpSampling2D((2,2),input_shape=(40,40,3)))
model.add(Conv2D(64,(2,2),padding='same',activation='relu'))
model.add(Conv2D(32,(1,1),padding='same',activation='elu'))
model.add(MaxPooling2D((2,2)))
model.add(Flatten())
model.add(Dense(3*40*40,activation='elu'))
model.add(Dense(3*40*40,activation='sigmoid'))
model.add(Reshape((40,40,3)))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# up_sampling2d (UpSampling2D) (None, 80, 80, 3)         0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 80, 80, 64)        832
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 80, 80, 32)        2080
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 40, 40, 32)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 51200)             0
# _________________________________________________________________
# dense (Dense)                (None, 4800)              245764800
# _________________________________________________________________
# dense_1 (Dense)              (None, 4800)              23044800
# _________________________________________________________________
# reshape (Reshape)            (None, 40, 40, 3)         0
# =================================================================
# Total params: 268,812,512
# Trainable params: 268,812,512
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

checkpoint=ModelCheckpoint('models/ref/ref_cnn2.h5',
                            monitor='val_loss',
                            mode='min',
                            save_best_only=True,
                            verbose=1
                          )
earlystop=EarlyStopping(monitor='val_loss',
                        patience=10,
                        min_delta=0,
                        restore_best_weights=True,
                        verbose=1
                       )
reduce_lr=ReduceLROnPlateau(monitor='val_loss',
                            factor=0.2,
                            patience=10,
                            min_delta=0.0001,
                            verbose=1
                           )
callbacks=[checkpoint,earlystop,reduce_lr]

model.compile(loss=keras.losses.MeanSquaredError(),
              optimizer='adam',
              metrics=['accuracy']
             )

history=model.fit(
    x=x_train,
    y=y_train,
    batch_size=32,
    shuffle=True,
    epochs=200,
    validation_data=(x_test, y_test),
    callbacks=callbacks
    )
# Out:
# Epoch 1/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0482 - accuracy: 0.4239
# Epoch 00001: val_loss improved from inf to 0.05236, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 74s 5s/step - loss: 0.0482 - accuracy: 0.4239 - val_loss: 0.0524 - val_accuracy: 0.4465
# Epoch 2/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0391 - accuracy: 0.4695
# Epoch 00002: val_loss improved from 0.05236 to 0.04343, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 126s 8s/step - loss: 0.0391 - accuracy: 0.4695 - val_loss: 0.0434 - val_accuracy: 0.4455
# Epoch 3/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0344 - accuracy: 0.4882
# Epoch 00003: val_loss improved from 0.04343 to 0.03792, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 121s 8s/step - loss: 0.0344 - accuracy: 0.4882 - val_loss: 0.0379 - val_accuracy: 0.5197
# Epoch 4/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0295 - accuracy: 0.5462
# Epoch 00004: val_loss improved from 0.03792 to 0.03284, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 125s 8s/step - loss: 0.0295 - accuracy: 0.5462 - val_loss: 0.0328 - val_accuracy: 0.4851
# Epoch 5/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0248 - accuracy: 0.5415
# Epoch 00005: val_loss improved from 0.03284 to 0.02976, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 155s 10s/step - loss: 0.0248 - accuracy: 0.5415 - val_loss: 0.0298 - val_accuracy: 0.5212
# Epoch 6/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0218 - accuracy: 0.5814
# Epoch 00006: val_loss improved from 0.02976 to 0.02787, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 152s 9s/step - loss: 0.0218 - accuracy: 0.5814 - val_loss: 0.0279 - val_accuracy: 0.5990
# Epoch 7/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0191 - accuracy: 0.5954
# Epoch 00007: val_loss improved from 0.02787 to 0.02773, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 96s 6s/step - loss: 0.0191 - accuracy: 0.5954 - val_loss: 0.0277 - val_accuracy: 0.6275
# Epoch 8/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0182 - accuracy: 0.6109
# Epoch 00008: val_loss improved from 0.02773 to 0.02650, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 141s 9s/step - loss: 0.0182 - accuracy: 0.6109 - val_loss: 0.0265 - val_accuracy: 0.6075
# Epoch 9/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0170 - accuracy: 0.6264
# Epoch 00009: val_loss improved from 0.02650 to 0.02336, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 134s 8s/step - loss: 0.0170 - accuracy: 0.6264 - val_loss: 0.0234 - val_accuracy: 0.6118
# Epoch 10/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0150 - accuracy: 0.6414
# Epoch 00010: val_loss improved from 0.02336 to 0.02177, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 125s 8s/step - loss: 0.0150 - accuracy: 0.6414 - val_loss: 0.0218 - val_accuracy: 0.6260
# Epoch 11/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0130 - accuracy: 0.6486
# Epoch 00011: val_loss did not improve from 0.02177
# 16/16 [==============================] - 75s 5s/step - loss: 0.0130 - accuracy: 0.6486 - val_loss: 0.0235 - val_accuracy: 0.6635
# Epoch 12/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0109 - accuracy: 0.6615
# Epoch 00012: val_loss improved from 0.02177 to 0.01999, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 73s 5s/step - loss: 0.0109 - accuracy: 0.6615 - val_loss: 0.0200 - val_accuracy: 0.6660
# Epoch 13/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 0.6803
# Epoch 00013: val_loss improved from 0.01999 to 0.01919, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 117s 7s/step - loss: 0.0092 - accuracy: 0.6803 - val_loss: 0.0192 - val_accuracy: 0.6596
# Epoch 14/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0083 - accuracy: 0.6944
# Epoch 00014: val_loss improved from 0.01919 to 0.01749, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 111s 7s/step - loss: 0.0083 - accuracy: 0.6944 - val_loss: 0.0175 - val_accuracy: 0.6268
# Epoch 15/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0074 - accuracy: 0.6946
# Epoch 00015: val_loss improved from 0.01749 to 0.01651, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 118s 7s/step - loss: 0.0074 - accuracy: 0.6946 - val_loss: 0.0165 - val_accuracy: 0.6927
# Epoch 16/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0065 - accuracy: 0.7145
# Epoch 00016: val_loss improved from 0.01651 to 0.01619, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 126s 8s/step - loss: 0.0065 - accuracy: 0.7145 - val_loss: 0.0162 - val_accuracy: 0.7028
# Epoch 17/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0055 - accuracy: 0.7266
# Epoch 00017: val_loss improved from 0.01619 to 0.01504, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 144s 9s/step - loss: 0.0055 - accuracy: 0.7266 - val_loss: 0.0150 - val_accuracy: 0.6905
# Epoch 18/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0052 - accuracy: 0.7251
# Epoch 00018: val_loss improved from 0.01504 to 0.01473, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 103s 6s/step - loss: 0.0052 - accuracy: 0.7251 - val_loss: 0.0147 - val_accuracy: 0.7195
# Epoch 19/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0048 - accuracy: 0.7421
# Epoch 00019: val_loss did not improve from 0.01473
# 16/16 [==============================] - 57s 4s/step - loss: 0.0048 - accuracy: 0.7421 - val_loss: 0.0160 - val_accuracy: 0.7344
# Epoch 20/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0046 - accuracy: 0.7423
# Epoch 00020: val_loss did not improve from 0.01473
# 16/16 [==============================] - 43s 3s/step - loss: 0.0046 - accuracy: 0.7423 - val_loss: 0.0156 - val_accuracy: 0.7435
# Epoch 21/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0043 - accuracy: 0.7621
# Epoch 00021: val_loss improved from 0.01473 to 0.01344, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 91s 6s/step - loss: 0.0043 - accuracy: 0.7621 - val_loss: 0.0134 - val_accuracy: 0.7339
# Epoch 22/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0038 - accuracy: 0.7717
# Epoch 00022: val_loss improved from 0.01344 to 0.01307, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 153s 10s/step - loss: 0.0038 - accuracy: 0.7717 - val_loss: 0.0131 - val_accuracy: 0.7507
# Epoch 23/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.7817
# Epoch 00023: val_loss improved from 0.01307 to 0.01159, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 113s 7s/step - loss: 0.0032 - accuracy: 0.7817 - val_loss: 0.0116 - val_accuracy: 0.7500
# Epoch 24/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0029 - accuracy: 0.7854
# Epoch 00024: val_loss improved from 0.01159 to 0.01135, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 112s 7s/step - loss: 0.0029 - accuracy: 0.7854 - val_loss: 0.0113 - val_accuracy: 0.7450
# Epoch 25/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0027 - accuracy: 0.7888
# Epoch 00025: val_loss did not improve from 0.01135
# 16/16 [==============================] - 71s 4s/step - loss: 0.0027 - accuracy: 0.7888 - val_loss: 0.0116 - val_accuracy: 0.7842
# Epoch 26/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0025 - accuracy: 0.8064
# Epoch 00026: val_loss improved from 0.01135 to 0.01107, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 100s 6s/step - loss: 0.0025 - accuracy: 0.8064 - val_loss: 0.0111 - val_accuracy: 0.7779
# Epoch 27/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0032 - accuracy: 0.8041
# Epoch 00027: val_loss did not improve from 0.01107
# 16/16 [==============================] - 55s 3s/step - loss: 0.0032 - accuracy: 0.8041 - val_loss: 0.0131 - val_accuracy: 0.7808
# Epoch 28/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0028 - accuracy: 0.8066
# Epoch 00028: val_loss did not improve from 0.01107
# 16/16 [==============================] - 40s 3s/step - loss: 0.0028 - accuracy: 0.8066 - val_loss: 0.0126 - val_accuracy: 0.7850
# Epoch 29/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 0.8141
# Epoch 00029: val_loss improved from 0.01107 to 0.00954, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 77s 5s/step - loss: 0.0024 - accuracy: 0.8141 - val_loss: 0.0095 - val_accuracy: 0.7980
# Epoch 30/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0023 - accuracy: 0.8194
# Epoch 00030: val_loss did not improve from 0.00954
# 16/16 [==============================] - 45s 3s/step - loss: 0.0023 - accuracy: 0.8194 - val_loss: 0.0112 - val_accuracy: 0.8063
# Epoch 31/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0019 - accuracy: 0.8265
# Epoch 00031: val_loss did not improve from 0.00954
# 16/16 [==============================] - 35s 2s/step - loss: 0.0019 - accuracy: 0.8265 - val_loss: 0.0108 - val_accuracy: 0.8037
# Epoch 32/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0018 - accuracy: 0.8330
# Epoch 00032: val_loss did not improve from 0.00954
# 16/16 [==============================] - 31s 2s/step - loss: 0.0018 - accuracy: 0.8330 - val_loss: 0.0109 - val_accuracy: 0.8097
# Epoch 33/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0015 - accuracy: 0.8449
# Epoch 00033: val_loss did not improve from 0.00954
# 16/16 [==============================] - 31s 2s/step - loss: 0.0015 - accuracy: 0.8449 - val_loss: 0.0103 - val_accuracy: 0.8213
# Epoch 34/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 0.8504
# Epoch 00034: val_loss did not improve from 0.00954
# 16/16 [==============================] - 31s 2s/step - loss: 0.0013 - accuracy: 0.8504 - val_loss: 0.0097 - val_accuracy: 0.8080
# Epoch 35/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0014 - accuracy: 0.8577
# Epoch 00035: val_loss did not improve from 0.00954
# 16/16 [==============================] - 31s 2s/step - loss: 0.0014 - accuracy: 0.8577 - val_loss: 0.0102 - val_accuracy: 0.8256
# Epoch 36/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0012 - accuracy: 0.8554
# Epoch 00036: val_loss improved from 0.00954 to 0.00904, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 94s 6s/step - loss: 0.0012 - accuracy: 0.8554 - val_loss: 0.0090 - val_accuracy: 0.8135
# Epoch 37/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.8615
# Epoch 00037: val_loss did not improve from 0.00904
# 16/16 [==============================] - 40s 2s/step - loss: 0.0011 - accuracy: 0.8615 - val_loss: 0.0092 - val_accuracy: 0.8313
# Epoch 38/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 0.8675
# Epoch 00038: val_loss did not improve from 0.00904
# 16/16 [==============================] - 44s 3s/step - loss: 0.0010 - accuracy: 0.8675 - val_loss: 0.0093 - val_accuracy: 0.8318
# Epoch 39/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0011 - accuracy: 0.8723
# Epoch 00039: val_loss did not improve from 0.00904
# 16/16 [==============================] - 31s 2s/step - loss: 0.0011 - accuracy: 0.8723 - val_loss: 0.0095 - val_accuracy: 0.8249
# Epoch 40/200
# 16/16 [==============================] - ETA: 0s - loss: 0.0010 - accuracy: 0.8725
# Epoch 00040: val_loss did not improve from 0.00904
# 16/16 [==============================] - 31s 2s/step - loss: 0.0010 - accuracy: 0.8725 - val_loss: 0.0092 - val_accuracy: 0.8391
# Epoch 41/200
# 16/16 [==============================] - ETA: 0s - loss: 9.8765e-04 - accuracy: 0.8749
# Epoch 00041: val_loss improved from 0.00904 to 0.00870, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 80s 5s/step - loss: 9.8765e-04 - accuracy: 0.8749 - val_loss: 0.0087 - val_accuracy: 0.8211
# Epoch 42/200
# 16/16 [==============================] - ETA: 0s - loss: 9.9660e-04 - accuracy: 0.8757
# Epoch 00042: val_loss improved from 0.00870 to 0.00862, saving model to models/ref\ref_cnn2.h5
# 16/16 [==============================] - 104s 6s/step - loss: 9.9660e-04 - accuracy: 0.8757 - val_loss: 0.0086 - val_accuracy: 0.8395
# Epoch 43/200
# 16/16 [==============================] - ETA: 0s - loss: 9.8996e-04 - accuracy: 0.8754
# Epoch 00043: val_loss did not improve from 0.00862
# 16/16 [==============================] - 58s 4s/step - loss: 9.8996e-04 - accuracy: 0.8754 - val_loss: 0.0100 - val_accuracy: 0.8266
# Epoch 44/200
# 16/16 [==============================] - ETA: 0s - loss: 8.2158e-04 - accuracy: 0.8786
# Epoch 00044: val_loss did not improve from 0.00862
# 16/16 [==============================] - 33s 2s/step - loss: 8.2158e-04 - accuracy: 0.8786 - val_loss: 0.0097 - val_accuracy: 0.8317
# Epoch 45/200
# 16/16 [==============================] - ETA: 0s - loss: 8.5584e-04 - accuracy: 0.8796
# Epoch 00045: val_loss did not improve from 0.00862
# 16/16 [==============================] - 31s 2s/step - loss: 8.5584e-04 - accuracy: 0.8796 - val_loss: 0.0089 - val_accuracy: 0.8460
# Epoch 46/200
# 16/16 [==============================] - ETA: 0s - loss: 8.3932e-04 - accuracy: 0.8850
# Epoch 00046: val_loss did not improve from 0.00862
# 16/16 [==============================] - 31s 2s/step - loss: 8.3932e-04 - accuracy: 0.8850 - val_loss: 0.0090 - val_accuracy: 0.8338
# Epoch 47/200
# 16/16 [==============================] - ETA: 0s - loss: 6.7905e-04 - accuracy: 0.8916
# Epoch 00047: val_loss did not improve from 0.00862
# 16/16 [==============================] - 31s 2s/step - loss: 6.7905e-04 - accuracy: 0.8916 - val_loss: 0.0094 - val_accuracy: 0.8409
# Epoch 48/200
# 16/16 [==============================] - ETA: 0s - loss: 6.3929e-04 - accuracy: 0.8964
# Epoch 00048: val_loss did not improve from 0.00862
# 16/16 [==============================] - 31s 2s/step - loss: 6.3929e-04 - accuracy: 0.8964 - val_loss: 0.0090 - val_accuracy: 0.8435
# Epoch 49/200
# 16/16 [==============================] - ETA: 0s - loss: 7.0728e-04 - accuracy: 0.8924
# Epoch 00049: val_loss did not improve from 0.00862
# 16/16 [==============================] - 31s 2s/step - loss: 7.0728e-04 - accuracy: 0.8924 - val_loss: 0.0090 - val_accuracy: 0.8530
# Epoch 50/200
# 16/16 [==============================] - ETA: 0s - loss: 6.6315e-04 - accuracy: 0.8956
# Epoch 00050: val_loss did not improve from 0.00862
# 16/16 [==============================] - 31s 2s/step - loss: 6.6315e-04 - accuracy: 0.8956 - val_loss: 0.0090 - val_accuracy: 0.8473
# Epoch 51/200
# 16/16 [==============================] - ETA: 0s - loss: 6.2841e-04 - accuracy: 0.9000
# Epoch 00051: val_loss did not improve from 0.00862
#
# Epoch 00051: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 16/16 [==============================] - 31s 2s/step - loss: 6.2841e-04 - accuracy: 0.9000 - val_loss: 0.0092 - val_accuracy: 0.8498
# Epoch 52/200
# 16/16 [==============================] - ETA: 0s - loss: 4.9519e-04 - accuracy: 0.9115
# Epoch 00052: val_loss did not improve from 0.00862
# Restoring model weights from the end of the best epoch.
# 16/16 [==============================] - 30s 2s/step - loss: 4.9519e-04 - accuracy: 0.9115 - val_loss: 0.0089 - val_accuracy: 0.8485
# Epoch 00052: early stopping

# %%
plt.grid()

plt.plot(history.history['loss'],'--^r',label="loss")
plt.plot(history.history['accuracy'],'--^g',label='accuracy')
plt.plot(history.history['val_loss'],'-or',label='val_loss')
plt.plot(history.history['val_accuracy'],'-og',label='val_accuracy')
plt.legend()

# %%
fig=plt.figure()

def check_result(n):
    fig.add_subplot(1,2,1).imshow(y_test[n])
    fig.add_subplot(1,2,2).imshow(model.predict(x_test)[n])

check_result(5)
