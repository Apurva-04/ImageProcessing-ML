# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import tensorflow as tf
import keras
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array

# %%
h, w = 160, 160

x_train=[]
y_train=[]
x_test=[]
y_test=[]

path_train_low='../dataSets/ref/our485/low/'
path_train_high='../dataSets/ref/our485/high/'
path_test_low='../dataSets/ref/eval15/low/'
path_test_high='../dataSets/ref/eval15/high/'

print('\nLoding Train dataset :')
i=0;
for img in os.listdir(path_train_low):
    img_low_path=os.path.join(path_train_low, img)
    img_high_path=os.path.join(path_train_high, img)
    
    img_low=load_img(img_low_path, target_size=(h,w))
    img_low=img_to_array(img_low)/255.
        
    img_low_hsv=cv2.cvtColor(np.array(img_low,dtype=np.uint8),cv2.COLOR_RGB2HSV)
    img_low=np.concatenate([img_low,img_low_hsv[:,:,2:]],axis=-1)
    
    i=i+1
    print("{:.2f}".format(i/4.89)+' %',end='\r')
    
    img_high=load_img(img_high_path, target_size=(h,w))
    img_high=img_to_array(img_high)/255.
    
    x_train.append(img_low)
    y_train.append(img_high)
    
print('\nLoding Test dataset :')
i=0;
for img in os.listdir(path_test_low):
    img_low_path=os.path.join(path_test_low, img)
    img_high_path=os.path.join(path_test_high, img)
    
    img_low=load_img(img_low_path, target_size=(h,w))
    img_low=img_to_array(img_low)/255.
    
    img_low_hsv=cv2.cvtColor(np.array(img_low,dtype=np.uint8),cv2.COLOR_RGB2HSV)
    img_low=np.concatenate([img_low,img_low_hsv[:,:,2:]],axis=-1)
    
    i=i+1
    print("{:.2f}".format(i/0.14)+' %',end='\r')
    
    img_high=load_img(img_high_path, target_size=(h,w))
    img_high=img_to_array(img_high)/255.
    
    x_test.append(img_low)
    y_test.append(img_high)

x_train=np.array(x_train, dtype="float32")
y_train=np.array(y_train, dtype="float32")

x_test=np.array(x_test, dtype="float32")
y_test=np.array(y_test, dtype="float32")
# Out:
# Loding Train dataset :
# 100.00 %
# Loding Test dataset :
# 100.00 %

# %%
fig=plt.figure()

f=fig.add_subplot(1,2,1)
s=fig.add_subplot(1,2,2)

f.imshow(x_test[6][:,:,:3])
s.imshow(y_test[6])

# %%
from keras.models import Model
from keras.models import Sequential
from keras.layers import Input,add,Conv2D,MaxPooling2D,UpSampling2D,Flatten,Dropout,Dense,BatchNormalization,Reshape,UpSampling2D,Conv2DTranspose,Concatenate,Lambda

def getRGB(x):
    return x[:,:,:,:3]
def getValue(x):
    return x[:,:,:,3:]

def InstantiateModel(in_):
    channel = 32
    kernal_size = (3,3)
    in_0 = Lambda(getRGB)(in_)
    in_1 = Lambda(getValue)(in_)
    
    #denoise
    conv0 = Conv2D(channel, kernal_size, strides=1, padding='same', activation=None)(in_0)#(in_)
    
    conv1 = Conv2D(channel, kernal_size, strides=2, padding='same', activation='relu')(conv0)
    conv2 = Conv2D(channel, kernal_size, strides=2, padding='same', activation='relu')(conv1)
    conv3 = Conv2D(channel, kernal_size, strides=2, padding='same', activation='relu')(conv2)
    
    up3 = UpSampling2D((2,2))(conv3)
    deconv3 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(up3)+conv2
    up2 = UpSampling2D((2,2))(deconv3)
    deconv2 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(up2)+conv1
    up1 = UpSampling2D((2,2))(deconv2)
    deconv1 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(up1)+conv0
    
    
    deconv2_resize = UpSampling2D((2,2))(deconv2)
    feature_gather = Concatenate()([deconv2_resize, deconv1])
    model_1 = Conv2D(3, (1,1), padding='same', activation=None)(feature_gather)
    
    #adjustment
    model_2 = Conv2D(channel, kernal_size, activation='relu', padding='same', strides=1)(in_1)
    model_2 = Conv2D(channel, kernal_size, activation='relu', padding='same', strides=1)(model_2)
    model_2 = Conv2D(channel, kernal_size, activation='relu', padding='same', strides=1)(model_2)
    model_2 = Conv2D(1, (1,1), padding='same', activation=None)(model_2)
    
    model_add = Concatenate()([model_2,model_1])
    
    #restoration
    model_3 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(model_add)
    model_3 = Conv2D(channel, kernal_size, activation='relu', padding='same', strides=1)(model_3)
#     model_3 = Conv2D(3,(1,1), activation='sigmoid',padding='same',strides=1)(model_3)
    
#     #adjustment-pro
#     model_4 = Conv2D(32, (2,2), strides=1, padding='same', activation='relu')(model_2)
#     model_4 = Conv2D(32, (2,2), activation='relu', padding='same', strides=1)(model_4)
#     model_4 = Conv2D(1,(1,1), activation=None,padding='same',strides=1)(model_4)
    
#     feature_gather_1 = Concatenate()([model_3, model_4])
#     feature_fusion = Conv2D(64, (1,1), activation='relu', padding='same', strides=1)(feature_gather_1)
    
    out = Conv2D(3, (1,1), activation='sigmoid', padding='same', strides=1)(model_3)#(feature_fusion)
    
    return out

# %%
Input_Sample = Input(shape=(h, w, 4))
Output_ = InstantiateModel(Input_Sample)
model = Model(inputs=Input_Sample, outputs=Output_)
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 160, 160, 4) 0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 160, 160, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 160, 160, 32) 896         lambda[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 80, 80, 32)   9248        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 40, 40, 32)   9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 20, 20, 32)   9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 40, 40, 32)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 40, 40, 32)   9248        up_sampling2d[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp [(None, 40, 40, 32)] 0           conv2d_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 80, 80, 32)   0           tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 80, 80, 32)   9248        up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_1 (TensorFlow [(None, 80, 80, 32)] 0           conv2d_5[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 160, 160, 1)  0           input_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 160, 160, 32) 0           tf_op_layer_AddV2_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 160, 160, 32) 320         lambda_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 160, 160, 32) 9248        up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 160, 160, 32) 9248        conv2d_8[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 160, 160, 32) 0           tf_op_layer_AddV2_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_2 (TensorFlow [(None, 160, 160, 32 0           conv2d_6[0][0]
#                                                                  conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 160, 160, 32) 9248        conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 160, 160, 64) 0           up_sampling2d_3[0][0]
#                                                                  tf_op_layer_AddV2_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 160, 160, 1)  33          conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 160, 160, 3)  195         concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 160, 160, 4)  0           conv2d_11[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 160, 160, 32) 1184        concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 160, 160, 32) 9248        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 160, 160, 3)  99          conv2d_13[0][0]
# ==================================================================================================
# Total params: 85,959
# Trainable params: 85,959
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model,to_file='model.png',show_shapes=True, show_layer_names=True)

# %%
def _tf_fspecial_gauss(size, sigma):
    """Function to mimic the 'fspecial' gaussian MATLAB function
    """
    x_data, y_data = np.mgrid[-size//2 + 1:size//2 + 1, -size//2 + 1:size//2 + 1]

    x_data = np.expand_dims(x_data, axis=-1)
    x_data = np.expand_dims(x_data, axis=-1)

    y_data = np.expand_dims(y_data, axis=-1)
    y_data = np.expand_dims(y_data, axis=-1)

    x = tf.constant(x_data, dtype=tf.float32)
    y = tf.constant(y_data, dtype=tf.float32)

    g = tf.exp(-((x**2 + y**2)/(2.0*sigma**2)))
    return g / tf.reduce_sum(g)

def tf_ssim(img1, img2, cs_map=False, mean_metric=True, size=11, sigma=1.5):
    window = _tf_fspecial_gauss(size, sigma) # window shape [size, size]
    K1 = 0.01
    K2 = 0.03
    L = 1  # depth of image (255 in case the image has a differnt scale)
    C1 = (K1*L)**2
    C2 = (K2*L)**2
    mu1 = tf.nn.conv2d(img1, window, strides=[1,1,1,1], padding='VALID')
    mu2 = tf.nn.conv2d(img2, window, strides=[1,1,1,1],padding='VALID')
    mu1_sq = mu1*mu1
    mu2_sq = mu2*mu2
    mu1_mu2 = mu1*mu2
    sigma1_sq = tf.nn.conv2d(img1*img1, window, strides=[1,1,1,1],padding='VALID') - mu1_sq
    sigma2_sq = tf.nn.conv2d(img2*img2, window, strides=[1,1,1,1],padding='VALID') - mu2_sq
    sigma12 = tf.nn.conv2d(img1*img2, window, strides=[1,1,1,1],padding='VALID') - mu1_mu2
    if cs_map:
        value = (((2*mu1_mu2 + C1)*(2*sigma12 + C2))/((mu1_sq + mu2_sq + C1)*
                            (sigma1_sq + sigma2_sq + C2)),
                        (2.0*sigma12 + C2)/(sigma1_sq + sigma2_sq + C2))
    else:
        value = ((2*mu1_mu2 + C1)*(2*sigma12 + C2))/((mu1_sq + mu2_sq + C1)*
                            (sigma1_sq + sigma2_sq + C2))

    if mean_metric:
        value = tf.reduce_mean(value)
    return value

def my_loss(y_true, y_pred):
    MAE_loss = K.mean(K.abs(y_pred - y_true))
    SSIM_loss = tf_ssim(tf.expand_dims(y_pred[:, :, :, 0], -1),tf.expand_dims(y_true[:, :, :, 0], -1)) + tf_ssim(
                tf.expand_dims(y_pred[:, :, :, 1], -1), tf.expand_dims(y_true[:, :, :, 1], -1)) + tf_ssim(
                tf.expand_dims(y_pred[:, :, :, 2], -1), tf.expand_dims(y_true[:, :, :, 2], -1))

    percent = 0.4
    index = int(h * w * percent - 1)
    gray1 = 0.39 * y_pred[:, :, :, 0] + 0.5 * y_pred[:, :, :, 1] + 0.11 * y_pred[:, :, :, 2]
    gray = tf.reshape(gray1, [-1, h * w])
    gray_sort = tf.nn.top_k(-gray, h * w)[0]
    yu = gray_sort[:, index]
    yu = tf.expand_dims(tf.expand_dims(yu, -1), -1)
    mask = tf.cast(gray1 <= yu,tf.float32)
    mask1 = tf.expand_dims(mask, -1)
    mask = tf.concat([mask1, mask1, mask1], -1)

    low_fake_clean = tf.multiply(mask, y_pred[:, :, :, :3])
    high_fake_clean = tf.multiply(1 - mask, y_pred[:, :, :, :3])
    low_clean = tf.multiply(mask, y_true[:, :, :, :])
    high_clean = tf.multiply(1 - mask, y_true[:, :, :, :])
    Region_loss = K.mean(K.abs(low_fake_clean - low_clean) * 4 + K.abs(high_fake_clean - high_clean))

    loss = MAE_loss + 3 - SSIM_loss + Region_loss
    
    return loss

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

checkpoint=ModelCheckpoint('models/ref/4C.h5',
                            monitor='val_loss',
                            mode='min',
                            save_best_only=True,
                            verbose=1
                          )
earlystop=EarlyStopping(monitor='val_loss',
                        patience=6,
                        min_delta=0,
                        restore_best_weights=True,
                        verbose=1
                       )
reduce_lr=ReduceLROnPlateau(monitor='val_loss',
                            factor=0.2,
                            patience=6,
                            min_delta=0.001,
                            verbose=1
                           )

callbacks=[checkpoint,earlystop,reduce_lr]

METRICS=[
    keras.metrics.MeanSquaredError(name='mse'),
    ssim,
    'accuracy'
]
model.compile(loss=my_loss,
              optimizer=keras.optimizers.Adam(learning_rate=0.001),
              metrics=METRICS
             )

history=model.fit(
    x=x_train,
    y=y_train,
    batch_size=16,
    shuffle=True,
    epochs=100,
    validation_data=(x_test, y_test),
    callbacks=callbacks
    )
# Out:
# Epoch 1/100
# 62/62 [==============================] - ETA: 0s - loss: 0.8289 - accuracy: 0.5290
# Epoch 00001: val_loss improved from inf to 0.62331, saving model to models/ref\4C.h5
# 62/62 [==============================] - 153s 2s/step - loss: 0.8289 - accuracy: 0.5290 - val_loss: 0.6233 - val_accuracy: 0.5424
# Epoch 2/100
# 62/62 [==============================] - ETA: 0s - loss: 0.4711 - accuracy: 0.5487
# Epoch 00002: val_loss improved from 0.62331 to 0.50726, saving model to models/ref\4C.h5
# 62/62 [==============================] - 146s 2s/step - loss: 0.4711 - accuracy: 0.5487 - val_loss: 0.5073 - val_accuracy: 0.4588
# Epoch 3/100
# 62/62 [==============================] - ETA: 0s - loss: 0.4030 - accuracy: 0.5428
# Epoch 00003: val_loss improved from 0.50726 to 0.41899, saving model to models/ref\4C.h5
# 62/62 [==============================] - 147s 2s/step - loss: 0.4030 - accuracy: 0.5428 - val_loss: 0.4190 - val_accuracy: 0.5471
# Epoch 4/100
# 62/62 [==============================] - ETA: 0s - loss: 0.3456 - accuracy: 0.5507
# Epoch 00004: val_loss improved from 0.41899 to 0.30898, saving model to models/ref\4C.h5
# 62/62 [==============================] - 145s 2s/step - loss: 0.3456 - accuracy: 0.5507 - val_loss: 0.3090 - val_accuracy: 0.5482
# Epoch 5/100
# 62/62 [==============================] - ETA: 0s - loss: 0.3140 - accuracy: 0.5531
# Epoch 00005: val_loss did not improve from 0.30898
# 62/62 [==============================] - 146s 2s/step - loss: 0.3140 - accuracy: 0.5531 - val_loss: 0.3449 - val_accuracy: 0.5505
# Epoch 6/100
# 62/62 [==============================] - ETA: 0s - loss: 0.2774 - accuracy: 0.6269
# Epoch 00006: val_loss improved from 0.30898 to 0.22521, saving model to models/ref\4C.h5
# 62/62 [==============================] - 146s 2s/step - loss: 0.2774 - accuracy: 0.6269 - val_loss: 0.2252 - val_accuracy: 0.6718
# Epoch 7/100
# 62/62 [==============================] - ETA: 0s - loss: 0.2605 - accuracy: 0.6638
# Epoch 00007: val_loss improved from 0.22521 to 0.19593, saving model to models/ref\4C.h5
# 62/62 [==============================] - 146s 2s/step - loss: 0.2605 - accuracy: 0.6638 - val_loss: 0.1959 - val_accuracy: 0.6824
# Epoch 8/100
# 62/62 [==============================] - ETA: 0s - loss: 0.2410 - accuracy: 0.6547
# Epoch 00008: val_loss improved from 0.19593 to 0.18223, saving model to models/ref\4C.h5
# 62/62 [==============================] - 149s 2s/step - loss: 0.2410 - accuracy: 0.6547 - val_loss: 0.1822 - val_accuracy: 0.7252
# Epoch 9/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1973 - accuracy: 0.6851
# Epoch 00009: val_loss improved from 0.18223 to 0.16184, saving model to models/ref\4C.h5
# 62/62 [==============================] - 147s 2s/step - loss: 0.1973 - accuracy: 0.6851 - val_loss: 0.1618 - val_accuracy: 0.7211
# Epoch 10/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1909 - accuracy: 0.6929
# Epoch 00010: val_loss improved from 0.16184 to 0.15586, saving model to models/ref\4C.h5
# 62/62 [==============================] - 146s 2s/step - loss: 0.1909 - accuracy: 0.6929 - val_loss: 0.1559 - val_accuracy: 0.7033
# Epoch 11/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1719 - accuracy: 0.6655
# Epoch 00011: val_loss did not improve from 0.15586
# 62/62 [==============================] - 146s 2s/step - loss: 0.1719 - accuracy: 0.6655 - val_loss: 0.1770 - val_accuracy: 0.5701
# Epoch 12/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1769 - accuracy: 0.6668
# Epoch 00012: val_loss did not improve from 0.15586
# 62/62 [==============================] - 124s 2s/step - loss: 0.1769 - accuracy: 0.6668 - val_loss: 0.1596 - val_accuracy: 0.7203
# Epoch 13/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1684 - accuracy: 0.6532
# Epoch 00013: val_loss did not improve from 0.15586
# 62/62 [==============================] - 124s 2s/step - loss: 0.1684 - accuracy: 0.6532 - val_loss: 0.1979 - val_accuracy: 0.6668
# Epoch 14/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1661 - accuracy: 0.6715
# Epoch 00014: val_loss did not improve from 0.15586
# 62/62 [==============================] - 124s 2s/step - loss: 0.1661 - accuracy: 0.6715 - val_loss: 0.1746 - val_accuracy: 0.6626
# Epoch 15/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1470 - accuracy: 0.6712
# Epoch 00015: val_loss improved from 0.15586 to 0.13697, saving model to models/ref\4C.h5
# 62/62 [==============================] - 124s 2s/step - loss: 0.1470 - accuracy: 0.6712 - val_loss: 0.1370 - val_accuracy: 0.7325
# Epoch 16/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1414 - accuracy: 0.6969
# Epoch 00016: val_loss did not improve from 0.13697
# 62/62 [==============================] - 123s 2s/step - loss: 0.1414 - accuracy: 0.6969 - val_loss: 0.1595 - val_accuracy: 0.6384
# Epoch 17/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1397 - accuracy: 0.6929
# Epoch 00017: val_loss did not improve from 0.13697
# 62/62 [==============================] - 124s 2s/step - loss: 0.1397 - accuracy: 0.6929 - val_loss: 0.1489 - val_accuracy: 0.6718
# Epoch 18/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1336 - accuracy: 0.6493
# Epoch 00018: val_loss improved from 0.13697 to 0.13611, saving model to models/ref\4C.h5
# 62/62 [==============================] - 128s 2s/step - loss: 0.1336 - accuracy: 0.6493 - val_loss: 0.1361 - val_accuracy: 0.5245
# Epoch 19/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1447 - accuracy: 0.6690
# Epoch 00019: val_loss did not improve from 0.13611
# 62/62 [==============================] - 126s 2s/step - loss: 0.1447 - accuracy: 0.6690 - val_loss: 0.1391 - val_accuracy: 0.7328
# Epoch 20/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1430 - accuracy: 0.6673
# Epoch 00020: val_loss improved from 0.13611 to 0.13417, saving model to models/ref\4C.h5
# 62/62 [==============================] - 125s 2s/step - loss: 0.1430 - accuracy: 0.6673 - val_loss: 0.1342 - val_accuracy: 0.5863
# Epoch 21/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1222 - accuracy: 0.6798
# Epoch 00021: val_loss improved from 0.13417 to 0.10852, saving model to models/ref\4C.h5
# 62/62 [==============================] - 124s 2s/step - loss: 0.1222 - accuracy: 0.6798 - val_loss: 0.1085 - val_accuracy: 0.7232
# Epoch 22/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1183 - accuracy: 0.6822
# Epoch 00022: val_loss did not improve from 0.10852
# 62/62 [==============================] - 125s 2s/step - loss: 0.1183 - accuracy: 0.6822 - val_loss: 0.1830 - val_accuracy: 0.7223
# Epoch 23/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1227 - accuracy: 0.6923
# Epoch 00023: val_loss did not improve from 0.10852
# 62/62 [==============================] - 124s 2s/step - loss: 0.1227 - accuracy: 0.6923 - val_loss: 0.1130 - val_accuracy: 0.7161
# Epoch 24/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1217 - accuracy: 0.6980
# Epoch 00024: val_loss did not improve from 0.10852
# 62/62 [==============================] - 124s 2s/step - loss: 0.1217 - accuracy: 0.6980 - val_loss: 0.1329 - val_accuracy: 0.7107
# Epoch 25/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1129 - accuracy: 0.6857
# Epoch 00025: val_loss did not improve from 0.10852
# 62/62 [==============================] - 124s 2s/step - loss: 0.1129 - accuracy: 0.6857 - val_loss: 0.1119 - val_accuracy: 0.7293
# Epoch 26/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1074 - accuracy: 0.6864
# Epoch 00026: val_loss did not improve from 0.10852
# 62/62 [==============================] - 124s 2s/step - loss: 0.1074 - accuracy: 0.6864 - val_loss: 0.1093 - val_accuracy: 0.6310
# Epoch 27/100
# 62/62 [==============================] - ETA: 0s - loss: 0.1053 - accuracy: 0.6875
# Epoch 00027: val_loss did not improve from 0.10852
# Restoring model weights from the end of the best epoch.
#
# Epoch 00027: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 62/62 [==============================] - 124s 2s/step - loss: 0.1053 - accuracy: 0.6875 - val_loss: 0.1564 - val_accuracy: 0.7051
# Epoch 00027: early stopping

# %%
plt.grid()

plt.plot(history.history['loss'],'--^r',label="loss")
plt.plot(history.history['accuracy'],'--^g',label='accuracy')
plt.plot(history.history['val_loss'],'-or',label='val_loss')
plt.plot(history.history['val_accuracy'],'-og',label='val_accuracy')
plt.legend()

# %%
def check_result(n):
    fig=plt.figure(figsize=(8,8))
    fig.add_subplot(1,2,1).imshow(y_test[n])
    fig.add_subplot(1,2,2).imshow(model.predict(x_test)[n])

# %%
for i in range(10):
    check_result(i)

# %%
def plot_hist(img,f):
#     if(f==0):
    img=cv2.cvtColor(np.array(img*255,dtype=np.uint8),cv2.COLOR_RGB2HSV)/255.
#         clahe=cv2.createCLAHE(clipLimit=3.0, tileGridSize=(2,2))
#         img[:,:,2]=clahe.apply(img[:,:,2])
#         img=cv2.cvtColor(img,cv2.COLOR_HSV2RGB)/255.
    h,s,v=cv2.split(img)
    fig=plt.figure(figsize=(16,16))
    fig.add_subplot(4,2,1).imshow(img)
    fig.add_subplot(4,2,2).hist(img.ravel(), bins=256, range=(0.0, 1.0))
    #red
    fig.add_subplot(4,2,3).imshow(h)
    fig.add_subplot(4,2,4).hist(h.ravel(), bins=256, range=(0.0, 1.0))
    #green
    fig.add_subplot(4,2,5).imshow(s)
    fig.add_subplot(4,2,6).hist(s.ravel(), bins=256, range=(0.0, 1.0))
    #blue
#     v=np.power(v,1/3)
    fig.add_subplot(4,2,7).imshow(v)
    fig.add_subplot(4,2,8).hist(v.ravel(), bins=256, range=(0.0, 1.0))

# %%
plot_hist(x_test[1],1)

# %%
plot_hist(y_test[1],1)

# %%
# look at hue

# %%
plot_hist(model.predict(x_test)[1],1)
