# %%
import numpy as np
import keras
import matplotlib.pyplot as plt

# %%
import keras.preprocessing.image as img_preprocess

img=img_preprocess.load_img('../../dataSets/pic2.jpeg',target_size=(128, 128))
img_arr=(img_preprocess.img_to_array(img)/255.).reshape(1, 128, 128, 3)
img
#plt.imshow(img_arr)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1CD67B46A88>

# %%
from PIL import ImageFilter

im1 = img.filter(ImageFilter.BLUR)
im2 = img.filter(ImageFilter.MinFilter(3))
im3 = img.filter(ImageFilter.MinFilter)

# %%
im1
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1CD67CBA688>

# %%
im2
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1CD67D625C8>

# %%
im3
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x1CD67D62848>

# %%
img_preprocess.array_to_img(np.array(keras.layers.UpSampling2D(size=(3,3))(img_arr)).reshape(3*128,3*128,3))
# Out:
# <PIL.Image.Image image mode=RGB size=384x384 at 0x1CD67831D48>

# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,UpSampling2D,Flatten,Dense,Dropout

plt.imshow(np.array(Conv2D(3,(1,1),padding='same',activation='elu')(Conv2D(32,(3,3),padding='same',activation='elu')(img_arr))).reshape(128,128,3))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
def f(x):
    I = np.add(0.29*x[:,:,:,0], np.add(0.58*x[:,:,:,1], 0.11*x[:,:,:,2]))
    I = 1 - I
    return I

# %%
plt.imshow(np.squeeze(f(img_arr),0))
