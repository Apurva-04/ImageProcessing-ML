# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import tensorflow as tf
import keras
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array

# %%
h,w=160,160

x_train=[]
y_train=[]
x_test=[]
y_test=[]

path_train_low='../../dataSets/ref/our485/low/'
path_train_high='../../dataSets/ref/our485/high/'
path_test_low='../../dataSets/ref/eval15/low/'
path_test_high='../../dataSets/ref/eval15/high/'

print('\nLoding Train dataset :')
i=0;
for img in os.listdir(path_train_low):
    img_low_path=os.path.join(path_train_low, img)
    img_high_path=os.path.join(path_train_high, img)
    
    img_low=load_img(img_low_path, target_size=(h,w))
    img_low=img_to_array(img_low)/255.
       
    i=i+1
    print("{:.2f}".format(i/4.89)+' %',end='\r')
    
    img_high=load_img(img_high_path, target_size=(h,w))
    img_high=img_to_array(img_high)/255.
    
    x_train.append(img_low)
    y_train.append(img_high)
    
print('\nLoding Test dataset :')
i=0;
for img in os.listdir(path_test_low):
    img_low_path=os.path.join(path_test_low, img)
    img_high_path=os.path.join(path_test_high, img)
    
    img_low=load_img(img_low_path, target_size=(h,w))
    img_low=img_to_array(img_low)/255.
   
    i=i+1
    print("{:.2f}".format(i/0.14)+' %',end='\r')
    
    img_high=load_img(img_high_path, target_size=(h,w))
    img_high=img_to_array(img_high)/255.
    
    x_test.append(img_low)
    y_test.append(img_high)

x_train=np.array(x_train, dtype="float32")
y_train=np.array(y_train, dtype="float32")

x_test=np.array(x_test, dtype="float32")
y_test=np.array(y_test, dtype="float32")
# Out:
# Loding Train dataset :
# 100.00 %
# Loding Test dataset :
# 100.00 %

# %%
fig=plt.figure()

f=fig.add_subplot(1,2,1)
s=fig.add_subplot(1,2,2)

f.imshow(x_test[1])
s.imshow(y_test[1])

# %%
from keras.models import Model
from keras.models import Sequential
from keras.layers import Input,add,Conv2D,MaxPooling2D,UpSampling2D,Flatten,Dropout,Dense,BatchNormalization,Reshape,UpSampling2D,Conv2DTranspose,Concatenate

def InstantiateModel(in_):
    channel = 40
    kernal_size = (3, 3)
    #denoise
    conv0 = Conv2D(channel, kernal_size, strides=1, padding='same', activation=None)(in_)#(in_)
    
    conv1 = Conv2D(channel, kernal_size, strides=2, padding='same', activation='relu')(conv0)
    conv2 = Conv2D(channel, kernal_size, strides=2, padding='same', activation='relu')(conv1)
    conv3 = Conv2D(channel, kernal_size, strides=2, padding='same', activation='relu')(conv2)
    
    up3 = UpSampling2D((2,2))(conv3)
    deconv3 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(up3)+conv2
    up2 = UpSampling2D((2,2))(deconv3)
    deconv2 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(up2)+conv1
    up1 = UpSampling2D((2,2))(deconv2)
    deconv1 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(up1)+conv0
    
    deconv2_resize = UpSampling2D((2,2))(deconv2)
    model_1 = Concatenate()([deconv2_resize, deconv1])
    
    #adjustment
    model_2 = Conv2D(channel, kernal_size, activation='relu', padding='same', strides=1)(Concatenate()([in_,model_1]))
    model_2 = Conv2D(channel, kernal_size, activation='relu', padding='same', strides=1)(model_2)
    model_2 = Conv2D(channel, kernal_size, activation='relu', padding='same', strides=1)(model_2)
    
    model_concat = Concatenate()([model_2,model_1])
    
    c =  Conv2D(channel, kernal_size, activation='relu', padding='same', strides=1)(in_)
    conv1 = Conv2D(channel, kernal_size, strides=2, padding='same', activation='relu')(Concatenate()([c, model_concat]))
    conv2 = Conv2D(channel, kernal_size, strides=2, padding='same', activation='relu')(conv1)
    conv3 = Conv2D(channel, kernal_size, strides=2, padding='same', activation='relu')(conv2)
    
    up3 = UpSampling2D((2,2))(conv3)
    deconv3 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(up3)+conv2
    up2 = UpSampling2D((2,2))(deconv3)
    deconv2 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(up2)+conv1
    up1 = UpSampling2D((2,2))(deconv2)
    y1 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(up1)+conv0
                                                                                         
    
    c =  Conv2D(channel, kernal_size, activation='relu', padding='same', strides=1)(c)
    y2 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(Concatenate()([c, model_concat]))
    y2 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(y2)
    y2 = Conv2D(channel, (2,2), strides=1, padding='same', activation='relu')(y2)
    
    y2 = Conv2DTranspose(channel, (2,2), strides=1, padding='same', activation='relu')(y2)
    y2 = Conv2DTranspose(channel, kernal_size, strides=1, padding='same', activation='relu')(y2)
    y2 = Conv2DTranspose(channel, kernal_size, strides=1, padding='same', activation='relu')(y2)
    
    c =  Conv2D(channel, kernal_size, activation='relu', padding='same', strides=1)(c)
    y4 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(Concatenate()([c, model_concat]))
    y4 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(y4)
    y4 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(y4)
                                                                                         
    out1 = Conv2D(3, (1,1), activation='sigmoid', padding='same', strides=1)(Concatenate()([y1, y2, y4]))                                                                                 
                                                                                         
    #restoration
    model_3 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(out1)
    model_3 = Conv2D(channel, kernal_size, activation='relu', padding='same', strides=1)(model_3)
    model_3 = Conv2D(channel, kernal_size, activation='relu', padding='same', strides=1)(model_3)
    
    out2 = Conv2D(3, (1,1), activation='sigmoid', padding='same', strides=1)(model_3)#(feature_fusion)
    
    return out2

# %%
Input_Sample = Input(shape=(h, w, 3))
Output_ = InstantiateModel(Input_Sample)
model = Model(inputs=Input_Sample, outputs=Output_)
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 160, 160, 40) 1120        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 80, 80, 40)   14440       conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 40, 40, 40)   14440       conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 20, 20, 40)   14440       conv2d_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 40, 40, 40)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 40, 40, 40)   14440       up_sampling2d[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp [(None, 40, 40, 40)] 0           conv2d_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 80, 80, 40)   0           tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 80, 80, 40)   14440       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_1 (TensorFlow [(None, 80, 80, 40)] 0           conv2d_5[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 160, 160, 40) 0           tf_op_layer_AddV2_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 160, 160, 40) 14440       up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 160, 160, 40) 0           tf_op_layer_AddV2_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_2 (TensorFlow [(None, 160, 160, 40 0           conv2d_6[0][0]
#                                                                  conv2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 160, 160, 80) 0           up_sampling2d_3[0][0]
#                                                                  tf_op_layer_AddV2_2[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 160, 160, 83) 0           input_1[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 160, 160, 40) 29920       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 160, 160, 40) 14440       conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 160, 160, 40) 14440       conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 160, 160, 40) 1120        input_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 160, 160, 120 0           conv2d_9[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 160, 160, 160 0           conv2d_10[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 80, 80, 40)   57640       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 40, 40, 40)   14440       conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 20, 20, 40)   14440       conv2d_12[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 40, 40, 40)   0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 40, 40, 40)   14440       up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 160, 160, 40) 14440       conv2d_10[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_3 (TensorFlow [(None, 40, 40, 40)] 0           conv2d_14[0][0]
#                                                                  conv2d_12[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 160, 160, 160 0           conv2d_17[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 80, 80, 40)   0           tf_op_layer_AddV2_3[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 160, 160, 40) 57640       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 80, 80, 40)   14440       up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 160, 160, 40) 14440       conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 160, 160, 40) 14440       conv2d_17[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_4 (TensorFlow [(None, 80, 80, 40)] 0           conv2d_15[0][0]
#                                                                  conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 160, 160, 40) 6440        conv2d_19[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 160, 160, 160 0           conv2d_21[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 160, 160, 40) 0           tf_op_layer_AddV2_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 160, 160, 40) 6440        conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 160, 160, 40) 57640       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 160, 160, 40) 14440       up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 160, 160, 40) 14440       conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 160, 160, 40) 14440       conv2d_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_5 (TensorFlow [(None, 160, 160, 40 0           conv2d_16[0][0]
#                                                                  conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 160, 160, 40) 14440       conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 160, 160, 40) 14440       conv2d_23[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 160, 160, 120 0           tf_op_layer_AddV2_5[0][0]
#                                                                  conv2d_transpose_2[0][0]
#                                                                  conv2d_24[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 160, 160, 3)  363         concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 160, 160, 40) 1120        conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 160, 160, 40) 14440       conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 160, 160, 40) 14440       conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 160, 160, 3)  123         conv2d_28[0][0]
# ==================================================================================================
# Total params: 537,246
# Trainable params: 537,246
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model,to_file='model.png',show_shapes=True, show_layer_names=True)

# %%
def _tf_fspecial_gauss(size, sigma):
    """Function to mimic the 'fspecial' gaussian MATLAB function
    """
    x_data, y_data = np.mgrid[-size//2 + 1:size//2 + 1, -size//2 + 1:size//2 + 1]

    x_data = np.expand_dims(x_data, axis=-1)
    x_data = np.expand_dims(x_data, axis=-1)

    y_data = np.expand_dims(y_data, axis=-1)
    y_data = np.expand_dims(y_data, axis=-1)

    x = tf.constant(x_data, dtype=tf.float32)
    y = tf.constant(y_data, dtype=tf.float32)

    g = tf.exp(-((x**2 + y**2)/(2.0*sigma**2)))
    return g / tf.reduce_sum(g)

def tf_ssim(img1, img2, cs_map=False, mean_metric=True, size=11, sigma=1.5):
    window = _tf_fspecial_gauss(size, sigma) # window shape [size, size]
    K1 = 0.01
    K2 = 0.03
    L = 1  # depth of image (255 in case the image has a differnt scale)
    C1 = (K1*L)**2
    C2 = (K2*L)**2
    mu1 = tf.nn.conv2d(img1, window, strides=[1,1,1,1], padding='VALID')
    mu2 = tf.nn.conv2d(img2, window, strides=[1,1,1,1],padding='VALID')
    mu1_sq = mu1*mu1
    mu2_sq = mu2*mu2
    mu1_mu2 = mu1*mu2
    sigma1_sq = tf.nn.conv2d(img1*img1, window, strides=[1,1,1,1],padding='VALID') - mu1_sq
    sigma2_sq = tf.nn.conv2d(img2*img2, window, strides=[1,1,1,1],padding='VALID') - mu2_sq
    sigma12 = tf.nn.conv2d(img1*img2, window, strides=[1,1,1,1],padding='VALID') - mu1_mu2
    if cs_map:
        value = (((2*mu1_mu2 + C1)*(2*sigma12 + C2))/((mu1_sq + mu2_sq + C1)*
                            (sigma1_sq + sigma2_sq + C2)),
                        (2.0*sigma12 + C2)/(sigma1_sq + sigma2_sq + C2))
    else:
        value = ((2*mu1_mu2 + C1)*(2*sigma12 + C2))/((mu1_sq + mu2_sq + C1)*
                            (sigma1_sq + sigma2_sq + C2))

    if mean_metric:
        value = tf.reduce_mean(value)
    return value

def ssim(y_true, y_pred):
    return tf_ssim(tf.expand_dims(y_pred[:, :, :, 0], -1),tf.expand_dims(y_true[:, :, :, 0], -1)) + tf_ssim(
                tf.expand_dims(y_pred[:, :, :, 1], -1), tf.expand_dims(y_true[:, :, :, 1], -1)) + tf_ssim(
                tf.expand_dims(y_pred[:, :, :, 2], -1), tf.expand_dims(y_true[:, :, :, 2], -1))

def my_loss(y_true, y_pred):
    MAE_loss = K.mean(K.abs(y_pred - y_true))
    SSIM_loss = tf_ssim(tf.expand_dims(y_pred[:, :, :, 0], -1),tf.expand_dims(y_true[:, :, :, 0], -1)) + tf_ssim(
                tf.expand_dims(y_pred[:, :, :, 1], -1), tf.expand_dims(y_true[:, :, :, 1], -1)) + tf_ssim(
                tf.expand_dims(y_pred[:, :, :, 2], -1), tf.expand_dims(y_true[:, :, :, 2], -1))

    percent = 0.4
    index = int(h * w * percent - 1)
    gray1 = 0.29 * y_pred[:, :, :, 0] + 0.58 * y_pred[:, :, :, 1] + 0.11 * y_pred[:, :, :, 2]
    gray = tf.reshape(gray1, [-1, h * w])
    gray_sort = tf.nn.top_k(-gray, h * w)[0]
    yu = gray_sort[:, index]
    yu = tf.expand_dims(tf.expand_dims(yu, -1), -1)
    mask = tf.cast(gray1 <= yu,tf.float32)
    mask1 = tf.expand_dims(mask, -1)
    mask = tf.concat([mask1, mask1, mask1], -1)

    low_fake_clean = tf.multiply(mask, y_pred[:, :, :, :3])
    high_fake_clean = tf.multiply(1 - mask, y_pred[:, :, :, :3])
    low_clean = tf.multiply(mask, y_true[:, :, :, :])
    high_clean = tf.multiply(1 - mask, y_true[:, :, :, :])
    Region_loss = K.mean(K.abs(low_fake_clean - low_clean) * 4 + K.abs(high_fake_clean - high_clean))

    loss = MAE_loss + 3 - SSIM_loss + Region_loss
    
    return loss

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

checkpoint=ModelCheckpoint('models/model_6.h5',
                            monitor='val_loss',
                            mode='min',
                            save_best_only=True,
                            verbose=1
                          )
earlystop=EarlyStopping(monitor='val_loss',
                        patience=10,
                        min_delta=0,
                        restore_best_weights=True,
                        verbose=1
                       )
reduce_lr=ReduceLROnPlateau(monitor='val_loss',
                            factor=0.1,
                            patience=10,
                            min_delta=0.001,
                            verbose=1
                           )

callbacks=[checkpoint,earlystop,reduce_lr]

METRICS=[
    keras.metrics.MeanSquaredError(name='mse'),
    ssim,
    'accuracy'
]
model.compile(loss=my_loss,
              optimizer=keras.optimizers.Adam(learning_rate=0.001),
              metrics=METRICS
             )

history=model.fit(
    x=x_train,
    y=y_train,
    batch_size=16,
    shuffle=True,
    epochs=100,
    validation_data=(x_test, y_test),
    callbacks=callbacks
    )
# Out:
# Epoch 1/100
# 31/31 [==============================] - ETA: 0s - loss: 1.7914 - mse: 0.0425 - ssim: 1.5479 - accuracy: 0.4841
# Epoch 00001: val_loss improved from inf to 1.50146, saving model to models\model_6.h5
# 31/31 [==============================] - 582s 19s/step - loss: 1.7914 - mse: 0.0425 - ssim: 1.5479 - accuracy: 0.4841 - val_loss: 1.5015 - val_mse: 0.0363 - val_ssim: 1.8039 - val_accuracy: 0.5471
# Epoch 2/100
# 31/31 [==============================] - ETA: 0s - loss: 1.2519 - mse: 0.0297 - ssim: 2.0276 - accuracy: 0.5094
# Epoch 00002: val_loss improved from 1.50146 to 1.26512, saving model to models\model_6.h5
# 31/31 [==============================] - 590s 19s/step - loss: 1.2519 - mse: 0.0297 - ssim: 2.0276 - accuracy: 0.5094 - val_loss: 1.2651 - val_mse: 0.0306 - val_ssim: 2.0189 - val_accuracy: 0.5452
# Epoch 3/100
# 31/31 [==============================] - ETA: 0s - loss: 1.1436 - mse: 0.0305 - ssim: 2.1337 - accuracy: 0.4675
# Epoch 00003: val_loss improved from 1.26512 to 1.09439, saving model to models\model_6.h5
# 31/31 [==============================] - 575s 19s/step - loss: 1.1436 - mse: 0.0305 - ssim: 2.1337 - accuracy: 0.4675 - val_loss: 1.0944 - val_mse: 0.0226 - val_ssim: 2.1421 - val_accuracy: 0.3642
# Epoch 4/100
# 31/31 [==============================] - ETA: 0s - loss: 1.0436 - mse: 0.0278 - ssim: 2.2191 - accuracy: 0.5283
# Epoch 00004: val_loss improved from 1.09439 to 1.04169, saving model to models\model_6.h5
# 31/31 [==============================] - 581s 19s/step - loss: 1.0436 - mse: 0.0278 - ssim: 2.2191 - accuracy: 0.5283 - val_loss: 1.0417 - val_mse: 0.0232 - val_ssim: 2.2005 - val_accuracy: 0.5479
# Epoch 5/100
# 31/31 [==============================] - ETA: 0s - loss: 0.9677 - mse: 0.0258 - ssim: 2.2865 - accuracy: 0.5266
# Epoch 00005: val_loss improved from 1.04169 to 0.96973, saving model to models\model_6.h5
# 31/31 [==============================] - 564s 18s/step - loss: 0.9677 - mse: 0.0258 - ssim: 2.2865 - accuracy: 0.5266 - val_loss: 0.9697 - val_mse: 0.0211 - val_ssim: 2.2585 - val_accuracy: 0.5350
# Epoch 6/100
# 31/31 [==============================] - ETA: 0s - loss: 0.9266 - mse: 0.0253 - ssim: 2.3254 - accuracy: 0.5371
# Epoch 00006: val_loss improved from 0.96973 to 0.94572, saving model to models\model_6.h5
# 31/31 [==============================] - 571s 18s/step - loss: 0.9266 - mse: 0.0253 - ssim: 2.3254 - accuracy: 0.5371 - val_loss: 0.9457 - val_mse: 0.0208 - val_ssim: 2.2803 - val_accuracy: 0.5504
# Epoch 7/100
# 31/31 [==============================] - ETA: 0s - loss: 0.9085 - mse: 0.0253 - ssim: 2.3454 - accuracy: 0.4899
# Epoch 00007: val_loss did not improve from 0.94572
# 31/31 [==============================] - 558s 18s/step - loss: 0.9085 - mse: 0.0253 - ssim: 2.3454 - accuracy: 0.4899 - val_loss: 0.9460 - val_mse: 0.0226 - val_ssim: 2.2914 - val_accuracy: 0.5446
# Epoch 8/100
# 31/31 [==============================] - ETA: 0s - loss: 0.8870 - mse: 0.0246 - ssim: 2.3601 - accuracy: 0.5270
# Epoch 00008: val_loss improved from 0.94572 to 0.92861, saving model to models\model_6.h5
# 31/31 [==============================] - 564s 18s/step - loss: 0.8870 - mse: 0.0246 - ssim: 2.3601 - accuracy: 0.5270 - val_loss: 0.9286 - val_mse: 0.0210 - val_ssim: 2.3003 - val_accuracy: 0.5430
# Epoch 9/100
# 31/31 [==============================] - ETA: 0s - loss: 0.8969 - mse: 0.0253 - ssim: 2.3569 - accuracy: 0.5481
# Epoch 00009: val_loss did not improve from 0.92861
# 31/31 [==============================] - 636s 21s/step - loss: 0.8969 - mse: 0.0253 - ssim: 2.3569 - accuracy: 0.5481 - val_loss: 0.9591 - val_mse: 0.0254 - val_ssim: 2.2937 - val_accuracy: 0.5478
# Epoch 10/100
# 31/31 [==============================] - ETA: 0s - loss: 0.8763 - mse: 0.0249 - ssim: 2.3745 - accuracy: 0.5461
# Epoch 00010: val_loss did not improve from 0.92861
# 31/31 [==============================] - 738s 24s/step - loss: 0.8763 - mse: 0.0249 - ssim: 2.3745 - accuracy: 0.5461 - val_loss: 0.9378 - val_mse: 0.0236 - val_ssim: 2.3071 - val_accuracy: 0.5550
# Epoch 11/100
# 31/31 [==============================] - ETA: 0s - loss: 0.8599 - mse: 0.0234 - ssim: 2.3822 - accuracy: 0.5687
# Epoch 00011: val_loss improved from 0.92861 to 0.86824, saving model to models\model_6.h5
# 31/31 [==============================] - 768s 25s/step - loss: 0.8599 - mse: 0.0234 - ssim: 2.3822 - accuracy: 0.5687 - val_loss: 0.8682 - val_mse: 0.0183 - val_ssim: 2.3448 - val_accuracy: 0.5047
# Epoch 12/100
# 31/31 [==============================] - ETA: 0s - loss: 0.8237 - mse: 0.0220 - ssim: 2.4099 - accuracy: 0.6366
# Epoch 00012: val_loss improved from 0.86824 to 0.85317, saving model to models\model_6.h5
# 31/31 [==============================] - 725s 23s/step - loss: 0.8237 - mse: 0.0220 - ssim: 2.4099 - accuracy: 0.6366 - val_loss: 0.8532 - val_mse: 0.0184 - val_ssim: 2.3627 - val_accuracy: 0.7283
# Epoch 13/100
# 31/31 [==============================] - ETA: 0s - loss: 0.8368 - mse: 0.0237 - ssim: 2.4043 - accuracy: 0.6411
# Epoch 00013: val_loss did not improve from 0.85317
# 31/31 [==============================] - 550s 18s/step - loss: 0.8368 - mse: 0.0237 - ssim: 2.4043 - accuracy: 0.6411 - val_loss: 0.8615 - val_mse: 0.0189 - val_ssim: 2.3566 - val_accuracy: 0.6560
# Epoch 14/100
# 31/31 [==============================] - ETA: 0s - loss: 0.8074 - mse: 0.0213 - ssim: 2.4225 - accuracy: 0.6537
# Epoch 00014: val_loss improved from 0.85317 to 0.82500, saving model to models\model_6.h5
# 31/31 [==============================] - 543s 18s/step - loss: 0.8074 - mse: 0.0213 - ssim: 2.4225 - accuracy: 0.6537 - val_loss: 0.8250 - val_mse: 0.0166 - val_ssim: 2.3799 - val_accuracy: 0.7285
# Epoch 15/100
# 31/31 [==============================] - ETA: 0s - loss: 0.7972 - mse: 0.0212 - ssim: 2.4336 - accuracy: 0.6391
# Epoch 00015: val_loss did not improve from 0.82500
# 31/31 [==============================] - 587s 19s/step - loss: 0.7972 - mse: 0.0212 - ssim: 2.4336 - accuracy: 0.6391 - val_loss: 0.8387 - val_mse: 0.0176 - val_ssim: 2.3732 - val_accuracy: 0.7130
# Epoch 16/100
# 31/31 [==============================] - ETA: 0s - loss: 0.7781 - mse: 0.0202 - ssim: 2.4476 - accuracy: 0.6629
# Epoch 00016: val_loss improved from 0.82500 to 0.79899, saving model to models\model_6.h5
# 31/31 [==============================] - 708s 23s/step - loss: 0.7781 - mse: 0.0202 - ssim: 2.4476 - accuracy: 0.6629 - val_loss: 0.7990 - val_mse: 0.0155 - val_ssim: 2.3983 - val_accuracy: 0.7212
# Epoch 17/100
# 31/31 [==============================] - ETA: 0s - loss: 0.7872 - mse: 0.0209 - ssim: 2.4415 - accuracy: 0.6752
# Epoch 00017: val_loss did not improve from 0.79899
# 31/31 [==============================] - 710s 23s/step - loss: 0.7872 - mse: 0.0209 - ssim: 2.4415 - accuracy: 0.6752 - val_loss: 0.8141 - val_mse: 0.0175 - val_ssim: 2.3961 - val_accuracy: 0.7553
# Epoch 18/100
# 31/31 [==============================] - ETA: 0s - loss: 0.7691 - mse: 0.0203 - ssim: 2.4562 - accuracy: 0.6846
# Epoch 00018: val_loss did not improve from 0.79899
# 31/31 [==============================] - 710s 23s/step - loss: 0.7691 - mse: 0.0203 - ssim: 2.4562 - accuracy: 0.6846 - val_loss: 0.8023 - val_mse: 0.0166 - val_ssim: 2.4052 - val_accuracy: 0.7116
# Epoch 19/100
# 31/31 [==============================] - ETA: 0s - loss: 0.7775 - mse: 0.0200 - ssim: 2.4464 - accuracy: 0.6431
# Epoch 00019: val_loss did not improve from 0.79899
# 31/31 [==============================] - 701s 23s/step - loss: 0.7775 - mse: 0.0200 - ssim: 2.4464 - accuracy: 0.6431 - val_loss: 0.8262 - val_mse: 0.0173 - val_ssim: 2.3820 - val_accuracy: 0.6318
# Epoch 20/100
# 31/31 [==============================] - ETA: 0s - loss: 0.7912 - mse: 0.0209 - ssim: 2.4389 - accuracy: 0.6324
# Epoch 00020: val_loss did not improve from 0.79899
# 31/31 [==============================] - 616s 20s/step - loss: 0.7912 - mse: 0.0209 - ssim: 2.4389 - accuracy: 0.6324 - val_loss: 0.8579 - val_mse: 0.0205 - val_ssim: 2.3711 - val_accuracy: 0.7320
# Epoch 21/100
# 31/31 [==============================] - ETA: 0s - loss: 0.7572 - mse: 0.0194 - ssim: 2.4654 - accuracy: 0.6784
# Epoch 00021: val_loss improved from 0.79899 to 0.78656, saving model to models\model_6.h5
# 31/31 [==============================] - 550s 18s/step - loss: 0.7572 - mse: 0.0194 - ssim: 2.4654 - accuracy: 0.6784 - val_loss: 0.7866 - val_mse: 0.0165 - val_ssim: 2.4185 - val_accuracy: 0.6492
# Epoch 22/100
# 31/31 [==============================] - ETA: 0s - loss: 0.7458 - mse: 0.0189 - ssim: 2.4708 - accuracy: 0.6861
# Epoch 00022: val_loss improved from 0.78656 to 0.78310, saving model to models\model_6.h5
# 31/31 [==============================] - 558s 18s/step - loss: 0.7458 - mse: 0.0189 - ssim: 2.4708 - accuracy: 0.6861 - val_loss: 0.7831 - val_mse: 0.0160 - val_ssim: 2.4192 - val_accuracy: 0.7241
# Epoch 23/100
# 31/31 [==============================] - ETA: 0s - loss: 0.7439 - mse: 0.0192 - ssim: 2.4754 - accuracy: 0.6782
# Epoch 00023: val_loss did not improve from 0.78310
# 31/31 [==============================] - 561s 18s/step - loss: 0.7439 - mse: 0.0192 - ssim: 2.4754 - accuracy: 0.6782 - val_loss: 0.8163 - val_mse: 0.0188 - val_ssim: 2.4045 - val_accuracy: 0.7351
# Epoch 24/100
# 31/31 [==============================] - ETA: 0s - loss: 0.7446 - mse: 0.0189 - ssim: 2.4743 - accuracy: 0.6630
# Epoch 00024: val_loss did not improve from 0.78310
# 31/31 [==============================] - 554s 18s/step - loss: 0.7446 - mse: 0.0189 - ssim: 2.4743 - accuracy: 0.6630 - val_loss: 0.8655 - val_mse: 0.0220 - val_ssim: 2.3745 - val_accuracy: 0.5844
# Epoch 25/100
# 31/31 [==============================] - ETA: 0s - loss: 0.7431 - mse: 0.0185 - ssim: 2.4737 - accuracy: 0.6741
# Epoch 00025: val_loss did not improve from 0.78310
# 31/31 [==============================] - 553s 18s/step - loss: 0.7431 - mse: 0.0185 - ssim: 2.4737 - accuracy: 0.6741 - val_loss: 0.7871 - val_mse: 0.0157 - val_ssim: 2.4142 - val_accuracy: 0.6485
# Epoch 26/100
# 31/31 [==============================] - ETA: 0s - loss: 0.7618 - mse: 0.0202 - ssim: 2.4628 - accuracy: 0.6702
# Epoch 00026: val_loss did not improve from 0.78310
# 31/31 [==============================] - 565s 18s/step - loss: 0.7618 - mse: 0.0202 - ssim: 2.4628 - accuracy: 0.6702 - val_loss: 0.9092 - val_mse: 0.0270 - val_ssim: 2.3550 - val_accuracy: 0.6843
# Epoch 27/100
# 31/31 [==============================] - ETA: 0s - loss: 0.7610 - mse: 0.0201 - ssim: 2.4652 - accuracy: 0.6811
# Epoch 00027: val_loss improved from 0.78310 to 0.77675, saving model to models\model_6.h5
# 31/31 [==============================] - 568s 18s/step - loss: 0.7610 - mse: 0.0201 - ssim: 2.4652 - accuracy: 0.6811 - val_loss: 0.7767 - val_mse: 0.0157 - val_ssim: 2.4242 - val_accuracy: 0.7626
# Epoch 28/100
# 31/31 [==============================] - ETA: 0s - loss: 0.7285 - mse: 0.0182 - ssim: 2.4836 - accuracy: 0.6963
# Epoch 00028: val_loss did not improve from 0.77675
# 31/31 [==============================] - 656s 21s/step - loss: 0.7285 - mse: 0.0182 - ssim: 2.4836 - accuracy: 0.6963 - val_loss: 0.7804 - val_mse: 0.0154 - val_ssim: 2.4175 - val_accuracy: 0.7323
# Epoch 29/100
# 31/31 [==============================] - ETA: 0s - loss: 0.7365 - mse: 0.0185 - ssim: 2.4811 - accuracy: 0.6874
# Epoch 00029: val_loss improved from 0.77675 to 0.76673, saving model to models\model_6.h5
# 31/31 [==============================] - 752s 24s/step - loss: 0.7365 - mse: 0.0185 - ssim: 2.4811 - accuracy: 0.6874 - val_loss: 0.7667 - val_mse: 0.0154 - val_ssim: 2.4314 - val_accuracy: 0.5655
# Epoch 30/100
# 31/31 [==============================] - ETA: 0s - loss: 0.7156 - mse: 0.0175 - ssim: 2.4938 - accuracy: 0.6920
# Epoch 00030: val_loss did not improve from 0.76673
# 31/31 [==============================] - 765s 25s/step - loss: 0.7156 - mse: 0.0175 - ssim: 2.4938 - accuracy: 0.6920 - val_loss: 0.7928 - val_mse: 0.0186 - val_ssim: 2.4264 - val_accuracy: 0.6602
# Epoch 31/100
# 31/31 [==============================] - ETA: 0s - loss: 0.7134 - mse: 0.0173 - ssim: 2.4941 - accuracy: 0.6706
# Epoch 00031: val_loss did not improve from 0.76673
# 31/31 [==============================] - 610s 20s/step - loss: 0.7134 - mse: 0.0173 - ssim: 2.4941 - accuracy: 0.6706 - val_loss: 0.7916 - val_mse: 0.0162 - val_ssim: 2.4129 - val_accuracy: 0.6845
# Epoch 32/100
# 31/31 [==============================] - ETA: 0s - loss: 0.7411 - mse: 0.0188 - ssim: 2.4768 - accuracy: 0.6677
# Epoch 00032: val_loss did not improve from 0.76673
# 31/31 [==============================] - 576s 19s/step - loss: 0.7411 - mse: 0.0188 - ssim: 2.4768 - accuracy: 0.6677 - val_loss: 0.7947 - val_mse: 0.0175 - val_ssim: 2.4180 - val_accuracy: 0.6778
# Epoch 33/100
#  2/31 [>.............................] - ETA: 4:42 - loss: 0.6886 - mse: 0.0168 - ssim: 2.5085 - accuracy: 0.6858

# %%
plt.grid()

plt.plot(history.history['loss'],'--^r',label="loss")
plt.plot(history.history['accuracy'],'--^g',label='accuracy')
plt.plot(history.history['val_loss'],'-or',label='val_loss')
plt.plot(history.history['val_accuracy'],'-og',label='val_accuracy')
plt.legend()

# %%
def check_result(n):
    fig=plt.figure()
    fig.add_subplot(1,2,1).imshow(y_test[n])
    fig.add_subplot(1,2,2).imshow(model.predict(x_test)[n])

# %%
check_result(1)

# %%
def plot_hist(img,f):
#     if(f==0):
    img=cv2.cvtColor(np.array(img*255,dtype=np.uint8),cv2.COLOR_RGB2HSV)/255.
#         clahe=cv2.createCLAHE(clipLimit=3.0, tileGridSize=(2,2))
#         img[:,:,2]=clahe.apply(img[:,:,2])
#         img=cv2.cvtColor(img,cv2.COLOR_HSV2RGB)/255.
    h,s,v=cv2.split(img)
    fig=plt.figure(figsize=(16,16))
    fig.add_subplot(4,2,1).imshow(img)
    fig.add_subplot(4,2,2).hist(img.ravel(), bins=256, range=(0.0, 1.0))
    #red
    fig.add_subplot(4,2,3).imshow(h)
    fig.add_subplot(4,2,4).hist(h.ravel(), bins=256, range=(0.0, 1.0))
    #green
    fig.add_subplot(4,2,5).imshow(s)
    fig.add_subplot(4,2,6).hist(s.ravel(), bins=256, range=(0.0, 1.0))
    #blue
#     v=np.power(v,1/3)
    fig.add_subplot(4,2,7).imshow(v)
    fig.add_subplot(4,2,8).hist(v.ravel(), bins=256, range=(0.0, 1.0))

# %%
plot_hist(y_test[1],1)

# %%
plot_hist(x_test[1],1)

# %%
# look at hue

# %%
plot_hist(model.predict(x_test)[1],1)
