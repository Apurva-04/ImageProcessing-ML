# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import tensorflow as tf
import keras
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array

# %%
h, w = 160, 160

x_train=[]
y_train=[]
x_test=[]
y_test=[]

path_train_low='../../dataSets/ref/our485/low/'
path_train_high='../../dataSets/ref/our485/high/'
path_test_low='../../dataSets/ref/eval15/low/'
path_test_high='../../dataSets/ref/eval15/high/'

print('\nLoding Train dataset :')
i=0;
for img in os.listdir(path_train_low):
    img_low_path=os.path.join(path_train_low, img)
    img_high_path=os.path.join(path_train_high, img)
    
    img_low=load_img(img_low_path, target_size=(h,w))
    img_low=img_to_array(img_low)/255.
    
    i=i+1
    print("{:.2f}".format(i/4.89)+' %',end='\r')
    
    img_high=load_img(img_high_path, target_size=(h,w))
    img_high=img_to_array(img_high)/255.
    
    x_train.append(img_low)
    y_train.append(img_high)
    
print('\nLoding Test dataset :')
i=0;
for img in os.listdir(path_test_low):
    img_low_path=os.path.join(path_test_low, img)
    img_high_path=os.path.join(path_test_high, img)
    
    img_low=load_img(img_low_path, target_size=(h,w))
    img_low=img_to_array(img_low)/255.
    
    i=i+1
    print("{:.2f}".format(i/0.14)+' %',end='\r')
    
    img_high=load_img(img_high_path, target_size=(h,w))
    img_high=img_to_array(img_high)/255.
    
    x_test.append(img_low)
    y_test.append(img_high)

x_train=np.array(x_train, dtype="float32")
y_train=np.array(y_train, dtype="float32")

x_test=np.array(x_test, dtype="float32")
y_test=np.array(y_test, dtype="float32")
# Out:
# Loding Train dataset :
# 100.00 %
# Loding Test dataset :
# 100.00 %

# %%
fig=plt.figure()

f=fig.add_subplot(1,2,1)
s=fig.add_subplot(1,2,2)

f.imshow(x_test[6])
s.imshow(y_test[6])

# %%
from keras.models import Model
from keras.models import Sequential
from keras.layers import Input,add,Conv2D,MaxPooling2D,UpSampling2D,Flatten,Dropout,Dense,BatchNormalization,Reshape,UpSampling2D,Conv2DTranspose,Concatenate,Lambda

def f(x):
    I = tf.math.add(0.29*x[:,:,:,0], tf.math.add(0.58*x[:,:,:,1], 0.11*x[:,:,:,2]))
    I = 1 - I
    I = tf.expand_dims(I , -1)
    return I

def InstantiateModel(in_):
    channel = 32
    kernal_size = (4, 4)
    
    #AM
    def AM(in_AM):
        return Lambda(lambda x: f(x))(in_AM)
    
    #NM
    def NM(in_NM):
        nm_conv0 = Conv2D(channel, kernal_size, strides=1, padding='same', activation=None)(in_NM)
        
        nm_conv1 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(nm_conv0)
        nm_conv2 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(nm_conv1)
        nm_conv3 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(nm_conv2)
        nm_conv4 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(nm_conv3)
        
        nm_model = Conv2D(1, (1,1), padding='same', activation=None)(nm_conv4)
        return nm_model
    
    #EM
    def EM(in_EM):
        em_conv0 = Conv2D(channel, kernal_size, strides=1, padding='same', activation=None)(in_EM)
        
        em_conv1 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(em_conv0)
        em_conv2 = Conv2D(channel/2, kernal_size, strides=1, padding='same', activation='relu')(em_conv1)
        em_conv3 = Conv2D(channel/4, kernal_size, strides=1, padding='same', activation='relu')(em_conv2)

        em_deconv3 = Conv2DTranspose(channel/4, kernal_size, strides=1, padding='same', activation='relu')(em_conv3)
        em_deconv2 = Conv2DTranspose(channel/2, kernal_size, strides=1, padding='same', activation='relu')(em_deconv3)
        em_deconv1 = Conv2DTranspose(channel, kernal_size, strides=1, padding='same', activation='relu')(em_deconv2)
        
        em_model = Conv2D(3, (1,1), padding='same', activation=None)(em_deconv1)
        return em_model
    
    def EM1(in_EM):
        em_conv0 = Conv2D(channel, kernal_size, strides=1, padding='same', activation=None)(in_EM)
        
        em_conv1 = Conv2D(channel, kernal_size, strides=2, padding='same', activation='relu')(em_conv0)
        em_conv2 = Conv2D(channel, kernal_size, strides=2, padding='same', activation='relu')(em_conv1)
        em_conv3 = Conv2D(channel, kernal_size, strides=2, padding='same', activation='relu')(em_conv2)

        em_up3 = UpSampling2D((2,2))(em_conv3)
        em_deconv3 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(em_up3)+em_conv2
        em_up2 = UpSampling2D((2,2))(em_deconv3)
        em_deconv2 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(em_up2)+em_conv1
        em_up1 = UpSampling2D((2,2))(em_deconv2)
        em_deconv1 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(em_up1)+em_conv0
        
        em_model = Conv2D(3, (1,1), padding='same', activation=None)(em_deconv1)
        return em_model
    
    am=AM(in_)
    nm=NM(Concatenate()([in_,am]))
    
    #FEM
    conv0 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(in_)
    conv1 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(conv0)
    conv2 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(conv1)
    conv3 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(conv2)
    conv4 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(conv3)
    
    #FM
    conv0 = EM(Concatenate()([conv0,am,nm]))
    conv1 = EM(Concatenate()([conv1,am,nm]))
    conv2 = EM1(Concatenate()([conv2,am,nm]))
    conv3 = EM1(Concatenate()([conv3,am,nm]))
    conv4 = EM1(Concatenate()([conv4,am,nm]))
    
    out = Concatenate()([conv0, conv1, conv2, conv3, conv4])
    out = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(out)
    out = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(out)
    out = Conv2D(3, (1,1), activation='sigmoid', padding='same', strides=1)(out)
    
    return out

# %%
Input_Sample = Input(shape=(h, w, 3))
Output_ = InstantiateModel(Input_Sample)
model = Model(inputs=Input_Sample, outputs=Output_)
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 160, 160, 1)  0           input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 160, 160, 4)  0           input_1[0][0]
#                                                                  lambda[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 160, 160, 32) 2080        concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 160, 160, 32) 1568        input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 160, 160, 32) 16416       conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 160, 160, 32) 16416       conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 160, 160, 32) 16416       conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 160, 160, 32) 16416       conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 160, 160, 32) 16416       conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 160, 160, 32) 16416       conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 160, 160, 32) 16416       conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 160, 160, 1)  33          conv2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 160, 160, 32) 16416       conv2d_9[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 160, 160, 34) 0           conv2d_8[0][0]
#                                                                  lambda[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 160, 160, 34) 0           conv2d_9[0][0]
#                                                                  lambda[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 160, 160, 34) 0           conv2d_10[0][0]
#                                                                  lambda[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 160, 160, 32) 17440       concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 160, 160, 32) 17440       concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 160, 160, 32) 17440       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 80, 80, 32)   16416       conv2d_21[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 80, 80, 32)   16416       conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 80, 80, 32)   16416       conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 40, 40, 32)   16416       conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 40, 40, 32)   16416       conv2d_30[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 40, 40, 32)   16416       conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 20, 20, 32)   16416       conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 20, 20, 32)   16416       conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 20, 20, 32)   16416       conv2d_39[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 40, 40, 32)   0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 40, 40, 32)   0           conv2d_32[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 40, 40, 32)   0           conv2d_40[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 160, 160, 34) 0           conv2d_6[0][0]
#                                                                  lambda[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 160, 160, 34) 0           conv2d_7[0][0]
#                                                                  lambda[0][0]
#                                                                  conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 40, 40, 32)   16416       up_sampling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 40, 40, 32)   16416       up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 40, 40, 32)   16416       up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 160, 160, 32) 17440       concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 160, 160, 32) 17440       concatenate_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp [(None, 40, 40, 32)] 0           conv2d_25[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_3 (TensorFlow [(None, 40, 40, 32)] 0           conv2d_33[0][0]
#                                                                  conv2d_31[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_6 (TensorFlow [(None, 40, 40, 32)] 0           conv2d_41[0][0]
#                                                                  conv2d_39[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 160, 160, 32) 16416       conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 160, 160, 32) 16416       conv2d_16[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 80, 80, 32)   0           tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 80, 80, 32)   0           tf_op_layer_AddV2_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 80, 80, 32)   0           tf_op_layer_AddV2_6[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 160, 160, 16) 8208        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 160, 160, 16) 8208        conv2d_17[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 80, 80, 32)   16416       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 80, 80, 32)   16416       up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 80, 80, 32)   16416       up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 160, 160, 8)  2056        conv2d_13[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 160, 160, 8)  2056        conv2d_18[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_1 (TensorFlow [(None, 80, 80, 32)] 0           conv2d_26[0][0]
#                                                                  conv2d_22[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_4 (TensorFlow [(None, 80, 80, 32)] 0           conv2d_34[0][0]
#                                                                  conv2d_30[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_7 (TensorFlow [(None, 80, 80, 32)] 0           conv2d_42[0][0]
#                                                                  conv2d_38[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 160, 160, 8)  1032        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 160, 160, 8)  1032        conv2d_19[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 160, 160, 32) 0           tf_op_layer_AddV2_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 160, 160, 32) 0           tf_op_layer_AddV2_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 160, 160, 32) 0           tf_op_layer_AddV2_7[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 160, 160, 16) 2064        conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 160, 160, 16) 2064        conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 160, 160, 32) 16416       up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 160, 160, 32) 16416       up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 160, 160, 32) 16416       up_sampling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 160, 160, 32) 8224        conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 160, 160, 32) 8224        conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_2 (TensorFlow [(None, 160, 160, 32 0           conv2d_27[0][0]
#                                                                  conv2d_21[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_5 (TensorFlow [(None, 160, 160, 32 0           conv2d_35[0][0]
#                                                                  conv2d_29[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_8 (TensorFlow [(None, 160, 160, 32 0           conv2d_43[0][0]
#                                                                  conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 160, 160, 3)  99          conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 160, 160, 3)  99          conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 160, 160, 3)  99          tf_op_layer_AddV2_2[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 160, 160, 3)  99          tf_op_layer_AddV2_5[0][0]
# __________________________________________________________________________________________________
# conv2d_44 (Conv2D)              (None, 160, 160, 3)  99          tf_op_layer_AddV2_8[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 160, 160, 15) 0           conv2d_15[0][0]
#                                                                  conv2d_20[0][0]
#                                                                  conv2d_28[0][0]
#                                                                  conv2d_36[0][0]
#                                                                  conv2d_44[0][0]
# __________________________________________________________________________________________________
# conv2d_45 (Conv2D)              (None, 160, 160, 32) 7712        concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_46 (Conv2D)              (None, 160, 160, 32) 16416       conv2d_45[0][0]
# __________________________________________________________________________________________________
# conv2d_47 (Conv2D)              (None, 160, 160, 3)  99          conv2d_46[0][0]
# ==================================================================================================
# Total params: 618,419
# Trainable params: 618,419
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model,to_file='model.png',show_shapes=True, show_layer_names=True)

# %%
def _tf_fspecial_gauss(size, sigma):
    """Function to mimic the 'fspecial' gaussian MATLAB function
    """
    x_data, y_data = np.mgrid[-size//2 + 1:size//2 + 1, -size//2 + 1:size//2 + 1]

    x_data = np.expand_dims(x_data, axis=-1)
    x_data = np.expand_dims(x_data, axis=-1)

    y_data = np.expand_dims(y_data, axis=-1)
    y_data = np.expand_dims(y_data, axis=-1)

    x = tf.constant(x_data, dtype=tf.float32)
    y = tf.constant(y_data, dtype=tf.float32)

    g = tf.exp(-((x**2 + y**2)/(2.0*sigma**2)))
    return g / tf.reduce_sum(g)

def tf_ssim(img1, img2, cs_map=False, mean_metric=True, size=11, sigma=1.5):
    window = _tf_fspecial_gauss(size, sigma) # window shape [size, size]
    K1 = 0.01
    K2 = 0.03
    L = 1  # depth of image (255 in case the image has a differnt scale)
    C1 = (K1*L)**2
    C2 = (K2*L)**2
    mu1 = tf.nn.conv2d(img1, window, strides=[1,1,1,1], padding='VALID')
    mu2 = tf.nn.conv2d(img2, window, strides=[1,1,1,1],padding='VALID')
    mu1_sq = mu1*mu1
    mu2_sq = mu2*mu2
    mu1_mu2 = mu1*mu2
    sigma1_sq = tf.nn.conv2d(img1*img1, window, strides=[1,1,1,1],padding='VALID') - mu1_sq
    sigma2_sq = tf.nn.conv2d(img2*img2, window, strides=[1,1,1,1],padding='VALID') - mu2_sq
    sigma12 = tf.nn.conv2d(img1*img2, window, strides=[1,1,1,1],padding='VALID') - mu1_mu2
    if cs_map:
        value = (((2*mu1_mu2 + C1)*(2*sigma12 + C2))/((mu1_sq + mu2_sq + C1)*
                            (sigma1_sq + sigma2_sq + C2)),
                        (2.0*sigma12 + C2)/(sigma1_sq + sigma2_sq + C2))
    else:
        value = ((2*mu1_mu2 + C1)*(2*sigma12 + C2))/((mu1_sq + mu2_sq + C1)*
                            (sigma1_sq + sigma2_sq + C2))

    if mean_metric:
        value = tf.reduce_mean(value)
    return value

def ssim(y_true, y_pred):
    return tf_ssim(tf.expand_dims(y_pred[:, :, :, 0], -1),tf.expand_dims(y_true[:, :, :, 0], -1)) + tf_ssim(
                tf.expand_dims(y_pred[:, :, :, 1], -1), tf.expand_dims(y_true[:, :, :, 1], -1)) + tf_ssim(
                tf.expand_dims(y_pred[:, :, :, 2], -1), tf.expand_dims(y_true[:, :, :, 2], -1))

def my_loss(y_true, y_pred):
    MAE_loss = K.mean(K.abs(y_pred - y_true))
    SSIM_loss = tf_ssim(tf.expand_dims(y_pred[:, :, :, 0], -1),tf.expand_dims(y_true[:, :, :, 0], -1)) + tf_ssim(
                tf.expand_dims(y_pred[:, :, :, 1], -1), tf.expand_dims(y_true[:, :, :, 1], -1)) + tf_ssim(
                tf.expand_dims(y_pred[:, :, :, 2], -1), tf.expand_dims(y_true[:, :, :, 2], -1))

    percent = 0.4
    index = int(h * w * percent - 1)
    gray1 = 0.29 * y_pred[:, :, :, 0] + 0.58 * y_pred[:, :, :, 1] + 0.11 * y_pred[:, :, :, 2]
    gray = tf.reshape(gray1, [-1, h * w])
    gray_sort = tf.nn.top_k(-gray, h * w)[0]
    yu = gray_sort[:, index]
    yu = tf.expand_dims(tf.expand_dims(yu, -1), -1)
    mask = tf.cast(gray1 <= yu,tf.float32)
    mask1 = tf.expand_dims(mask, -1)
    mask = tf.concat([mask1, mask1, mask1], -1)

    low_fake_clean = tf.multiply(mask, y_pred[:, :, :, :3])
    high_fake_clean = tf.multiply(1 - mask, y_pred[:, :, :, :3])
    low_clean = tf.multiply(mask, y_true[:, :, :, :])
    high_clean = tf.multiply(1 - mask, y_true[:, :, :, :])
    Region_loss = K.mean(K.abs(low_fake_clean - low_clean) * 4 + K.abs(high_fake_clean - high_clean))

    loss = MAE_loss + 3 - SSIM_loss + Region_loss
    
    return loss

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

checkpoint=ModelCheckpoint('models/new.h5',
                            monitor='val_loss',
                            mode='min',
                            save_best_only=True,
                            verbose=1
                          )
earlystop=EarlyStopping(monitor='val_loss',
                        patience=10,
                        min_delta=0,
                        restore_best_weights=True,
                        verbose=1
                       )
reduce_lr=ReduceLROnPlateau(monitor='val_loss',
                            factor=0.2,
                            patience=10,
                            min_delta=0.001,
                            verbose=1
                           )
callbacks=[checkpoint, earlystop, reduce_lr]

METRICS=[
    keras.metrics.MeanSquaredError(name='mse'),
    ssim,
    'accuracy'
]
model.compile(loss=my_loss,
              optimizer=keras.optimizers.Adam(learning_rate=0.0005),
              metrics=METRICS
             )

history=model.fit(
    x=x_train,
    y=y_train,
    batch_size=32,
    shuffle=True,
    epochs=100,
    validation_data=(x_test, y_test),
    callbacks=callbacks
    )
# Out:
# Epoch 1/100
# 16/16 [==============================] - ETA: 0s - loss: 2.1331 - mse: 0.0466 - ssim: 1.2362 - accuracy: 0.4555
# Epoch 00001: val_loss improved from inf to 1.85970, saving model to models\new.h5
# 16/16 [==============================] - 739s 46s/step - loss: 2.1331 - mse: 0.0466 - ssim: 1.2362 - accuracy: 0.4555 - val_loss: 1.8597 - val_mse: 0.0338 - val_ssim: 1.4382 - val_accuracy: 0.1270
# Epoch 2/100
# 16/16 [==============================] - ETA: 0s - loss: 1.5913 - mse: 0.0348 - ssim: 1.7162 - accuracy: 0.3937
# Epoch 00002: val_loss improved from 1.85970 to 1.45206, saving model to models\new.h5
# 16/16 [==============================] - 679s 42s/step - loss: 1.5913 - mse: 0.0348 - ssim: 1.7162 - accuracy: 0.3937 - val_loss: 1.4521 - val_mse: 0.0268 - val_ssim: 1.8052 - val_accuracy: 0.4879
# Epoch 3/100
# 16/16 [==============================] - ETA: 0s - loss: 1.3241 - mse: 0.0304 - ssim: 1.9571 - accuracy: 0.5107
# Epoch 00003: val_loss improved from 1.45206 to 1.29263, saving model to models\new.h5
# 16/16 [==============================] - 629s 39s/step - loss: 1.3241 - mse: 0.0304 - ssim: 1.9571 - accuracy: 0.5107 - val_loss: 1.2926 - val_mse: 0.0243 - val_ssim: 1.9526 - val_accuracy: 0.3004
# Epoch 4/100
# 16/16 [==============================] - ETA: 0s - loss: 1.1842 - mse: 0.0272 - ssim: 2.0760 - accuracy: 0.5218
# Epoch 00004: val_loss improved from 1.29263 to 1.23073, saving model to models\new.h5
# 16/16 [==============================] - 624s 39s/step - loss: 1.1842 - mse: 0.0272 - ssim: 2.0760 - accuracy: 0.5218 - val_loss: 1.2307 - val_mse: 0.0261 - val_ssim: 2.0268 - val_accuracy: 0.5510
# Epoch 5/100
# 16/16 [==============================] - ETA: 0s - loss: 1.1344 - mse: 0.0271 - ssim: 2.1281 - accuracy: 0.5438
# Epoch 00005: val_loss improved from 1.23073 to 1.13116, saving model to models\new.h5
# 16/16 [==============================] - 634s 40s/step - loss: 1.1344 - mse: 0.0271 - ssim: 2.1281 - accuracy: 0.5438 - val_loss: 1.1312 - val_mse: 0.0216 - val_ssim: 2.0984 - val_accuracy: 0.3633
# Epoch 6/100
# 16/16 [==============================] - ETA: 0s - loss: 1.1129 - mse: 0.0290 - ssim: 2.1532 - accuracy: 0.5190
# Epoch 00006: val_loss improved from 1.13116 to 1.13009, saving model to models\new.h5
# 16/16 [==============================] - 665s 42s/step - loss: 1.1129 - mse: 0.0290 - ssim: 2.1532 - accuracy: 0.5190 - val_loss: 1.1301 - val_mse: 0.0230 - val_ssim: 2.1105 - val_accuracy: 0.5429
# Epoch 7/100
# 16/16 [==============================] - ETA: 0s - loss: 1.0613 - mse: 0.0258 - ssim: 2.1992 - accuracy: 0.5367
# Epoch 00007: val_loss improved from 1.13009 to 1.11046, saving model to models\new.h5
# 16/16 [==============================] - 682s 43s/step - loss: 1.0613 - mse: 0.0258 - ssim: 2.1992 - accuracy: 0.5367 - val_loss: 1.1105 - val_mse: 0.0239 - val_ssim: 2.1370 - val_accuracy: 0.2998
# Epoch 8/100
# 16/16 [==============================] - ETA: 0s - loss: 1.0370 - mse: 0.0258 - ssim: 2.2253 - accuracy: 0.4932
# Epoch 00008: val_loss improved from 1.11046 to 1.04794, saving model to models\new.h5
# 16/16 [==============================] - 697s 44s/step - loss: 1.0370 - mse: 0.0258 - ssim: 2.2253 - accuracy: 0.4932 - val_loss: 1.0479 - val_mse: 0.0211 - val_ssim: 2.1792 - val_accuracy: 0.5534
# Epoch 9/100
# 16/16 [==============================] - ETA: 0s - loss: 1.0002 - mse: 0.0245 - ssim: 2.2496 - accuracy: 0.6190
# Epoch 00009: val_loss improved from 1.04794 to 1.00334, saving model to models\new.h5
# 16/16 [==============================] - 683s 43s/step - loss: 1.0002 - mse: 0.0245 - ssim: 2.2496 - accuracy: 0.6190 - val_loss: 1.0033 - val_mse: 0.0190 - val_ssim: 2.2131 - val_accuracy: 0.6094
# Epoch 10/100
# 16/16 [==============================] - ETA: 0s - loss: 0.9587 - mse: 0.0232 - ssim: 2.2789 - accuracy: 0.6291
# Epoch 00010: val_loss improved from 1.00334 to 0.98242, saving model to models\new.h5
# 16/16 [==============================] - 680s 42s/step - loss: 0.9587 - mse: 0.0232 - ssim: 2.2789 - accuracy: 0.6291 - val_loss: 0.9824 - val_mse: 0.0188 - val_ssim: 2.2348 - val_accuracy: 0.6097
# Epoch 11/100
# 16/16 [==============================] - ETA: 0s - loss: 0.9474 - mse: 0.0229 - ssim: 2.2860 - accuracy: 0.6359
# Epoch 00011: val_loss improved from 0.98242 to 0.95460, saving model to models\new.h5
# 16/16 [==============================] - 716s 45s/step - loss: 0.9474 - mse: 0.0229 - ssim: 2.2860 - accuracy: 0.6359 - val_loss: 0.9546 - val_mse: 0.0180 - val_ssim: 2.2578 - val_accuracy: 0.6445
# Epoch 12/100
# 16/16 [==============================] - ETA: 0s - loss: 0.9543 - mse: 0.0243 - ssim: 2.2866 - accuracy: 0.6330
# Epoch 00012: val_loss did not improve from 0.95460
# 16/16 [==============================] - 881s 55s/step - loss: 0.9543 - mse: 0.0243 - ssim: 2.2866 - accuracy: 0.6330 - val_loss: 0.9645 - val_mse: 0.0193 - val_ssim: 2.2581 - val_accuracy: 0.5716
# Epoch 13/100
# 16/16 [==============================] - ETA: 0s - loss: 0.9229 - mse: 0.0225 - ssim: 2.3166 - accuracy: 0.6351
# Epoch 00013: val_loss improved from 0.95460 to 0.94866, saving model to models\new.h5
# 16/16 [==============================] - 876s 55s/step - loss: 0.9229 - mse: 0.0225 - ssim: 2.3166 - accuracy: 0.6351 - val_loss: 0.9487 - val_mse: 0.0190 - val_ssim: 2.2708 - val_accuracy: 0.6673
# Epoch 14/100
# 16/16 [==============================] - ETA: 0s - loss: 0.9028 - mse: 0.0223 - ssim: 2.3318 - accuracy: 0.6559
# Epoch 00014: val_loss improved from 0.94866 to 0.93875, saving model to models\new.h5
# 16/16 [==============================] - 868s 54s/step - loss: 0.9028 - mse: 0.0223 - ssim: 2.3318 - accuracy: 0.6559 - val_loss: 0.9387 - val_mse: 0.0189 - val_ssim: 2.2810 - val_accuracy: 0.6119
# Epoch 15/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8973 - mse: 0.0224 - ssim: 2.3425 - accuracy: 0.6487
# Epoch 00015: val_loss improved from 0.93875 to 0.91811, saving model to models\new.h5
# 16/16 [==============================] - 863s 54s/step - loss: 0.8973 - mse: 0.0224 - ssim: 2.3425 - accuracy: 0.6487 - val_loss: 0.9181 - val_mse: 0.0181 - val_ssim: 2.2956 - val_accuracy: 0.7256
# Epoch 16/100
# 16/16 [==============================] - ETA: 0s - loss: 0.9024 - mse: 0.0232 - ssim: 2.3387 - accuracy: 0.6593
# Epoch 00016: val_loss improved from 0.91811 to 0.91556, saving model to models\new.h5
# 16/16 [==============================] - 880s 55s/step - loss: 0.9024 - mse: 0.0232 - ssim: 2.3387 - accuracy: 0.6593 - val_loss: 0.9156 - val_mse: 0.0184 - val_ssim: 2.3003 - val_accuracy: 0.5642
# Epoch 17/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8732 - mse: 0.0220 - ssim: 2.3650 - accuracy: 0.6383
# Epoch 00017: val_loss improved from 0.91556 to 0.89627, saving model to models\new.h5
# 16/16 [==============================] - 829s 52s/step - loss: 0.8732 - mse: 0.0220 - ssim: 2.3650 - accuracy: 0.6383 - val_loss: 0.8963 - val_mse: 0.0180 - val_ssim: 2.3166 - val_accuracy: 0.5117
# Epoch 18/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8577 - mse: 0.0211 - ssim: 2.3713 - accuracy: 0.6524
# Epoch 00018: val_loss improved from 0.89627 to 0.87600, saving model to models\new.h5
# 16/16 [==============================] - 721s 45s/step - loss: 0.8577 - mse: 0.0211 - ssim: 2.3713 - accuracy: 0.6524 - val_loss: 0.8760 - val_mse: 0.0167 - val_ssim: 2.3285 - val_accuracy: 0.7010
# Epoch 19/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8708 - mse: 0.0224 - ssim: 2.3652 - accuracy: 0.6607
# Epoch 00019: val_loss did not improve from 0.87600
# 16/16 [==============================] - 695s 43s/step - loss: 0.8708 - mse: 0.0224 - ssim: 2.3652 - accuracy: 0.6607 - val_loss: 0.9218 - val_mse: 0.0196 - val_ssim: 2.3031 - val_accuracy: 0.6166
# Epoch 20/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8642 - mse: 0.0222 - ssim: 2.3717 - accuracy: 0.6754
# Epoch 00020: val_loss did not improve from 0.87600
# 16/16 [==============================] - 629s 39s/step - loss: 0.8642 - mse: 0.0222 - ssim: 2.3717 - accuracy: 0.6754 - val_loss: 0.9050 - val_mse: 0.0196 - val_ssim: 2.3183 - val_accuracy: 0.6487
# Epoch 21/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8400 - mse: 0.0209 - ssim: 2.3835 - accuracy: 0.6819
# Epoch 00021: val_loss improved from 0.87600 to 0.86400, saving model to models\new.h5
# 16/16 [==============================] - 627s 39s/step - loss: 0.8400 - mse: 0.0209 - ssim: 2.3835 - accuracy: 0.6819 - val_loss: 0.8640 - val_mse: 0.0171 - val_ssim: 2.3438 - val_accuracy: 0.5967
# Epoch 22/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8471 - mse: 0.0216 - ssim: 2.3836 - accuracy: 0.6706
# Epoch 00022: val_loss did not improve from 0.86400
# 16/16 [==============================] - 627s 39s/step - loss: 0.8471 - mse: 0.0216 - ssim: 2.3836 - accuracy: 0.6706 - val_loss: 0.8692 - val_mse: 0.0180 - val_ssim: 2.3450 - val_accuracy: 0.6771
# Epoch 23/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8512 - mse: 0.0226 - ssim: 2.3821 - accuracy: 0.6518
# Epoch 00023: val_loss did not improve from 0.86400
# 16/16 [==============================] - 694s 43s/step - loss: 0.8512 - mse: 0.0226 - ssim: 2.3821 - accuracy: 0.6518 - val_loss: 0.8698 - val_mse: 0.0175 - val_ssim: 2.3400 - val_accuracy: 0.6645
# Epoch 24/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8406 - mse: 0.0214 - ssim: 2.3935 - accuracy: 0.6492
# Epoch 00024: val_loss improved from 0.86400 to 0.85725, saving model to models\new.h5
# 16/16 [==============================] - 628s 39s/step - loss: 0.8406 - mse: 0.0214 - ssim: 2.3935 - accuracy: 0.6492 - val_loss: 0.8573 - val_mse: 0.0178 - val_ssim: 2.3559 - val_accuracy: 0.6607
# Epoch 25/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8262 - mse: 0.0205 - ssim: 2.4067 - accuracy: 0.6556
# Epoch 00025: val_loss improved from 0.85725 to 0.83219, saving model to models\new.h5
# 16/16 [==============================] - 631s 39s/step - loss: 0.8262 - mse: 0.0205 - ssim: 2.4067 - accuracy: 0.6556 - val_loss: 0.8322 - val_mse: 0.0164 - val_ssim: 2.3703 - val_accuracy: 0.6949
# Epoch 26/100
# 16/16 [==============================] - ETA: 0s - loss: 0.8163 - mse: 0.0212 - ssim: 2.4154 - accuracy: 0.6870
# Epoch 00026: val_loss did not improve from 0.83219
# 16/16 [==============================] - 685s 43s/step - loss: 0.8163 - mse: 0.0212 - ssim: 2.4154 - accuracy: 0.6870 - val_loss: 0.8765 - val_mse: 0.0186 - val_ssim: 2.3419 - val_accuracy: 0.6800
# Epoch 27/100
#  1/16 [>.............................] - ETA: 0s - loss: 0.8247 - mse: 0.0190 - ssim: 2.4010 - accuracy: 0.6607

# %%
plt.grid()

plt.plot(history.history['loss'],'--^r',label="loss")
plt.plot(history.history['accuracy'],'--^g',label='accuracy')
plt.plot(history.history['val_loss'],'-or',label='val_loss')
plt.plot(history.history['val_accuracy'],'-og',label='val_accuracy')
plt.legend()

# %%
def check_result(n):
    fig=plt.figure(figsize=(16,16))
    fig.add_subplot(1,2,1).imshow(y_test[n])
    fig.add_subplot(1,2,2).imshow(model.predict(x_test)[n])

# %%
for i in range(10):
    check_result(i)

# %%
def plot_hist(img,f):
#     if(f==0):
    img=cv2.cvtColor(np.array(img*255,dtype=np.uint8),cv2.COLOR_RGB2HSV)/255.
#         clahe=cv2.createCLAHE(clipLimit=3.0, tileGridSize=(2,2))
#         img[:,:,2]=clahe.apply(img[:,:,2])
#         img=cv2.cvtColor(img,cv2.COLOR_HSV2RGB)/255.
    h,s,v=cv2.split(img)
    fig=plt.figure(figsize=(16,16))
    fig.add_subplot(4,2,1).imshow(img)
    fig.add_subplot(4,2,2).hist(img.ravel(), bins=256, range=(0.0, 1.0))
    #red
    fig.add_subplot(4,2,3).imshow(h)
    fig.add_subplot(4,2,4).hist(h.ravel(), bins=256, range=(0.0, 1.0))
    #green
    fig.add_subplot(4,2,5).imshow(s)
    fig.add_subplot(4,2,6).hist(s.ravel(), bins=256, range=(0.0, 1.0))
    #blue
#     v=np.power(v,1/3)
    fig.add_subplot(4,2,7).imshow(v)
    fig.add_subplot(4,2,8).hist(v.ravel(), bins=256, range=(0.0, 1.0))

# %%
plot_hist(x_test[1],1)

# %%
plot_hist(y_test[1],1)

# %%
plot_hist(model.predict(x_test)[1],1)
