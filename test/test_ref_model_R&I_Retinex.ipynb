# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import math
import tensorflow as tf
import keras
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array

# %%
h, w = 160, 160

x_train=[]
y_train=[]
x_test=[]
y_test=[]

path_train_low='../../dataSets/ref/our485/low/'
path_train_high='../../dataSets/ref/our485/high/'
path_test_low='../../dataSets/ref/eval15/low/'
path_test_high='../../dataSets/ref/eval15/high/'

print('\nLoding Train dataset :')
i=0;
for img in os.listdir(path_train_low):
    img_low_path=os.path.join(path_train_low, img)
    img_high_path=os.path.join(path_train_high, img)
    
    img_low=load_img(img_low_path, target_size=(h,w))
    img_low=img_to_array(img_low)/255.
       
    i=i+1
    print("{:.2f}".format(i/4.89)+' %',end='\r')
    
    img_high=load_img(img_high_path, target_size=(h,w))
    img_high=img_to_array(img_high)/255.
    
    x_train.append(img_low)
    y_train.append(np.concatenate((img_low, img_high), axis=2))
    
print('\nLoding Test dataset :')
i=0;
for img in os.listdir(path_test_low):
    img_low_path=os.path.join(path_test_low, img)
    img_high_path=os.path.join(path_test_high, img)
    
    img_low=load_img(img_low_path, target_size=(h,w))
    img_low=img_to_array(img_low)/255.
   
    i=i+1
    print("{:.2f}".format(i/0.14)+' %',end='\r')
    
    img_high=load_img(img_high_path, target_size=(h,w))
    img_high=img_to_array(img_high)/255.
    
    x_test.append(img_low)
    y_test.append(np.concatenate((img_low, img_high), axis=2))

x_train=np.array(x_train, dtype="float32")
y_train=np.array(y_train, dtype="float32")

x_test=np.array(x_test, dtype="float32")
y_test=np.array(y_test, dtype="float32")
# Out:
# Loding Train dataset :
# 100.00 %
# Loding Test dataset :
# 100.00 %

# %%
fig=plt.figure()

f=fig.add_subplot(1,2,1)
s=fig.add_subplot(1,2,2)

f.imshow(x_test[1])
s.imshow(y_test[1][:,:,:3])

# %%
def _tf_fspecial_gauss(size, sigma):
    """Function to mimic the 'fspecial' gaussian MATLAB function
    """
    x_data, y_data = np.mgrid[-size//2 + 1:size//2 + 1, -size//2 + 1:size//2 + 1]

    x_data = np.expand_dims(x_data, axis=-1)
    x_data = np.expand_dims(x_data, axis=-1)

    y_data = np.expand_dims(y_data, axis=-1)
    y_data = np.expand_dims(y_data, axis=-1)

    x = tf.constant(x_data, dtype=tf.float32)
    y = tf.constant(y_data, dtype=tf.float32)

    g = tf.exp(-((x**2 + y**2)/(2.0*sigma**2)))
    return g / tf.reduce_sum(g)

def tf_ssim(img1, img2, cs_map=False, mean_metric=True, size=11, sigma=1.5):
    window = _tf_fspecial_gauss(size, sigma) # window shape [size, size]
    K1 = 0.01
    K2 = 0.03
    L = 1  # depth of image (255 in case the image has a differnt scale)
    C1 = (K1*L)**2
    C2 = (K2*L)**2
    mu1 = tf.nn.conv2d(img1, window, strides=[1,1,1,1], padding='VALID')
    mu2 = tf.nn.conv2d(img2, window, strides=[1,1,1,1],padding='VALID')
    mu1_sq = mu1*mu1
    mu2_sq = mu2*mu2
    mu1_mu2 = mu1*mu2
    sigma1_sq = tf.nn.conv2d(img1*img1, window, strides=[1,1,1,1],padding='VALID') - mu1_sq
    sigma2_sq = tf.nn.conv2d(img2*img2, window, strides=[1,1,1,1],padding='VALID') - mu2_sq
    sigma12 = tf.nn.conv2d(img1*img2, window, strides=[1,1,1,1],padding='VALID') - mu1_mu2
    if cs_map:
        value = (((2*mu1_mu2 + C1)*(2*sigma12 + C2))/((mu1_sq + mu2_sq + C1)*
                            (sigma1_sq + sigma2_sq + C2)),
                        (2.0*sigma12 + C2)/(sigma1_sq + sigma2_sq + C2))
    else:
        value = ((2*mu1_mu2 + C1)*(2*sigma12 + C2))/((mu1_sq + mu2_sq + C1)*
                            (sigma1_sq + sigma2_sq + C2))

    if mean_metric:
        value = tf.reduce_mean(value)
    return value

def ssim(y_true, y_pred):
    I = tf.concat([y_pred[:, :, :, 3:], y_pred[:, :, :, 3:], y_pred[:, :, :, 3:]], axis=3)
    R = y_pred[:, :, :, :3]
    S = R*I
    return tf_ssim(tf.expand_dims(S[:, :, :, 0], -1),tf.expand_dims(y_true[:, :, :, 0], -1)) + tf_ssim(
                tf.expand_dims(S[:, :, :, 1], -1), tf.expand_dims(y_true[:, :, :, 1], -1)) + tf_ssim(
                tf.expand_dims(S[:, :, :, 2], -1), tf.expand_dims(y_true[:, :, :, 2], -1))

def my_loss(y_true, y_pred):
    I = tf.concat([y_pred[:, :, :, 3:], y_pred[:, :, :, 3:], y_pred[:, :, :, 3:]], axis=3)
    R = y_pred[:, :, :, :3]
    S = R*I
    
    y_tp = model(y_true[:, :, :, 3:])
    
    MAE_loss = K.mean(K.abs(S - y_true[:, :, :, :3])) + K.mean(K.abs(y_pred[:, :, :, :3] - y_tp[:, :, :, :3]))
    
    SSIM_loss =  tf_ssim(tf.expand_dims(S[:, :, :, 0], -1),tf.expand_dims(y_true[:, :, :, 0], -1)) + tf_ssim(
                  tf.expand_dims(S[:, :, :, 1], -1), tf.expand_dims(y_true[:, :, :, 1], -1)) + tf_ssim(
                  tf.expand_dims(S[:, :, :, 2], -1), tf.expand_dims(y_true[:, :, :, 2], -1))
#                  +
#                   tf_ssim(tf.expand_dims(y_pred[:, :, :, 0], -1),tf.expand_dims(y_tp[:, :, :, 0], -1)) + tf_ssim(
#                   tf.expand_dims(y_pred[:, :, :, 1], -1), tf.expand_dims(y_tp[:, :, :, 1], -1)) + tf_ssim(
#                   tf.expand_dims(y_pred[:, :, :, 2], -1), tf.expand_dims(y_tp[:, :, :, 2], -1))
#                 )/2

    percent = 0.4
    index = int(h * w * percent - 1)
    gray1 = 0.39 * S[:, :, :, 0] + 0.5 * S[:, :, :, 1] + 0.11 * S[:, :, :, 2]
    gray = tf.reshape(gray1, [-1, h * w])
    gray_sort = tf.nn.top_k(-gray, h * w)[0]
    yu = gray_sort[:, index]
    yu = tf.expand_dims(tf.expand_dims(yu, -1), -1)
    mask = tf.cast(gray1 <= yu,tf.float32)
    mask1 = tf.expand_dims(mask, -1)
    mask = tf.concat([mask1, mask1, mask1], -1)

    low_fake_clean = tf.multiply(mask, S[:, :, :, :3])
    high_fake_clean = tf.multiply(1 - mask, S[:, :, :, :3])
    low_clean = tf.multiply(mask, y_true[:, :, :, :3])
    high_clean = tf.multiply(1 - mask, y_true[:, :, :, :3])
    Region_loss = K.mean(K.abs(low_fake_clean - low_clean) * 4 + K.abs(high_fake_clean - high_clean))

    loss = MAE_loss + 3 - SSIM_loss + Region_loss
    
    return loss

def acc(y_true, y_pred):
    I = tf.concat([y_pred[:, :, :, 3:], y_pred[:, :, :, 3:], y_pred[:, :, :, 3:]], axis=3)
    R = y_pred[:, :, :, :3]
    S = R*I
    m = keras.metrics.CategoricalAccuracy()
    m.update_state(y_true[:, :, :, :3], S)
    return m.result().numpy()

def mse_S(y_true, y_pred):
    I = tf.concat([y_pred[:, :, :, 3:], y_pred[:, :, :, 3:], y_pred[:, :, :, 3:]], axis=3)
    R = y_pred[:, :, :, :3]
    S = R*I
    return K.mean(K.abs(S - y_true[:, :, :, :3]))

def mse_R(y_true, y_pred):
    y_tp = model(y_true[:, :, :, 3:])
    return K.mean(K.abs(y_pred[:, :, :, :3] - y_tp[:, :, :, :3]))

# %%
from keras.models import Model
from keras.models import Sequential
from keras.layers import Input,add,Conv2D,MaxPooling2D,UpSampling2D,Flatten,Dropout,Dense,BatchNormalization,Reshape,UpSampling2D,Conv2DTranspose,Concatenate,Lambda

def InstantiateModel(in_):
    channel = 32
    kernel_size = (3, 3)
    
    in_max = tf.reduce_max(in_, axis=3, keepdims=True)
    in_ = Concatenate()([in_max, in_])
    
    conv = Conv2D(channel, kernel_size, padding='same', activation=None)(in_)
    for i in range(4):
        conv = Conv2D(channel, kernel_size, padding='same', activation='relu')(conv)
    conv = Conv2D(4, kernel_size, padding='same', activation='sigmoid')(conv)
    
    return conv

# %%
Input_Sample = Input(shape=(h, w, 3))
Output_ = InstantiateModel(Input_Sample)
model = Model(inputs=Input_Sample, outputs=Output_)
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# tf_op_layer_Max (TensorFlowOpLa [(None, 160, 160, 1) 0           input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 160, 160, 4)  0           tf_op_layer_Max[0][0]
#                                                                  input_1[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 160, 160, 32) 1184        concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 160, 160, 32) 9248        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 160, 160, 32) 9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 160, 160, 32) 9248        conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 160, 160, 32) 9248        conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 160, 160, 4)  1156        conv2d_4[0][0]
# ==================================================================================================
# Total params: 39,332
# Trainable params: 39,332
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model,to_file='model.png',show_shapes=True, show_layer_names=True)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

checkpoint=ModelCheckpoint('models/R&I_Retinex.h5',
                            monitor='val_loss',
                            mode='min',
                            save_best_only=True,
                            verbose=1
                          )
earlystop=EarlyStopping(monitor='val_loss',
                        patience=6,
                        min_delta=0,
                        restore_best_weights=True,
                        verbose=1
                       )
reduce_lr=ReduceLROnPlateau(monitor='val_loss',
                            factor=0.2,
                            patience=6,
                            min_delta=0.001,
                            verbose=1
                           )

callbacks=[checkpoint,earlystop,reduce_lr]

METRICS=[
    mse_S,
    mse_R,
    ssim,
    acc
]
model.compile(loss=my_loss,
              optimizer=keras.optimizers.Adam(learning_rate=0.001),
              metrics=METRICS,
              run_eagerly=True
             )

history=model.fit(
    x=x_train,
    y=y_train,
    batch_size=16,
    shuffle=True,
    epochs=100,
    validation_data=(x_test, y_test),
    callbacks=callbacks
    )
# Out:
# Epoch 1/100
# 31/31 [==============================] - ETA: 0s - loss: 1.8031 - mse_S: 0.1062 - mse_R: 0.0729 - ssim: 1.4943 - acc: 0.2655
# Epoch 00001: val_loss improved from inf to 0.65538, saving model to models\R&I_Retinex.h5
# 31/31 [==============================] - 308s 10s/step - loss: 1.8031 - mse_S: 0.1062 - mse_R: 0.0729 - ssim: 1.4943 - acc: 0.2655 - val_loss: 0.6554 - val_mse_S: 0.0243 - val_mse_R: 0.0879 - val_ssim: 2.4811 - val_acc: 0.4302
# Epoch 2/100
# 31/31 [==============================] - ETA: 0s - loss: 0.5478 - mse_S: 0.0201 - mse_R: 0.0648 - ssim: 2.5589 - acc: 0.3907
# Epoch 00002: val_loss improved from 0.65538 to 0.40469, saving model to models\R&I_Retinex.h5
# 31/31 [==============================] - 307s 10s/step - loss: 0.5478 - mse_S: 0.0201 - mse_R: 0.0648 - ssim: 2.5589 - acc: 0.3907 - val_loss: 0.4047 - val_mse_S: 0.0147 - val_mse_R: 0.0320 - val_ssim: 2.6567 - val_acc: 0.4160
# Epoch 3/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3841 - mse_S: 0.0159 - mse_R: 0.0186 - ssim: 2.6671 - acc: 0.4543
# Epoch 00003: val_loss improved from 0.40469 to 0.32845, saving model to models\R&I_Retinex.h5
# 31/31 [==============================] - 307s 10s/step - loss: 0.3841 - mse_S: 0.0159 - mse_R: 0.0186 - ssim: 2.6671 - acc: 0.4543 - val_loss: 0.3285 - val_mse_S: 0.0143 - val_mse_R: 0.0152 - val_ssim: 2.7152 - val_acc: 0.4262
# Epoch 4/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3270 - mse_S: 0.0148 - mse_R: 0.0131 - ssim: 2.7154 - acc: 0.4699
# Epoch 00004: val_loss improved from 0.32845 to 0.27608, saving model to models\R&I_Retinex.h5
# 31/31 [==============================] - 307s 10s/step - loss: 0.3270 - mse_S: 0.0148 - mse_R: 0.0131 - ssim: 2.7154 - acc: 0.4699 - val_loss: 0.2761 - val_mse_S: 0.0121 - val_mse_R: 0.0118 - val_ssim: 2.7599 - val_acc: 0.3879
# Epoch 5/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2954 - mse_S: 0.0141 - mse_R: 0.0133 - ssim: 2.7449 - acc: 0.4478
# Epoch 00005: val_loss improved from 0.27608 to 0.26045, saving model to models\R&I_Retinex.h5
# 31/31 [==============================] - 307s 10s/step - loss: 0.2954 - mse_S: 0.0141 - mse_R: 0.0133 - ssim: 2.7449 - acc: 0.4478 - val_loss: 0.2604 - val_mse_S: 0.0122 - val_mse_R: 0.0130 - val_ssim: 2.7769 - val_acc: 0.4289
# Epoch 6/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2710 - mse_S: 0.0134 - mse_R: 0.0124 - ssim: 2.7686 - acc: 0.4967
# Epoch 00006: val_loss improved from 0.26045 to 0.24146, saving model to models\R&I_Retinex.h5
# 31/31 [==============================] - 308s 10s/step - loss: 0.2710 - mse_S: 0.0134 - mse_R: 0.0124 - ssim: 2.7686 - acc: 0.4967 - val_loss: 0.2415 - val_mse_S: 0.0115 - val_mse_R: 0.0161 - val_ssim: 2.7975 - val_acc: 0.4364
# Epoch 7/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2408 - mse_S: 0.0117 - mse_R: 0.0215 - ssim: 2.8024 - acc: 0.5669
# Epoch 00007: val_loss improved from 0.24146 to 0.22655, saving model to models\R&I_Retinex.h5
# 31/31 [==============================] - 309s 10s/step - loss: 0.2408 - mse_S: 0.0117 - mse_R: 0.0215 - ssim: 2.8024 - acc: 0.5669 - val_loss: 0.2265 - val_mse_S: 0.0107 - val_mse_R: 0.0319 - val_ssim: 2.8267 - val_acc: 0.5605
# Epoch 8/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2021 - mse_S: 0.0100 - mse_R: 0.0346 - ssim: 2.8507 - acc: 0.6425
# Epoch 00008: val_loss improved from 0.22655 to 0.18203, saving model to models\R&I_Retinex.h5
# 31/31 [==============================] - 307s 10s/step - loss: 0.2021 - mse_S: 0.0100 - mse_R: 0.0346 - ssim: 2.8507 - acc: 0.6425 - val_loss: 0.1820 - val_mse_S: 0.0089 - val_mse_R: 0.0334 - val_ssim: 2.8692 - val_acc: 0.5816
# Epoch 9/100
# 31/31 [==============================] - ETA: 0s - loss: 0.1913 - mse_S: 0.0095 - mse_R: 0.0389 - ssim: 2.8665 - acc: 0.6496
# Epoch 00009: val_loss improved from 0.18203 to 0.16304, saving model to models\R&I_Retinex.h5
# 31/31 [==============================] - 307s 10s/step - loss: 0.1913 - mse_S: 0.0095 - mse_R: 0.0389 - ssim: 2.8665 - acc: 0.6496 - val_loss: 0.1630 - val_mse_S: 0.0077 - val_mse_R: 0.0307 - val_ssim: 2.8830 - val_acc: 0.5659
# Epoch 10/100
# 31/31 [==============================] - ETA: 0s - loss: 0.1789 - mse_S: 0.0090 - mse_R: 0.0370 - ssim: 2.8746 - acc: 0.6475
# Epoch 00010: val_loss did not improve from 0.16304
# 31/31 [==============================] - 336s 11s/step - loss: 0.1789 - mse_S: 0.0090 - mse_R: 0.0370 - ssim: 2.8746 - acc: 0.6475 - val_loss: 0.1756 - val_mse_S: 0.0073 - val_mse_R: 0.0480 - val_ssim: 2.8870 - val_acc: 0.6075
# Epoch 11/100
# 31/31 [==============================] - ETA: 0s - loss: 0.1737 - mse_S: 0.0087 - mse_R: 0.0346 - ssim: 2.8776 - acc: 0.6550
# Epoch 00011: val_loss did not improve from 0.16304
# 31/31 [==============================] - 492s 16s/step - loss: 0.1737 - mse_S: 0.0087 - mse_R: 0.0346 - ssim: 2.8776 - acc: 0.6550 - val_loss: 0.1648 - val_mse_S: 0.0080 - val_mse_R: 0.0350 - val_ssim: 2.8862 - val_acc: 0.6104
# Epoch 12/100
# 31/31 [==============================] - ETA: 0s - loss: 0.1713 - mse_S: 0.0085 - mse_R: 0.0356 - ssim: 2.8811 - acc: 0.6705
# Epoch 00012: val_loss improved from 0.16304 to 0.14851, saving model to models\R&I_Retinex.h5
# 31/31 [==============================] - 493s 16s/step - loss: 0.1713 - mse_S: 0.0085 - mse_R: 0.0356 - ssim: 2.8811 - acc: 0.6705 - val_loss: 0.1485 - val_mse_S: 0.0063 - val_mse_R: 0.0333 - val_ssim: 2.8974 - val_acc: 0.6373
# Epoch 13/100
# 31/31 [==============================] - ETA: 0s - loss: 0.1643 - mse_S: 0.0081 - mse_R: 0.0336 - ssim: 2.8855 - acc: 0.6765
# Epoch 00013: val_loss did not improve from 0.14851
# 31/31 [==============================] - 492s 16s/step - loss: 0.1643 - mse_S: 0.0081 - mse_R: 0.0336 - ssim: 2.8855 - acc: 0.6765 - val_loss: 0.1617 - val_mse_S: 0.0068 - val_mse_R: 0.0436 - val_ssim: 2.8954 - val_acc: 0.6238
# Epoch 14/100
# 31/31 [==============================] - ETA: 0s - loss: 0.
100
# 31/31 [==============================] - ETA: 0s - loss: 0.1010 - mse_S: 0.0059 - mse_R: 0.0351 - ssim: 2.9463 - acc: 0.7954
# Epoch 00055: val_loss did not improve from 0.08556
# 31/31 [==============================] - 367s 12s/step - loss: 0.1010 - mse_S: 0.0059 - mse_R: 0.0351 - ssim: 2.9463 - acc: 0.7954 - val_loss: 0.0904 - val_mse_S: 0.0045 - val_mse_R: 0.0327 - val_ssim: 2.9514 - val_acc: 0.7794
# Epoch 56/100
# 31/31 [==============================] - ETA: 0s - loss: 0.1009 - mse_S: 0.0060 - mse_R: 0.0355 - ssim: 2.9462 - acc: 0.7952
# Epoch 00056: val_loss did not improve from 0.08556
# 31/31 [==============================] - 367s 12s/step - loss: 0.1009 - mse_S: 0.0060 - mse_R: 0.0355 - ssim: 2.9462 - acc: 0.7952 - val_loss: 0.0913 - val_mse_S: 0.0042 - val_mse_R: 0.0398 - val_ssim: 2.9570 - val_acc: 0.7696
# Epoch 57/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0982 - mse_S: 0.0057 - mse_R: 0.0348 - ssim: 2.9483 - acc: 0.7981
# Epoch 00057: val_loss improved from 0.08556 to 0.08548, saving model to models\R&I_Retinex.h5
# 31/31 [==============================] - 368s 12s/step - loss: 0.0982 - mse_S: 0.0057 - mse_R: 0.0348 - ssim: 2.9483 - acc: 0.7981 - val_loss: 0.0855 - val_mse_S: 0.0040 - val_mse_R: 0.0358 - val_ssim: 2.9584 - val_acc: 0.7701
# Epoch 58/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0962 - mse_S: 0.0056 - mse_R: 0.0349 - ssim: 2.9499 - acc: 0.8059
# Epoch 00058: val_loss improved from 0.08548 to 0.08405, saving model to models\R&I_Retinex.h5
# 31/31 [==============================] - 367s 12s/step - loss: 0.0962 - mse_S: 0.0056 - mse_R: 0.0349 - ssim: 2.9499 - acc: 0.8059 - val_loss: 0.0841 - val_mse_S: 0.0041 - val_mse_R: 0.0340 - val_ssim: 2.9582 - val_acc: 0.7874
# Epoch 59/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0968 - mse_S: 0.0057 - mse_R: 0.0351 - ssim: 2.9498 - acc: 0.8040
# Epoch 00059: val_loss improved from 0.08405 to 0.08230, saving model to models\R&I_Retinex.h5
# 31/31 [==============================] - 368s 12s/step - loss: 0.0968 - mse_S: 0.0057 - mse_R: 0.0351 - ssim: 2.9498 - acc: 0.8040 - val_loss: 0.0823 - val_mse_S: 0.0041 - val_mse_R: 0.0345 - val_ssim: 2.9604 - val_acc: 0.7760
# Epoch 60/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0977 - mse_S: 0.0058 - mse_R: 0.0354 - ssim: 2.9492 - acc: 0.8001
# Epoch 00060: val_loss did not improve from 0.08230
# 31/31 [==============================] - 366s 12s/step - loss: 0.0977 - mse_S: 0.0058 - mse_R: 0.0354 - ssim: 2.9492 - acc: 0.8001 - val_loss: 0.0830 - val_mse_S: 0.0043 - val_mse_R: 0.0345 - val_ssim: 2.9602 - val_acc: 0.7763
# Epoch 61/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0960 - mse_S: 0.0058 - mse_R: 0.0348 - ssim: 2.9499 - acc: 0.8017
# Epoch 00061: val_loss did not improve from 0.08230
# 31/31 [==============================] - 368s 12s/step - loss: 0.0960 - mse_S: 0.0058 - mse_R: 0.0348 - ssim: 2.9499 - acc: 0.8017 - val_loss: 0.0832 - val_mse_S: 0.0037 - val_mse_R: 0.0381 - val_ssim: 2.9623 - val_acc: 0.7929
# Epoch 62/100
# 31/31 [==============================] - ETA: 0s - loss: 0.
100
# 31/31 [==============================] - ETA: 0s - loss: 0.0906 - mse_S: 0.0055 - mse_R: 0.0341 - ssim: 2.9546 - acc: 0.8198
# Epoch 00069: val_loss did not improve from 0.07647
# 31/31 [==============================] - 453s 15s/step - loss: 0.0906 - mse_S: 0.0055 - mse_R: 0.0341 - ssim: 2.9546 - acc: 0.8198 - val_loss: 0.0779 - val_mse_S: 0.0041 - val_mse_R: 0.0351 - val_ssim: 2.9654 - val_acc: 0.7869
# Epoch 70/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0935 - mse_S: 0.0057 - mse_R: 0.0358 - ssim: 2.9538 - acc: 0.8209
# Epoch 00070: val_loss did not improve from 0.07647
# 31/31 [==============================] - 458s 15s/step - loss: 0.0935 - mse_S: 0.0057 - mse_R: 0.0358 - ssim: 2.9538 - acc: 0.8209 - val_loss: 0.0926 - val_mse_S: 0.0054 - val_mse_R: 0.0356 - val_ssim: 2.9539 - val_acc: 0.7923
# Epoch 71/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0899 - mse_S: 0.0055 - mse_R: 0.0347 - ssim: 2.9558 - acc: 0.8175
# Epoch 00071: val_loss did not improve from 0.07647
# 31/31 [==============================] - 454s 15s/step - loss: 0.0899 - mse_S: 0.0055 - mse_R: 0.0347 - ssim: 2.9558 - acc: 0.8175 - val_loss: 0.0811 - val_mse_S: 0.0038 - val_mse_R: 0.0390 - val_ssim: 2.9655 - val_acc: 0.7973
# Epoch 72/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0881 - mse_S: 0.0052 - mse_R: 0.0347 - ssim: 2.9575 - acc: 0.8206
# Epoch 00072: val_loss improved from 0.07647 to 0.07570, saving model to models\R&I_Retinex.h5
#
# Epoch 00072: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 31/31 [==============================] - 443s 14s/step - loss: 0.0881 - mse_S: 0.0052 - mse_R: 0.0347 - ssim: 2.9575 - acc: 0.8206 - val_loss: 0.0757 - val_mse_S: 0.0035 - val_mse_R: 0.0353 - val_ssim: 2.9667 - val_acc: 0.7989
# Epoch 73/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0844 - mse_S: 0.0050 - mse_R: 0.0333 - ssim: 2.9590 - acc: 0.8292
# Epoch 00073: val_loss improved from 0.07570 to 0.07288, saving model to models\R&I_Retinex.h5
# 31/31 [==============================] - 367s 12s/step - loss: 0.0844 - mse_S: 0.0050 - mse_R: 0.0333 - ssim: 2.9590 - acc: 0.8292 - val_loss: 0.0729 - val_mse_S: 0.0035 - val_mse_R: 0.0345 - val_ssim: 2.9686 - val_acc: 0.8138
# Epoch 74/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0838 - mse_S: 0.0049 - mse_R: 0.0337 - ssim: 2.9599 - acc: 0.8304
# Epoch 00074: val_loss improved from 0.07288 to 0.07219, saving model to models\R&I_Retinex.h5
# 31/31 [==============================] - 366s 12s/step - loss: 0.0838 - mse_S: 0.0049 - mse_R: 0.0337 - ssim: 2.9599 - acc: 0.8304 - val_loss: 0.0722 - val_mse_S: 0.0034 - val_mse_R: 0.0341 - val_ssim: 2.9687 - val_acc: 0.8100
# Epoch 75/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0836 - mse_S: 0.0049 - mse_R: 0.0334 - ssim: 2.9599 - acc: 0.8308
# Epoch 00075: val_loss did not improve from 0.07219
# 31/31 [==============================] - 367s 12s/step - loss: 0.0836 - mse_S: 0.0049 - mse_R: 0.0334 - ssim: 2.9599 - acc: 0.8308 - val_loss: 0.0746 - val_mse_S: 0.0036 - val_mse_R: 0.0358 - val_ssim: 2.9684 - val_acc: 0.8115
# Epoch 76/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0835 - mse_S: 0.0049 - mse_R: 0.0334 - ssim: 2.9599 - acc: 0.8304
# Epoch 00076: val_loss did not improve from 0.07219
# 31/31 [==============================] - 366s 12s/step - loss: 0.0835 - mse_S: 0.0049 - mse_R: 0.0334 - ssim: 2.9599 - acc: 0.8304 - val_loss: 0.0722 - val_mse_S: 0.0034 - val_mse_R: 0.0343 - val_ssim: 2.9689 - val_acc: 0.8145
# Epoch 77/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0834 - mse_S: 0.0050 - mse_R: 0.0335 - ssim: 2.9601 - acc: 0.8306
# Epoch 00077: val_loss improved from 0.07219 to 0.07096, saving model to models\R&I_Retinex.h5
# 31/31 [==============================] - 367s 12s/step - loss: 0.0834 - mse_S: 0.0050 - mse_R: 0.0335 - ssim: 2.9601 - acc: 0.8306 - val_loss: 0.0710 - val_mse_S: 0.0035 - val_mse_R: 0.0326 - val_ssim: 2.9687 - val_acc: 0.8082
# Epoch 78/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0838 - mse_S: 0.0050 - mse_R: 0.0338 - ssim: 2.9601 - acc: 0.8283
# Epoch 00078: val_loss did not improve from 0.07096
# 31/31 [==============================] - 367s 12s/step - loss: 0.0838 - mse_S: 0.0050 - mse_R: 0.0338 - ssim: 2.9601 - acc: 0.8283 - val_loss: 0.0724 - val_mse_S: 0.0036 - val_mse_R: 0.0334 - val_ssim: 2.9682 - val_acc: 0.8113
# Epoch 79/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0832 - mse_S: 0.0050 - mse_R: 0.0332 - ssim: 2.9601 - acc: 0.8311
# Epoch 00079: val_loss did not improve from 0.07096
# 31/31 [==============================] - 367s 12s/step - loss: 0.0832 - mse_S: 0.0050 - mse_R: 0.0332 - ssim: 2.9601 - acc: 0.8311 - val_loss: 0.0728 - val_mse_S: 0.0035 - val_mse_R: 0.0347 - val_ssim: 2.9690 - val_acc: 0.8010
# Epoch 80/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0831 - mse_S: 0.0049 - mse_R: 0.0335 - ssim: 2.9605 - acc: 0.8309
# Epoch 00080: val_loss did not improve from 0.07096
# 31/31 [==============================] - 367s 12s/step - loss: 0.0831 - mse_S: 0.0049 - mse_R: 0.0335 - ssim: 2.9605 - acc: 0.8309 - val_loss: 0.0710 - val_mse_S: 0.0034 - val_mse_R: 0.0338 - val_ssim: 2.9696 - val_acc: 0.8126
# Epoch 81/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0828 - mse_S: 0.0049 - mse_R: 0.0331 - ssim: 2.9604 - acc: 0.8317
# Epoch 00081: val_loss did not improve from 0.07096
# 31/31 [==============================] - 366s 12s/step - loss: 0.0828 - mse_S: 0.0049 - mse_R: 0.0331 - ssim: 2.9604 - acc: 0.8317 - val_loss: 0.0722 - val_mse_S: 0.0035 - val_mse_R: 0.0343 - val_ssim: 2.9690 - val_acc: 0.8162
# Epoch 82/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0829 - mse_S: 0.0049 - mse_R: 0.0336 - ssim: 2.9607 - acc: 0.8301
# Epoch 00082: val_loss improved from 0.07096 to 0.07096, saving model to models\R&I_Retinex.h5
# 31/31 [==============================] - 366s 12s/step - loss: 0.0829 - mse_S: 0.0049 - mse_R: 0.0336 - ssim: 2.9607 - acc: 0.8301 - val_loss: 0.0710 - val_mse_S: 0.0034 - val_mse_R: 0.0341 - val_ssim: 2.9699 - val_acc: 0.8193
# Epoch 83/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0827 - mse_S: 0.0049 - mse_R: 0.0334 - ssim: 2.9607 - acc: 0.8325
# Epoch 00083: val_loss improved from 0.07096 to 0.07087, saving model to models\R&I_Retinex.h5
#
# Epoch 00083: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 31/31 [==============================] - 368s 12s/step - loss: 0.0827 - mse_S: 0.0049 - mse_R: 0.0334 - ssim: 2.9607 - acc: 0.8325 - val_loss: 0.0709 - val_mse_S: 0.0034 - val_mse_R: 0.0335 - val_ssim: 2.9694 - val_acc: 0.8118
# Epoch 84/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0821 - mse_S: 0.0049 - mse_R: 0.0329 - ssim: 2.9608 - acc: 0.8346
# Epoch 00084: val_loss improved from 0.07087 to 0.07080, saving model to models\R&I_Retinex.h5
# 31/31 [==============================] - 366s 12s/step - loss: 0.0821 - mse_S: 0.0049 - mse_R: 0.0329 - ssim: 2.9608 - acc: 0.8346 - val_loss: 0.0708 - val_mse_S: 0.0034 - val_mse_R: 0.0341 - val_ssim: 2.9700 - val_acc: 0.8175
# Epoch 85/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0820 - mse_S: 0.0051 - mse_R: 0.0330 - ssim: 2.9602 - acc: 0.8353
# Epoch 00085: val_loss improved from 0.07080 to 0.07048, saving model to models\R&I_Retinex.h5
# 31/31 [==============================] - 367s 12s/step - loss: 0.0820 - mse_S: 0.0051 - mse_R: 0.0330 - ssim: 2.9602 - acc: 0.8353 - val_loss: 0.0705 - val_mse_S: 0.0034 - val_mse_R: 0.0333 - val_ssim: 2.9697 - val_acc: 0.8154
# Epoch 86/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0819 - mse_S: 0.0048 - mse_R: 0.0336 - ssim: 2.9614 - acc: 0.8353
# Epoch 00086: val_loss did not improve from 0.07048
# 31/31 [==============================] - 367s 12s/step - loss: 0.0819 - mse_S: 0.0048 - mse_R: 0.0336 - ssim: 2.9614 - acc: 0.8353 - val_loss: 0.0714 - val_mse_S: 0.0034 - val_mse_R: 0.0343 - val_ssim: 2.9698 - val_acc: 0.8178
# Epoch 87/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0818 - mse_S: 0.0051 - mse_R: 0.0331 - ssim: 2.9604 - acc: 0.8340
# Epoch 00087: val_loss did not improve from 0.07048
# 31/31 [==============================] - 367s 12s/step - loss: 0.0818 - mse_S: 0.0051 - mse_R: 0.0331 - ssim: 2.9604 - acc: 0.8340 - val_loss: 0.0709 - val_mse_S: 0.0034 - val_mse_R: 0.0342 - val_ssim: 2.9700 - val_acc: 0.8157
# Epoch 88/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0818 - mse_S: 0.0049 - mse_R: 0.0334 - ssim: 2.9612 - acc: 0.8347
# Epoch 00088: val_loss did not improve from 0.07048
# 31/31 [==============================] - 366s 12s/step - loss: 0.0818 - mse_S: 0.0049 - mse_R: 0.0334 - ssim: 2.9612 - acc: 0.8347 - val_loss: 0.0706 - val_mse_S: 0.0034 - val_mse_R: 0.0335 - val_ssim: 2.9697 - val_acc: 0.8143
# Epoch 89/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0818 - mse_S: 0.0049 - mse_R: 0.0330 - ssim: 2.9612 - acc: 0.8334
# Epoch 00089: val_loss did not improve from 0.07048
#
# Epoch 00089: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 31/31 [==============================] - 368s 12s/step - loss: 0.0818 - mse_S: 0.0049 - mse_R: 0.0330 - ssim: 2.9612 - acc: 0.8334 - val_loss: 0.0708 - val_mse_S: 0.0034 - val_mse_R: 0.0340 - val_ssim: 2.9699 - val_acc: 0.8143
# Epoch 90/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0817 - mse_S: 0.0050 - mse_R: 0.0335 - ssim: 2.9607 - acc: 0.8364
# Epoch 00090: val_loss did not improve from 0.07048
# 31/31 [==============================] - 368s 12s/step - loss: 0.0817 - mse_S: 0.0050 - mse_R: 0.0335 - ssim: 2.9607 - acc: 0.8364 - val_loss: 0.0708 - val_mse_S: 0.0034 - val_mse_R: 0.0339 - val_ssim: 2.9699 - val_acc: 0.8165
# Epoch 91/100
# 31/31 [==============================] - ETA: 0s - loss: 0.0816 - mse_S: 0.0048 - mse_R: 0.0330 - ssim: 2.9614 - acc: 0.8347
# Epoch 00091: val_loss did not improve from 0.07048
# Restoring model weights from the end of the best epoch.
# 31/31 [==============================] - 367s 12s/step - loss: 0.0816 - mse_S: 0.0048 - mse_R: 0.0330 - ssim: 2.9614 - acc: 0.8347 - val_loss: 0.0709 - val_mse_S: 0.0034 - val_mse_R: 0.0340 - val_ssim: 2.9699 - val_acc: 0.8172
# Epoch 00091: early stopping

# %%
plt.grid()

plt.plot(history.history['loss'],'--^r',label="loss")
plt.plot(history.history['acc'],'--^g',label='acc')
plt.plot(history.history['val_loss'],'-or',label='val_loss')
plt.plot(history.history['val_acc'],'-og',label='val_acc')
plt.legend()

# %%
y_pred=model.predict(x_test)
I = np.concatenate((y_pred[:, :, :, 3:], y_pred[:, :, :, 3:], y_pred[:, :, :, 3:]), axis=3)
R = y_pred[:, :, :, :3]
S = R*I

def check_result(n):
    fig=plt.figure(figsize=(10,10))
    fig.add_subplot(1,4,1).imshow(x_test[n])
    fig.add_subplot(1,4,2).imshow(R[n])
    fig.add_subplot(1,4,3).imshow(I[n][:,:,:1])
    fig.add_subplot(1,4,4).imshow(S[n])

# %%
for i in range(10):
    check_result(i)

# %%
def plot_hist(img,f):
#     if(f==0):
    img=cv2.cvtColor(np.array(img*255,dtype=np.uint8),cv2.COLOR_RGB2HSV)/255.
#         clahe=cv2.createCLAHE(clipLimit=3.0, tileGridSize=(2,2))
#         img[:,:,2]=clahe.apply(img[:,:,2])
#         img=cv2.cvtColor(img,cv2.COLOR_HSV2RGB)/255.
    h,s,v=cv2.split(img)
    fig=plt.figure(figsize=(16,16))
    fig.add_subplot(4,2,1).imshow(img)
    fig.add_subplot(4,2,2).hist(img.ravel(), bins=256, range=(0.0, 1.0))
    #red
    fig.add_subplot(4,2,3).imshow(h)
    fig.add_subplot(4,2,4).hist(h.ravel(), bins=256, range=(0.0, 1.0))
    #green
    fig.add_subplot(4,2,5).imshow(s)
    fig.add_subplot(4,2,6).hist(s.ravel(), bins=256, range=(0.0, 1.0))
    #blue
#     v=np.power(v,1/3)
    fig.add_subplot(4,2,7).imshow(v)
    fig.add_subplot(4,2,8).hist(v.ravel(), bins=256, range=(0.0, 1.0))

# %%
plot_hist(x_test[0],1)

# %%
plot_hist(x_test[1],1)

# %%
# look at hue

# %%
y_pre=model.predict(x_test)
R=y_pred[:,:,:,:3]
I=np.concatenate((y_pred[:,:,:,3:],y_pred[:,:,:,3:],y_pred[:,:,:,3:]),axis=3)
S=R*I

# %%
plot_hist(S[0][:,:,:3],1)
