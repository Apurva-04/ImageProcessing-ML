# %%
import numpy as np
import keras
import matplotlib.pyplot as plt

# %%
import keras.preprocessing.image as img_preprocess

img=img_preprocess.load_img('../dataSets/pic2.jpeg',target_size=(256,256))
img_arr=(img_preprocess.img_to_array(img)/255.).reshape(1,256,256,3)
img
#plt.imshow(img_arr)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x265A6683588>

# %%
from PIL import ImageFilter

im1 = img.filter(ImageFilter.BLUR)
im2 = img.filter(ImageFilter.MinFilter(3))
im3 = img.filter(ImageFilter.MinFilter)

# %%
im3
# Out:
# <PIL.Image.Image image mode=RGB size=256x256 at 0x265A6690AC8>

# %%
img_preprocess.array_to_img(np.array(keras.layers.UpSampling2D(size=(3,3))(img_arr)).reshape(3*128,3*128,3))
# Out:
# <PIL.Image.Image image mode=RGB size=384x384 at 0x1DF39D8DBC8>

# %%
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,UpSampling2D,Flatten,Dense,Dropout

plt.imshow(np.array(Conv2D(3,(1,1),padding='same',activation='elu')(Conv2D(32,(3,3),padding='same',activation='elu')(img_arr))).reshape(128,128,3))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
