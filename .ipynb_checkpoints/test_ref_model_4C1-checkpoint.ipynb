# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import math
import tensorflow as tf
import keras
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array

# %%
h, w = 160, 160

x_train=[]
y_train=[]
x_test=[]
y_test=[]

path_train_low='../dataSets/ref/our485/low/'
path_train_high='../dataSets/ref/our485/high/'
path_test_low='../dataSets/ref/eval15/low/'
path_test_high='../dataSets/ref/eval15/high/'

print('\nLoding Train dataset :')
i=0;
for img in os.listdir(path_train_low):
    img_low_path=os.path.join(path_train_low, img)
    img_high_path=os.path.join(path_train_high, img)
    
    img_low=load_img(img_low_path, target_size=(h,w))
    img_low=img_to_array(img_low)/255.
       
    i=i+1
    print("{:.2f}".format(i/4.89)+' %',end='\r')
    
    img_high=load_img(img_high_path, target_size=(h,w))
    img_high=img_to_array(img_high)/255.
    
    x_train.append(img_low)
    y_train.append(img_high)
    
print('\nLoding Test dataset :')
i=0;
for img in os.listdir(path_test_low):
    img_low_path=os.path.join(path_test_low, img)
    img_high_path=os.path.join(path_test_high, img)
    
    img_low=load_img(img_low_path, target_size=(h,w))
    img_low=img_to_array(img_low)/255.
   
    i=i+1
    print("{:.2f}".format(i/0.14)+' %',end='\r')
    
    img_high=load_img(img_high_path, target_size=(h,w))
    img_high=img_to_array(img_high)/255.
    
    x_test.append(img_low)
    y_test.append(img_high)

x_train=np.array(x_train, dtype="float32")
y_train=np.array(y_train, dtype="float32")

x_test=np.array(x_test, dtype="float32")
y_test=np.array(y_test, dtype="float32")
# Out:
# Loding Train dataset :
# 100.00 %
# Loding Test dataset :
# 100.00 %

# %%
fig=plt.figure()

f=fig.add_subplot(1,2,1)
s=fig.add_subplot(1,2,2)

f.imshow(x_test[1])
s.imshow(y_test[1])

# %%
def _tf_fspecial_gauss(size, sigma):
    """Function to mimic the 'fspecial' gaussian MATLAB function
    """
    x_data, y_data = np.mgrid[-size//2 + 1:size//2 + 1, -size//2 + 1:size//2 + 1]

    x_data = np.expand_dims(x_data, axis=-1)
    x_data = np.expand_dims(x_data, axis=-1)

    y_data = np.expand_dims(y_data, axis=-1)
    y_data = np.expand_dims(y_data, axis=-1)

    x = tf.constant(x_data, dtype=tf.float32)
    y = tf.constant(y_data, dtype=tf.float32)

    g = tf.exp(-((x**2 + y**2)/(2.0*sigma**2)))
    return g / tf.reduce_sum(g)

def tf_ssim(img1, img2, cs_map=False, mean_metric=True, size=11, sigma=1.5):
    window = _tf_fspecial_gauss(size, sigma) # window shape [size, size]
    K1 = 0.01
    K2 = 0.03
    L = 1  # depth of image (255 in case the image has a differnt scale)
    C1 = (K1*L)**2
    C2 = (K2*L)**2
    mu1 = tf.nn.conv2d(img1, window, strides=[1,1,1,1], padding='VALID')
    mu2 = tf.nn.conv2d(img2, window, strides=[1,1,1,1],padding='VALID')
    mu1_sq = mu1*mu1
    mu2_sq = mu2*mu2
    mu1_mu2 = mu1*mu2
    sigma1_sq = tf.nn.conv2d(img1*img1, window, strides=[1,1,1,1],padding='VALID') - mu1_sq
    sigma2_sq = tf.nn.conv2d(img2*img2, window, strides=[1,1,1,1],padding='VALID') - mu2_sq
    sigma12 = tf.nn.conv2d(img1*img2, window, strides=[1,1,1,1],padding='VALID') - mu1_mu2
    if cs_map:
        value = (((2*mu1_mu2 + C1)*(2*sigma12 + C2))/((mu1_sq + mu2_sq + C1)*
                            (sigma1_sq + sigma2_sq + C2)),
                        (2.0*sigma12 + C2)/(sigma1_sq + sigma2_sq + C2))
    else:
        value = ((2*mu1_mu2 + C1)*(2*sigma12 + C2))/((mu1_sq + mu2_sq + C1)*
                            (sigma1_sq + sigma2_sq + C2))

    if mean_metric:
        value = tf.reduce_mean(value)
    return value

def my_loss(y_true, y_pred):
    MAE_loss = K.mean(K.abs(y_pred - y_true))
    SSIM_loss = tf_ssim(tf.expand_dims(y_pred[:, :, :, 0], -1),tf.expand_dims(y_true[:, :, :, 0], -1)) + tf_ssim(
                tf.expand_dims(y_pred[:, :, :, 1], -1), tf.expand_dims(y_true[:, :, :, 1], -1)) + tf_ssim(
                tf.expand_dims(y_pred[:, :, :, 2], -1), tf.expand_dims(y_true[:, :, :, 2], -1))

    percent = 0.4
    index = int(h * w * percent - 1)
    gray1 = 0.39 * y_pred[:, :, :, 0] + 0.5 * y_pred[:, :, :, 1] + 0.11 * y_pred[:, :, :, 2]
    gray = tf.reshape(gray1, [-1, h * w])
    gray_sort = tf.nn.top_k(-gray, h * w)[0]
    yu = gray_sort[:, index]
    yu = tf.expand_dims(tf.expand_dims(yu, -1), -1)
    mask = tf.cast(gray1 <= yu,tf.float32)
    mask1 = tf.expand_dims(mask, -1)
    mask = tf.concat([mask1, mask1, mask1], -1)

    low_fake_clean = tf.multiply(mask, y_pred[:, :, :, :3])
    high_fake_clean = tf.multiply(1 - mask, y_pred[:, :, :, :3])
    low_clean = tf.multiply(mask, y_true[:, :, :, :])
    high_clean = tf.multiply(1 - mask, y_true[:, :, :, :])
    Region_loss = K.mean(K.abs(low_fake_clean - low_clean) * 4 + K.abs(high_fake_clean - high_clean))
    
    loss = MAE_loss + 2.5 - SSIM_loss + Region_loss
    
    return loss

# %%
from keras.models import Model
from keras.models import Sequential
from keras.layers import Input,add,Conv2D,MaxPooling2D,UpSampling2D,Flatten,Dropout,Dense,BatchNormalization,Reshape,UpSampling2D,Conv2DTranspose,Concatenate,Lambda

def InstantiateModel(in_):
    channel = 64
    kernal_size = (3,3)
    in_lambda = in_
    for i in range(2,10):
        in_lambda = Concatenate()([in_lambda, Lambda(lambda x: i*x)(in_)])
    #denoise
    conv0 = Conv2D(channel, kernal_size, strides=1, padding='same', activation=None)(in_lambda)
    
    conv1 = Conv2D(channel, kernal_size, strides=2, padding='same', activation='relu')(conv0)
    conv2 = Conv2D(channel, kernal_size, strides=2, padding='same', activation='relu')(conv1)
    conv3 = Conv2D(channel, kernal_size, strides=2, padding='same', activation='relu')(conv2)
    
    up3 = UpSampling2D((2,2))(conv3)
    deconv3 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(up3)+conv2
    up2 = UpSampling2D((2,2))(deconv3)
    deconv2 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(up2)+conv1
    up1 = UpSampling2D((2,2))(deconv2)
    deconv1 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(up1)+conv0
    
    deconv2_resize = UpSampling2D((2,2))(deconv2)
    feature_gather = Concatenate()([deconv2_resize, deconv1])
    model_1 = Conv2D(3, (1,1), padding='same', activation=None)(feature_gather)
    
    #restoration
    model_3 = Conv2D(channel, kernal_size, strides=1, padding='same', activation='relu')(model_1)
    model_3 = Conv2D(channel, kernal_size, activation='relu', padding='same', strides=1)(model_3)
    
    out = Conv2D(3, (1,1), activation='sigmoid', padding='same', strides=1)(model_3)
    
    return out

# %%
Input_Sample = Input(shape=(h, w, 3))
Output_ = InstantiateModel(Input_Sample)
model = Model(inputs=Input_Sample, outputs=Output_)
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# lambda (Lambda)                 (None, 160, 160, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 160, 160, 6)  0           input_1[0][0]
#                                                                  lambda[0][0]
# __________________________________________________________________________________________________
# lambda_1 (Lambda)               (None, 160, 160, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 160, 160, 9)  0           concatenate[0][0]
#                                                                  lambda_1[0][0]
# __________________________________________________________________________________________________
# lambda_2 (Lambda)               (None, 160, 160, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 160, 160, 12) 0           concatenate_1[0][0]
#                                                                  lambda_2[0][0]
# __________________________________________________________________________________________________
# lambda_3 (Lambda)               (None, 160, 160, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 160, 160, 15) 0           concatenate_2[0][0]
#                                                                  lambda_3[0][0]
# __________________________________________________________________________________________________
# lambda_4 (Lambda)               (None, 160, 160, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 160, 160, 18) 0           concatenate_3[0][0]
#                                                                  lambda_4[0][0]
# __________________________________________________________________________________________________
# lambda_5 (Lambda)               (None, 160, 160, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 160, 160, 21) 0           concatenate_4[0][0]
#                                                                  lambda_5[0][0]
# __________________________________________________________________________________________________
# lambda_6 (Lambda)               (None, 160, 160, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 160, 160, 24) 0           concatenate_5[0][0]
#                                                                  lambda_6[0][0]
# __________________________________________________________________________________________________
# lambda_7 (Lambda)               (None, 160, 160, 3)  0           input_1[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 160, 160, 27) 0           concatenate_6[0][0]
#                                                                  lambda_7[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 160, 160, 64) 15616       concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 80, 80, 64)   36928       conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 40, 40, 64)   36928       conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 20, 20, 64)   36928       conv2d_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 40, 40, 64)   0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 40, 40, 64)   36928       up_sampling2d[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp [(None, 40, 40, 64)] 0           conv2d_4[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 80, 80, 64)   0           tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 80, 80, 64)   36928       up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_1 (TensorFlow [(None, 80, 80, 64)] 0           conv2d_5[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 160, 160, 64) 0           tf_op_layer_AddV2_1[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 160, 160, 64) 36928       up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 160, 160, 64) 0           tf_op_layer_AddV2_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_2 (TensorFlow [(None, 160, 160, 64 0           conv2d_6[0][0]
#                                                                  conv2d[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 160, 160, 128 0           up_sampling2d_3[0][0]
#                                                                  tf_op_layer_AddV2_2[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 160, 160, 3)  387         concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 160, 160, 64) 1792        conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 160, 160, 64) 36928       conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 160, 160, 3)  195         conv2d_9[0][0]
# ==================================================================================================
# Total params: 276,486
# Trainable params: 276,486
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model,to_file='model.png',show_shapes=True, show_layer_names=True)

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

checkpoint=ModelCheckpoint('models/ref/4C1.h5',
                            monitor='val_loss',
                            mode='min',
                            save_best_only=True,
                            verbose=1
                          )
earlystop=EarlyStopping(monitor='val_loss',
                        patience=6,
                        min_delta=0,
                        restore_best_weights=True,
                        verbose=1
                       )
reduce_lr=ReduceLROnPlateau(monitor='val_loss',
                            factor=0.2,
                            patience=6,
                            min_delta=0.001,
                            verbose=1
                           )
callbacks=[checkpoint,earlystop,reduce_lr]

model.compile(loss=my_loss,#keras.losses.MeanSquaredError(),
              optimizer=keras.optimizers.Adam(learning_rate=0.001),
              metrics=['accuracy']
             )

history=model.fit(
    x=x_train,
    y=y_train,
    batch_size=32,
    shuffle=True,
    epochs=100,
    validation_data=(x_test, y_test),
    callbacks=callbacks
    )
# Out:
# Epoch 1/100
# 16/16 [==============================] - ETA: 0s - loss: 1.0828 - accuracy: 0.4857
# Epoch 00001: val_loss improved from inf to 1.23298, saving model to models/ref\4C1.h5
# 16/16 [==============================] - 160s 10s/step - loss: 1.0828 - accuracy: 0.4857 - val_loss: 1.2330 - val_accuracy: 0.4249
# Epoch 2/100
# 16/16 [==============================] - ETA: 0s - loss: 0.7225 - accuracy: 0.5170
# Epoch 00002: val_loss improved from 1.23298 to 0.59578, saving model to models/ref\4C1.h5
# 16/16 [==============================] - 159s 10s/step - loss: 0.7225 - accuracy: 0.5170 - val_loss: 0.5958 - val_accuracy: 0.5763
# Epoch 3/100
# 16/16 [==============================] - ETA: 0s - loss: 0.5200 - accuracy: 0.5793
# Epoch 00003: val_loss improved from 0.59578 to 0.45267, saving model to models/ref\4C1.h5
# 16/16 [==============================] - 158s 10s/step - loss: 0.5200 - accuracy: 0.5793 - val_loss: 0.4527 - val_accuracy: 0.6728
# Epoch 4/100
# 16/16 [==============================] - ETA: 0s - loss: 0.4656 - accuracy: 0.6656
# Epoch 00004: val_loss improved from 0.45267 to 0.41064, saving model to models/ref\4C1.h5
# 16/16 [==============================] - 225s 14s/step - loss: 0.4656 - accuracy: 0.6656 - val_loss: 0.4106 - val_accuracy: 0.6838
# Epoch 5/100
# 16/16 [==============================] - ETA: 0s - loss: 0.4146 - accuracy: 0.6687
# Epoch 00005: val_loss improved from 0.41064 to 0.39862, saving model to models/ref\4C1.h5
# 16/16 [==============================] - 249s 16s/step - loss: 0.4146 - accuracy: 0.6687 - val_loss: 0.3986 - val_accuracy: 0.4902
# Epoch 6/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3966 - accuracy: 0.6628
# Epoch 00006: val_loss improved from 0.39862 to 0.38436, saving model to models/ref\4C1.h5
# 16/16 [==============================] - 249s 16s/step - loss: 0.3966 - accuracy: 0.6628 - val_loss: 0.3844 - val_accuracy: 0.5739
# Epoch 7/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3854 - accuracy: 0.6810
# Epoch 00007: val_loss improved from 0.38436 to 0.37330, saving model to models/ref\4C1.h5
# 16/16 [==============================] - 248s 16s/step - loss: 0.3854 - accuracy: 0.6810 - val_loss: 0.3733 - val_accuracy: 0.5404
# Epoch 8/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3711 - accuracy: 0.6623
# Epoch 00008: val_loss improved from 0.37330 to 0.34769, saving model to models/ref\4C1.h5
# 16/16 [==============================] - 249s 16s/step - loss: 0.3711 - accuracy: 0.6623 - val_loss: 0.3477 - val_accuracy: 0.6498
# Epoch 9/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3651 - accuracy: 0.6868
# Epoch 00009: val_loss improved from 0.34769 to 0.33945, saving model to models/ref\4C1.h5
# 16/16 [==============================] - 249s 16s/step - loss: 0.3651 - accuracy: 0.6868 - val_loss: 0.3394 - val_accuracy: 0.6698
# Epoch 10/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3484 - accuracy: 0.6736
# Epoch 00010: val_loss did not improve from 0.33945
# 16/16 [==============================] - 249s 16s/step - loss: 0.3484 - accuracy: 0.6736 - val_loss: 0.3409 - val_accuracy: 0.6908
# Epoch 11/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3394 - accuracy: 0.6745
# Epoch 00011: val_loss did not improve from 0.33945
# 16/16 [==============================] - 248s 15s/step - loss: 0.3394 - accuracy: 0.6745 - val_loss: 0.3971 - val_accuracy: 0.7339
# Epoch 12/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3592 - accuracy: 0.6737
# Epoch 00012: val_loss did not improve from 0.33945
# 16/16 [==============================] - 247s 15s/step - loss: 0.3592 - accuracy: 0.6737 - val_loss: 0.3571 - val_accuracy: 0.7439
# Epoch 13/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3534 - accuracy: 0.6618
# Epoch 00013: val_loss did not improve from 0.33945
# 16/16 [==============================] - 249s 16s/step - loss: 0.3534 - accuracy: 0.6618 - val_loss: 0.3462 - val_accuracy: 0.7319
# Epoch 14/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3374 - accuracy: 0.6481
# Epoch 00014: val_loss improved from 0.33945 to 0.31924, saving model to models/ref\4C1.h5
# 16/16 [==============================] - 250s 16s/step - loss: 0.3374 - accuracy: 0.6481 - val_loss: 0.3192 - val_accuracy: 0.7343
# Epoch 15/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3331 - accuracy: 0.6622
# Epoch 00015: val_loss did not improve from 0.31924
# 16/16 [==============================] - 248s 16s/step - loss: 0.3331 - accuracy: 0.6622 - val_loss: 0.3575 - val_accuracy: 0.6525
# Epoch 16/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3424 - accuracy: 0.6465
# Epoch 00016: val_loss improved from 0.31924 to 0.30876, saving model to models/ref\4C1.h5
# 16/16 [==============================] - 248s 16s/step - loss: 0.3424 - accuracy: 0.6465 - val_loss: 0.3088 - val_accuracy: 0.7660
# Epoch 17/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3221 - accuracy: 0.6773
# Epoch 00017: val_loss improved from 0.30876 to 0.30609, saving model to models/ref\4C1.h5
# 16/16 [==============================] - 248s 16s/step - loss: 0.3221 - accuracy: 0.6773 - val_loss: 0.3061 - val_accuracy: 0.7494
# Epoch 18/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3306 - accuracy: 0.6733
# Epoch 00018: val_loss did not improve from 0.30609
# 16/16 [==============================] - 248s 15s/step - loss: 0.3306 - accuracy: 0.6733 - val_loss: 0.3433 - val_accuracy: 0.7687
# Epoch 19/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3383 - accuracy: 0.6848
# Epoch 00019: val_loss improved from 0.30609 to 0.29213, saving model to models/ref\4C1.h5
# 16/16 [==============================] - 248s 16s/step - loss: 0.3383 - accuracy: 0.6848 - val_loss: 0.2921 - val_accuracy: 0.6535
# Epoch 20/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3111 - accuracy: 0.6851
# Epoch 00020: val_loss improved from 0.29213 to 0.28849, saving model to models/ref\4C1.h5
# 16/16 [==============================] - 248s 16s/step - loss: 0.3111 - accuracy: 0.6851 - val_loss: 0.2885 - val_accuracy: 0.7276
# Epoch 21/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3001 - accuracy: 0.6743
# Epoch 00021: val_loss did not improve from 0.28849
# 16/16 [==============================] - 249s 16s/step - loss: 0.3001 - accuracy: 0.6743 - val_loss: 0.2914 - val_accuracy: 0.7342
# Epoch 22/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3025 - accuracy: 0.6790
# Epoch 00022: val_loss did not improve from 0.28849
# 16/16 [==============================] - 204s 13s/step - loss: 0.3025 - accuracy: 0.6790 - val_loss: 0.3173 - val_accuracy: 0.6322
# Epoch 23/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3105 - accuracy: 0.6945
# Epoch 00023: val_loss did not improve from 0.28849
# 16/16 [==============================] - 196s 12s/step - loss: 0.3105 - accuracy: 0.6945 - val_loss: 0.2998 - val_accuracy: 0.6201
# Epoch 24/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3021 - accuracy: 0.6758
# Epoch 00024: val_loss did not improve from 0.28849
# 16/16 [==============================] - 205s 13s/step - loss: 0.3021 - accuracy: 0.6758 - val_loss: 0.2918 - val_accuracy: 0.7072
# Epoch 25/100
# 16/16 [==============================] - ETA: 0s - loss: 0.3135 - accuracy: 0.6821
# Epoch 00025: val_loss did not improve from 0.28849
# 16/16 [==============================] - 196s 12s/step - loss: 0.3135 - accuracy: 0.6821 - val_loss: 0.3103 - val_accuracy: 0.7036
# Epoch 26/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2931 - accuracy: 0.6914
# Epoch 00026: val_loss improved from 0.28849 to 0.28652, saving model to models/ref\4C1.h5
# 16/16 [==============================] - 197s 12s/step - loss: 0.2931 - accuracy: 0.6914 - val_loss: 0.2865 - val_accuracy: 0.7494
# Epoch 27/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2812 - accuracy: 0.6914
# Epoch 00027: val_loss did not improve from 0.28652
# 16/16 [==============================] - 196s 12s/step - loss: 0.2812 - accuracy: 0.6914 - val_loss: 0.3024 - val_accuracy: 0.6030
# Epoch 28/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2800 - accuracy: 0.6926
# Epoch 00028: val_loss improved from 0.28652 to 0.27653, saving model to models/ref\4C1.h5
# 16/16 [==============================] - 197s 12s/step - loss: 0.2800 - accuracy: 0.6926 - val_loss: 0.2765 - val_accuracy: 0.6343
# Epoch 29/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2850 - accuracy: 0.6877
# Epoch 00029: val_loss did not improve from 0.27653
# 16/16 [==============================] - 158s 10s/step - loss: 0.2850 - accuracy: 0.6877 - val_loss: 0.3151 - val_accuracy: 0.6513
# Epoch 30/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2881 - accuracy: 0.6811
# Epoch 00030: val_loss did not improve from 0.27653
# 16/16 [==============================] - 158s 10s/step - loss: 0.2881 - accuracy: 0.6811 - val_loss: 0.2809 - val_accuracy: 0.7217
# Epoch 31/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2676 - accuracy: 0.6996
# Epoch 00031: val_loss improved from 0.27653 to 0.26506, saving model to models/ref\4C1.h5
# 16/16 [==============================] - 158s 10s/step - loss: 0.2676 - accuracy: 0.6996 - val_loss: 0.2651 - val_accuracy: 0.7260
# Epoch 32/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2619 - accuracy: 0.7073
# Epoch 00032: val_loss did not improve from 0.26506
# 16/16 [==============================] - 167s 10s/step - loss: 0.2619 - accuracy: 0.7073 - val_loss: 0.2790 - val_accuracy: 0.7590
# Epoch 33/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2648 - accuracy: 0.7011
# Epoch 00033: val_loss did not improve from 0.26506
# 16/16 [==============================] - 175s 11s/step - loss: 0.2648 - accuracy: 0.7011 - val_loss: 0.2784 - val_accuracy: 0.6999
# Epoch 34/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2605 - accuracy: 0.6932
# Epoch 00034: val_loss did not improve from 0.26506
# 16/16 [==============================] - 159s 10s/step - loss: 0.2605 - accuracy: 0.6932 - val_loss: 0.3890 - val_accuracy: 0.5552
# Epoch 35/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2713 - accuracy: 0.6754
# Epoch 00035: val_loss did not improve from 0.26506
# 16/16 [==============================] - 159s 10s/step - loss: 0.2713 - accuracy: 0.6754 - val_loss: 0.2862 - val_accuracy: 0.7251
# Epoch 36/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2573 - accuracy: 0.7012
# Epoch 00036: val_loss improved from 0.26506 to 0.25566, saving model to models/ref\4C1.h5
# 16/16 [==============================] - 160s 10s/step - loss: 0.2573 - accuracy: 0.7012 - val_loss: 0.2557 - val_accuracy: 0.7679
# Epoch 37/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2647 - accuracy: 0.6775
# Epoch 00037: val_loss did not improve from 0.25566
# 16/16 [==============================] - 164s 10s/step - loss: 0.2647 - accuracy: 0.6775 - val_loss: 0.2758 - val_accuracy: 0.6526
# Epoch 38/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2695 - accuracy: 0.6792
# Epoch 00038: val_loss did not improve from 0.25566
# 16/16 [==============================] - 163s 10s/step - loss: 0.2695 - accuracy: 0.6792 - val_loss: 0.2752 - val_accuracy: 0.7642
# Epoch 39/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2733 - accuracy: 0.7004
# Epoch 00039: val_loss did not improve from 0.25566
# 16/16 [==============================] - 162s 10s/step - loss: 0.2733 - accuracy: 0.7004 - val_loss: 0.3366 - val_accuracy: 0.6129
# Epoch 40/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2741 - accuracy: 0.7028
# Epoch 00040: val_loss did not improve from 0.25566
# 16/16 [==============================] - 158s 10s/step - loss: 0.2741 - accuracy: 0.7028 - val_loss: 0.2629 - val_accuracy: 0.7453
# Epoch 41/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2580 - accuracy: 0.6971
# Epoch 00041: val_loss did not improve from 0.25566
# 16/16 [==============================] - 158s 10s/step - loss: 0.2580 - accuracy: 0.6971 - val_loss: 0.2667 - val_accuracy: 0.7395
# Epoch 42/100
# 16/16 [==============================] - ETA: 0s - loss: 0.2552 - accuracy: 0.7010
# Epoch 00042: val_loss did not improve from 0.25566
# Restoring model weights from the end of the best epoch.
#
# Epoch 00042: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 16/16 [==============================] - 158s 10s/step - loss: 0.2552 - accuracy: 0.7010 - val_loss: 0.2892 - val_accuracy: 0.5507
# Epoch 00042: early stopping

# %%
plt.grid()

plt.plot(history.history['loss'],'--^r',label="loss")
plt.plot(history.history['accuracy'],'--^g',label='accuracy')
plt.plot(history.history['val_loss'],'-or',label='val_loss')
plt.plot(history.history['val_accuracy'],'-og',label='val_accuracy')
plt.legend()

# %%
def check_result(n):
    fig=plt.figure()
    fig.add_subplot(1,2,1).imshow(y_test[n])
    fig.add_subplot(1,2,2).imshow(model.predict(x_test)[n])

# %%
check_result(3)

# %%
def plot_hist(img,f):
#     if(f==0):
    img=cv2.cvtColor(np.array(img*255,dtype=np.uint8),cv2.COLOR_RGB2HSV)/255.
#         clahe=cv2.createCLAHE(clipLimit=3.0, tileGridSize=(2,2))
#         img[:,:,2]=clahe.apply(img[:,:,2])
#         img=cv2.cvtColor(img,cv2.COLOR_HSV2RGB)/255.
    h,s,v=cv2.split(img)
    fig=plt.figure(figsize=(16,16))
    fig.add_subplot(4,2,1).imshow(img)
    fig.add_subplot(4,2,2).hist(img.ravel(), bins=256, range=(0.0, 1.0))
    #red
    fig.add_subplot(4,2,3).imshow(h)
    fig.add_subplot(4,2,4).hist(h.ravel(), bins=256, range=(0.0, 1.0))
    #green
    fig.add_subplot(4,2,5).imshow(s)
    fig.add_subplot(4,2,6).hist(s.ravel(), bins=256, range=(0.0, 1.0))
    #blue
#     v=np.power(v,1/3)
    fig.add_subplot(4,2,7).imshow(v)
    fig.add_subplot(4,2,8).hist(v.ravel(), bins=256, range=(0.0, 1.0))

# %%
plot_hist(x_test[2],1)

# %%
plot_hist(y_test[2],1)

# %%
# look at hue

# %%
plot_hist(model.predict(x_test)[2],1)
