# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2

import keras
from keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,AveragePooling2D,UpSampling2D,Flatten,Dropout,Dense,BatchNormalization,Reshape

# %%
import os

x_train=[]
y_train=[]
x_test=[]
y_test=[]

path_train_low='../dataSets/ref/our485/low/'
path_train_high='../dataSets/ref/our485/high/'
path_test_low='../dataSets/ref/eval15/low/'
path_test_high='../dataSets/ref/eval15/high/'

print('\nLoding Train dataset :')
i=0;
for img in os.listdir(path_train_low):
    img_low_path=os.path.join(path_train_low, img)
    img_high_path=os.path.join(path_train_high, img)
    
    img_low=load_img(img_low_path, target_size=(128,128))
    #img_low=img_to_array(img_low)/255.
    img_low=cv2.fastNlMeansDenoisingColored(np.array(img_to_array(img_low),dtype='uint8'),None,2,10,6,20)/255.
    
    i=i+1
    print("{:.2f}".format(i/4.89)+' %',end='\r')
    
    img_high=load_img(img_high_path, target_size=(128,128))
    #img_high=img_to_array(img_high)/255.
    img_high=cv2.fastNlMeansDenoisingColored(np.array(img_to_array(img_high),dtype='uint8'),None,2,10,6,20)/255.
    
    x_train.append(img_low)
    y_train.append(img_high)
#     Rx,Gx,Bx=cv2.split(img_low)
#     Ry,Gy,By=cv2.split(img_high)
    
#     x_train.append(Rx)
#     y_train.append(Ry)
    
print('\nLoding Test dataset :')
i=0;
for img in os.listdir(path_test_low):
    img_low_path=os.path.join(path_test_low, img)
    img_high_path=os.path.join(path_test_high, img)
    
    img_low=load_img(img_low_path, target_size=(128,128))
    #img_low=img_to_array(img_low)/255.
    img_low=cv2.fastNlMeansDenoisingColored(np.array(img_to_array(img_low),dtype='uint8'),None,2,10,6,20)/255.
    
    i=i+1
    print("{:.2f}".format(i/0.14)+' %',end='\r')
    
    img_high=load_img(img_high_path, target_size=(128,128))
    #img_high=img_to_array(img_high)/255.
    img_high=cv2.fastNlMeansDenoisingColored(np.array(img_to_array(img_high),dtype='uint8'),None,2,10,6,20)/255.
    
    x_test.append(img_low)
    y_test.append(img_high)
#     Rx,Gx,Bx=cv2.split(img_low)
#     Ry,Gy,By=cv2.split(img_high)
    
#     x_test.append(Rx)
#     y_test.append(Ry)

x_train=np.array(x_train, dtype="float32")
y_train=np.array(y_train, dtype="float32")

x_test=np.array(x_test, dtype="float32")
y_test=np.array(y_test, dtype="float32")

# x_train=np.expand_dims(np.array(x_train, dtype="float32"),3)
# y_train=np.expand_dims(np.array(y_train, dtype="float32"),3)

# x_test=np.expand_dims(np.array(x_test, dtype="float32"),3)
# y_test=np.expand_dims(np.array(y_test, dtype="float32"),3)
# Out:
# Loding Train dataset :
# 100.00 %
# Loding Test dataset :
# 100.00 %

# %%
y_train.shape
# Out:
# (489, 128, 128, 3)

# %%
fig=plt.figure()

f=fig.add_subplot(1,2,1)
s=fig.add_subplot(1,2,2)

f.imshow(x_test[9][:,:,0])
s.imshow(y_test[9][:,:,:])

# %%
model=Sequential()

model.add(Conv2D(128,(3,3),padding='same',activation='elu',input_shape=(128,128,3)))
model.add(UpSampling2D((2,2)))
model.add(Conv2D(64,(3,3),padding='same',activation='elu'))
model.add(Conv2D(64,(3,3),padding='same',activation='elu'))
model.add(MaxPooling2D((2,2)))
model.add(Conv2D(3,(1,1),padding='same',activation='sigmoid'))

model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 128, 128, 128)     3584
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 256, 256, 128)     0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 256, 256, 64)      73792
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 256, 256, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 128, 128, 64)      0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 128, 128, 3)       195
# =================================================================
# Total params: 114,499
# Trainable params: 114,499
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

checkpoint=ModelCheckpoint('models/ref/ref_cnn.h5',
                            monitor='val_loss',
                            mode='min',
                            save_best_only=True,
                            verbose=1
                          )
earlystop=EarlyStopping(monitor='val_loss',
                        patience=6,
                        min_delta=0,
                        restore_best_weights=True,
                        verbose=1
                       )
reduce_lr=ReduceLROnPlateau(monitor='val_loss',
                            factor=0.2,
                            patience=6,
                            min_delta=0.0001,
                            verbose=1
                           )
callbacks=[checkpoint,earlystop,reduce_lr]

model.compile(loss=keras.losses.MeanSquaredError(),
              optimizer='adam',
              metrics=['accuracy']
             )

history=model.fit(
    x=x_train,
    y=y_train,
    batch_size=32,
    epochs=50,
    validation_data=(x_test, y_test),
    callbacks=callbacks
    )
# Out:
# Epoch 1/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0386 - accuracy: 0.6167
# Epoch 00001: val_loss improved from inf to 0.02241, saving model to models/ref\ref_cnn.h5
# 16/16 [==============================] - 422s 26s/step - loss: 0.0386 - accuracy: 0.6167 - val_loss: 0.0224 - val_accuracy: 0.5675
# Epoch 2/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0312 - accuracy: 0.7038
# Epoch 00002: val_loss did not improve from 0.02241
# 16/16 [==============================] - 414s 26s/step - loss: 0.0312 - accuracy: 0.7038 - val_loss: 0.0249 - val_accuracy: 0.6761
# Epoch 3/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0294 - accuracy: 0.7057
# Epoch 00003: val_loss did not improve from 0.02241
# 16/16 [==============================] - 265s 17s/step - loss: 0.0294 - accuracy: 0.7057 - val_loss: 0.0255 - val_accuracy: 0.5626
# Epoch 4/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0278 - accuracy: 0.6842
# Epoch 00004: val_loss improved from 0.02241 to 0.02045, saving model to models/ref\ref_cnn.h5
# 16/16 [==============================] - 265s 17s/step - loss: 0.0278 - accuracy: 0.6842 - val_loss: 0.0205 - val_accuracy: 0.7035
# Epoch 5/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0267 - accuracy: 0.7070
# Epoch 00005: val_loss improved from 0.02045 to 0.02019, saving model to models/ref\ref_cnn.h5
# 16/16 [==============================] - 265s 17s/step - loss: 0.0267 - accuracy: 0.7070 - val_loss: 0.0202 - val_accuracy: 0.6557
# Epoch 6/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 0.7307
# Epoch 00006: val_loss did not improve from 0.02019
# 16/16 [==============================] - 261s 16s/step - loss: 0.0261 - accuracy: 0.7307 - val_loss: 0.0218 - val_accuracy: 0.6310
# Epoch 7/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0260 - accuracy: 0.7369
# Epoch 00007: val_loss did not improve from 0.02019
# 16/16 [==============================] - 258s 16s/step - loss: 0.0260 - accuracy: 0.7369 - val_loss: 0.0229 - val_accuracy: 0.6682
# Epoch 8/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.7129
# Epoch 00008: val_loss improved from 0.02019 to 0.01859, saving model to models/ref\ref_cnn.h5
# 16/16 [==============================] - 258s 16s/step - loss: 0.0263 - accuracy: 0.7129 - val_loss: 0.0186 - val_accuracy: 0.6694
# Epoch 9/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0261 - accuracy: 0.7355
# Epoch 00009: val_loss did not improve from 0.01859
# 16/16 [==============================] - 260s 16s/step - loss: 0.0261 - accuracy: 0.7355 - val_loss: 0.0193 - val_accuracy: 0.5331
# Epoch 10/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.7152
# Epoch 00010: val_loss improved from 0.01859 to 0.01854, saving model to models/ref\ref_cnn.h5
# 16/16 [==============================] - 258s 16s/step - loss: 0.0263 - accuracy: 0.7152 - val_loss: 0.0185 - val_accuracy: 0.7469
# Epoch 11/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.6997
# Epoch 00011: val_loss improved from 0.01854 to 0.01770, saving model to models/ref\ref_cnn.h5
# 16/16 [==============================] - 259s 16s/step - loss: 0.0263 - accuracy: 0.6997 - val_loss: 0.0177 - val_accuracy: 0.7661
# Epoch 12/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0258 - accuracy: 0.7292
# Epoch 00012: val_loss did not improve from 0.01770
# 16/16 [==============================] - 259s 16s/step - loss: 0.0258 - accuracy: 0.7292 - val_loss: 0.0195 - val_accuracy: 0.7581
# Epoch 13/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.7328
# Epoch 00013: val_loss improved from 0.01770 to 0.01725, saving model to models/ref\ref_cnn.h5
# 16/16 [==============================] - 261s 16s/step - loss: 0.0255 - accuracy: 0.7328 - val_loss: 0.0173 - val_accuracy: 0.7576
# Epoch 14/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.7351
# Epoch 00014: val_loss did not improve from 0.01725
# 16/16 [==============================] - 260s 16s/step - loss: 0.0256 - accuracy: 0.7351 - val_loss: 0.0176 - val_accuracy: 0.7426
# Epoch 15/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0256 - accuracy: 0.6852
# Epoch 00015: val_loss did not improve from 0.01725
# 16/16 [==============================] - 263s 16s/step - loss: 0.0256 - accuracy: 0.6852 - val_loss: 0.0227 - val_accuracy: 0.7422
# Epoch 16/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0258 - accuracy: 0.6738
# Epoch 00016: val_loss did not improve from 0.01725
# 16/16 [==============================] - 260s 16s/step - loss: 0.0258 - accuracy: 0.6738 - val_loss: 0.0193 - val_accuracy: 0.5890
# Epoch 17/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0259 - accuracy: 0.6846
# Epoch 00017: val_loss did not improve from 0.01725
# 16/16 [==============================] - 372s 23s/step - loss: 0.0259 - accuracy: 0.6846 - val_loss: 0.0214 - val_accuracy: 0.6860
# Epoch 18/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.7317
# Epoch 00018: val_loss did not improve from 0.01725
# 16/16 [==============================] - 414s 26s/step - loss: 0.0253 - accuracy: 0.7317 - val_loss: 0.0185 - val_accuracy: 0.6879
# Epoch 19/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.7132
# Epoch 00019: val_loss improved from 0.01725 to 0.01707, saving model to models/ref\ref_cnn.h5
# 16/16 [==============================] - 406s 25s/step - loss: 0.0253 - accuracy: 0.7132 - val_loss: 0.0171 - val_accuracy: 0.7079
# Epoch 20/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0252 - accuracy: 0.7227
# Epoch 00020: val_loss did not improve from 0.01707
# 16/16 [==============================] - 407s 25s/step - loss: 0.0252 - accuracy: 0.7227 - val_loss: 0.0192 - val_accuracy: 0.5593
# Epoch 21/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.7260
# Epoch 00021: val_loss did not improve from 0.01707
# 16/16 [==============================] - 410s 26s/step - loss: 0.0253 - accuracy: 0.7260 - val_loss: 0.0219 - val_accuracy: 0.5173
# Epoch 22/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.7044
# Epoch 00022: val_loss did not improve from 0.01707
# 16/16 [==============================] - 327s 20s/step - loss: 0.0253 - accuracy: 0.7044 - val_loss: 0.0194 - val_accuracy: 0.6746
# Epoch 23/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.7021
# Epoch 00023: val_loss did not improve from 0.01707
# 16/16 [==============================] - 262s 16s/step - loss: 0.0250 - accuracy: 0.7021 - val_loss: 0.0241 - val_accuracy: 0.6806
# Epoch 24/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0255 - accuracy: 0.7217
# Epoch 00024: val_loss did not improve from 0.01707
# 16/16 [==============================] - 262s 16s/step - loss: 0.0255 - accuracy: 0.7217 - val_loss: 0.0216 - val_accuracy: 0.5933
# Epoch 25/50
# 16/16 [==============================] - ETA: 0s - loss: 0.0251 - accuracy: 0.7062
# Epoch 00025: val_loss did not improve from 0.01707
# Restoring model weights from the end of the best epoch.
#
# Epoch 00025: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 16/16 [==============================] - 279s 17s/step - loss: 0.0251 - accuracy: 0.7062 - val_loss: 0.0190 - val_accuracy: 0.6521
# Epoch 00025: early stopping

# %%
plt.grid()

plt.plot(history.history['loss'],'--^r',label="loss")
plt.plot(history.history['accuracy'],'--^g',label='accuracy')
plt.plot(history.history['val_loss'],'-or',label='val_loss')
plt.plot(history.history['val_accuracy'],'-og',label='val_accuracy')
plt.legend()

# %%
fig=plt.figure()

def check_result(n):
    fig.add_subplot(1,2,1).imshow(y_test[n])
    fig.add_subplot(1,2,2).imshow(model.predict(x_test)[n])

check_result(4)

# %%
# #img=cv2.imread('../dataSets/pic2.jpeg')
# img=np.array(model.predict(x_test)[2]*255,dtype=np.uint8)
# R,G,B=cv2.split(img)

# # equ_R=cv2.equalizeHist(R)
# # equ_G=cv2.equalizeHist(G)
# # equ_B=cv2.equalizeHist(B)

# clahe = cv2.createCLAHE(clipLimit=1.0, tileGridSize=(10,10))
# equ_R = clahe.apply(R)
# equ_G = clahe.apply(G)
# equ_B = clahe.apply(B)

# equ=cv2.merge((equ_R,equ_G,equ_B))

# res = np.hstack((img,equ))

# cv2.imshow('img',res)
# cv2.waitKey(5000)
# cv2.destroyWindow('img')
