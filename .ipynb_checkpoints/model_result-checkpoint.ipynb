# %%
import numpy as np
import matplotlib.pyplot as plt
import keras
from keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,UpSampling2D,Flatten,Dropout,Dense,BatchNormalization

# %%
model=keras.models.load_model('models/ref/ref_cnn.h5')
model1=keras.models.load_model('models/ref/ref_cnn1.h5')
model2=keras.models.load_model('models/ref/ref_cnn2.h5')

# %%
import os

x_test=[]

path_test_low='../dataSets/test images/'

print('\nLoding Test dataset :')

i=0;
for img in os.listdir(path_test_low):
    img_low_path=os.path.join(path_test_low, img)
    
    img_low=load_img(img_low_path, target_size=(40, 40))
    img_low=img_to_array(img_low)/255.
    
    i=i+1
    print("{:.2f}".format(i/0.1)+' %',end='\r')
    
    x_test.append(img_low)

x_test=np.array(x_test, dtype="float32")
# Out:
# Loding Test dataset :
# 100.00 %

# %%
fig=plt.figure();

def check_result(n):
    fig.add_subplot(1,2,1).imshow(x_test[n])
    fig.add_subplot(1,2,2).imshow(model2.predict(x_test)[n])

check_result(5);

# %%
fig=plt.figure();

def check_result(n):
    fig.add_subplot(1,2,1).imshow(x_test[n])
    fig.add_subplot(1,2,2).imshow(model2.predict(x_test)[n])

check_result(6);

# %%
model=keras.models.load_model('models/ref/ref_cnn_mod.h5')

import os

x_test0=[]

path_test_low='../dataSets/test images/'

print('\nLoding Test dataset :')

i=0;
for img in os.listdir(path_test_low):
    img_low_path=os.path.join(path_test_low, img)
    
    img_low=load_img(img_low_path, target_size=(50,50))
    img_low=img_to_array(img_low)/255.
    
    i=i+1
    print("{:.2f}".format(i/0.1)+' %',end='\r')
    
    x_test0.append(img_low)

x_test0=np.array(x_test0, dtype="float32")

fig=plt.figure();

def check_result0(n):
    fig.add_subplot(1,2,1).imshow(x_test0[n])
    fig.add_subplot(1,2,2).imshow(model.predict(x_test0)[n])

check_result0(7);
# Out:
# Loding Test dataset :
# 100.00 %
