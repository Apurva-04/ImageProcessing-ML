# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import os
import tensorflow as tf
import keras
from keras import backend as K
from keras.preprocessing.image import ImageDataGenerator,load_img,img_to_array

# %%
h, w = 160, 160

x_train=[]
y_train=[]
x_test=[]
y_test=[]

path_train_low='../dataSets/ref/our485/low/'
path_train_high='../dataSets/ref/our485/high/'
path_test_low='../dataSets/ref/eval15/low/'
path_test_high='../dataSets/ref/eval15/high/'

print('\nLoding Train dataset :')
i=0;
for img in os.listdir(path_train_low):
    img_low_path=os.path.join(path_train_low, img)
    img_high_path=os.path.join(path_train_high, img)
    
    img_low=load_img(img_low_path, target_size=(h,w))
    img_low=img_to_array(img_low)/255.
    
    i=i+1
    print("{:.2f}".format(i/4.89)+' %',end='\r')
    
    img_high=load_img(img_high_path, target_size=(h,w))
    img_high=img_to_array(img_high)/255.
    
    x_train.append(img_low)
    y_train.append(img_high)
    
print('\nLoding Test dataset :')
i=0;
for img in os.listdir(path_test_low):
    img_low_path=os.path.join(path_test_low, img)
    img_high_path=os.path.join(path_test_high, img)
    
    img_low=load_img(img_low_path, target_size=(h,w))
    img_low=img_to_array(img_low)/255.
    
    i=i+1
    print("{:.2f}".format(i/0.14)+' %',end='\r')
    
    img_high=load_img(img_high_path, target_size=(h,w))
    img_high=img_to_array(img_high)/255.
    
    x_test.append(img_low)
    y_test.append(img_high)

x_train=np.array(x_train, dtype="float32")
y_train=np.array(y_train, dtype="float32")

x_test=np.array(x_test, dtype="float32")
y_test=np.array(y_test, dtype="float32")
# Out:
# Loding Train dataset :
# 100.00 %
# Loding Test dataset :
# 100.00 %

# %%
fig=plt.figure()

f=fig.add_subplot(1,2,1)
s=fig.add_subplot(1,2,2)

f.imshow(x_test[6])
s.imshow(y_test[6])

# %%
from keras.models import Model
from keras.models import Sequential
from keras.layers import Input,add,Conv2D,MaxPooling2D,UpSampling2D,Flatten,Dropout,Dense,BatchNormalization,Reshape,UpSampling2D,Conv2DTranspose,Concatenate,Lambda

def InstantiateModel(in_):
    channel = 32
    kernal_size = (3, 3)
    
    #EM
    def EM(in_EM):
        
        em_conv1 = Conv2D(channel, 2, strides=1, padding='same', activation='relu')(in_EM)
        em_conv2 = Conv2D(channel/2, 3, strides=1, padding='same', activation='relu')(em_conv1)
        em_conv3 = Conv2D(channel/4, 2, strides=1, padding='same', activation='relu')(em_conv2)

        em_deconv3 = Conv2DTranspose(channel/4, 2, strides=1, padding='same', activation='relu')(em_conv3)
        em_deconv2 = Conv2DTranspose(channel/2, 3, strides=1, padding='same', activation='relu')(em_deconv3)
        em_deconv1 = Conv2DTranspose(channel, 3, strides=1, padding='same', activation='relu')(em_deconv2)
        
        em_model = Conv2D(3, (1,1), padding='same', activation=None)(em_deconv1)
        return em_model
    
    def EM1(in_EM):
        em_conv0 = Conv2D(channel, 2, strides=1, padding='same', activation=None)(in_EM)
        
        em_conv1 = Conv2D(channel, 3, strides=2, padding='same', activation='relu')(em_conv0)
        em_conv2 = Conv2D(channel, 2, strides=2, padding='same', activation='relu')(em_conv1)
        em_conv3 = Conv2D(channel, 3, strides=2, padding='same', activation='relu')(em_conv2)

        em_up3 = UpSampling2D((2,2))(em_conv3)
        em_deconv3 = Conv2D(channel, 3, strides=1, padding='same', activation='relu')(em_up3)+em_conv2
        em_up2 = UpSampling2D((2,2))(em_deconv3)
        em_deconv2 = Conv2D(channel, 2, strides=1, padding='same', activation='relu')(em_up2)+em_conv1
        em_up1 = UpSampling2D((2,2))(em_deconv2)
        em_deconv1 = Conv2D(channel, 3, strides=1, padding='same', activation='relu')(em_up1)+em_conv0
        
        em_model = Conv2D(3, (1,1), padding='same', activation=None)(em_deconv1)
        return em_model
    #FEM
    conv0 = Conv2D(channel, kernal_size, strides=1, padding='same', activation=None)(in_)
    conv1 = Conv2D(channel, kernal_size, strides=1, padding='same', activation=None)(conv0)
    conv2 = Conv2D(channel, kernal_size, strides=1, padding='same', activation=None)(conv1)
    
    conv01 = Conv2D(channel, kernal_size, strides=1, padding='same', activation=None)(in_) + conv0
    conv11 = Conv2D(channel, kernal_size, strides=1, padding='same', activation=None)(conv01) + conv1
    conv21 = Conv2D(channel, kernal_size, strides=1, padding='same', activation=None)(conv11) + conv2
    
    #FM
    conv0 = EM(conv0)
    conv1 = EM(conv1)
    conv2 = EM(conv2)
    
    conv01 = EM1(conv01)
    conv11 = EM1(conv11)
    conv21 = EM1(conv21)
    
    out = Concatenate()([conv0, conv1, conv2, conv01, conv11, conv21])
    out = Conv2D(channel*2, kernal_size, strides=1, padding='same', activation='relu')(out)
    out = Conv2D(3, (1,1), activation='sigmoid', padding='same', strides=1)(out)
    
    return out

# %%
Input_Sample = Input(shape=(h, w, 3))
Output_ = InstantiateModel(Input_Sample)
model = Model(inputs=Input_Sample, outputs=Output_)
model.summary()
# Out:
# Model: "functional_1"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 160, 160, 3) 0
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 160, 160, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 160, 160, 32) 896         input_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2 (TensorFlowOp [(None, 160, 160, 32 0           conv2d_3[0][0]
#                                                                  conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 160, 160, 32) 9248        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 160, 160, 32) 9248        tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_1 (TensorFlow [(None, 160, 160, 32 0           conv2d_4[0][0]
#                                                                  conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 160, 160, 32) 9248        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 160, 160, 32) 9248        tf_op_layer_AddV2_1[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_2 (TensorFlow [(None, 160, 160, 32 0           conv2d_5[0][0]
#                                                                  conv2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 160, 160, 32) 4128        tf_op_layer_AddV2[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 160, 160, 32) 4128        tf_op_layer_AddV2_1[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 160, 160, 32) 4128        tf_op_layer_AddV2_2[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 80, 80, 32)   9248        conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 80, 80, 32)   9248        conv2d_26[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 80, 80, 32)   9248        conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 40, 40, 32)   4128        conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 40, 40, 32)   4128        conv2d_27[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 40, 40, 32)   4128        conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 20, 20, 32)   9248        conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 20, 20, 32)   9248        conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 20, 20, 32)   9248        conv2d_36[0][0]
# __________________________________________________________________________________________________
# up_sampling2d (UpSampling2D)    (None, 40, 40, 32)   0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, 40, 40, 32)   0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, 40, 40, 32)   0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 40, 40, 32)   9248        up_sampling2d[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 40, 40, 32)   9248        up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 40, 40, 32)   9248        up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_3 (TensorFlow [(None, 40, 40, 32)] 0           conv2d_22[0][0]
#                                                                  conv2d_20[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_6 (TensorFlow [(None, 40, 40, 32)] 0           conv2d_30[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_9 (TensorFlow [(None, 40, 40, 32)] 0           conv2d_38[0][0]
#                                                                  conv2d_36[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 160, 160, 32) 4128        conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 160, 160, 32) 4128        conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 160, 160, 32) 4128        conv2d_2[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, 80, 80, 32)   0           tf_op_layer_AddV2_3[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, 80, 80, 32)   0           tf_op_layer_AddV2_6[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_7 (UpSampling2D)  (None, 80, 80, 32)   0           tf_op_layer_AddV2_9[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 160, 160, 16) 4624        conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 160, 160, 16) 4624        conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 160, 160, 16) 4624        conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 80, 80, 32)   4128        up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 80, 80, 32)   4128        up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 80, 80, 32)   4128        up_sampling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 160, 160, 8)  520         conv2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 160, 160, 8)  520         conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 160, 160, 8)  520         conv2d_15[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_4 (TensorFlow [(None, 80, 80, 32)] 0           conv2d_23[0][0]
#                                                                  conv2d_19[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_7 (TensorFlow [(None, 80, 80, 32)] 0           conv2d_31[0][0]
#                                                                  conv2d_27[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_10 (TensorFlo [(None, 80, 80, 32)] 0           conv2d_39[0][0]
#                                                                  conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose (Conv2DTranspo (None, 160, 160, 8)  264         conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_3 (Conv2DTrans (None, 160, 160, 8)  264         conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 160, 160, 8)  264         conv2d_16[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, 160, 160, 32) 0           tf_op_layer_AddV2_4[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, 160, 160, 32) 0           tf_op_layer_AddV2_7[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_8 (UpSampling2D)  (None, 160, 160, 32) 0           tf_op_layer_AddV2_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_1 (Conv2DTrans (None, 160, 160, 16) 1168        conv2d_transpose[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_4 (Conv2DTrans (None, 160, 160, 16) 1168        conv2d_transpose_3[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 160, 160, 16) 1168        conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 160, 160, 32) 9248        up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 160, 160, 32) 9248        up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 160, 160, 32) 9248        up_sampling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_2 (Conv2DTrans (None, 160, 160, 32) 4640        conv2d_transpose_1[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 160, 160, 32) 4640        conv2d_transpose_4[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 160, 160, 32) 4640        conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_5 (TensorFlow [(None, 160, 160, 32 0           conv2d_24[0][0]
#                                                                  conv2d_18[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_8 (TensorFlow [(None, 160, 160, 32 0           conv2d_32[0][0]
#                                                                  conv2d_26[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_AddV2_11 (TensorFlo [(None, 160, 160, 32 0           conv2d_40[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 160, 160, 3)  99          conv2d_transpose_2[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 160, 160, 3)  99          conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 160, 160, 3)  99          conv2d_transpose_8[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 160, 160, 3)  99          tf_op_layer_AddV2_5[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 160, 160, 3)  99          tf_op_layer_AddV2_8[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 160, 160, 3)  99          tf_op_layer_AddV2_11[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 160, 160, 18) 0           conv2d_9[0][0]
#                                                                  conv2d_13[0][0]
#                                                                  conv2d_17[0][0]
#                                                                  conv2d_25[0][0]
#                                                                  conv2d_33[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 160, 160, 64) 10432       concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_43 (Conv2D)              (None, 160, 160, 3)  195         conv2d_42[0][0]
# ==================================================================================================
# Total params: 244,165
# Trainable params: 244,165
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
from keras.utils.vis_utils import plot_model
plot_model(model,to_file='model.png',show_shapes=True, show_layer_names=True)

# %%
def _tf_fspecial_gauss(size, sigma):
    """Function to mimic the 'fspecial' gaussian MATLAB function
    """
    x_data, y_data = np.mgrid[-size//2 + 1:size//2 + 1, -size//2 + 1:size//2 + 1]

    x_data = np.expand_dims(x_data, axis=-1)
    x_data = np.expand_dims(x_data, axis=-1)

    y_data = np.expand_dims(y_data, axis=-1)
    y_data = np.expand_dims(y_data, axis=-1)

    x = tf.constant(x_data, dtype=tf.float32)
    y = tf.constant(y_data, dtype=tf.float32)

    g = tf.exp(-((x**2 + y**2)/(2.0*sigma**2)))
    return g / tf.reduce_sum(g)

def tf_ssim(img1, img2, cs_map=False, mean_metric=True, size=11, sigma=1.5):
    window = _tf_fspecial_gauss(size, sigma) # window shape [size, size]
    K1 = 0.01
    K2 = 0.03
    L = 1  # depth of image (255 in case the image has a differnt scale)
    C1 = (K1*L)**2
    C2 = (K2*L)**2
    mu1 = tf.nn.conv2d(img1, window, strides=[1,1,1,1], padding='VALID')
    mu2 = tf.nn.conv2d(img2, window, strides=[1,1,1,1],padding='VALID')
    mu1_sq = mu1*mu1
    mu2_sq = mu2*mu2
    mu1_mu2 = mu1*mu2
    sigma1_sq = tf.nn.conv2d(img1*img1, window, strides=[1,1,1,1],padding='VALID') - mu1_sq
    sigma2_sq = tf.nn.conv2d(img2*img2, window, strides=[1,1,1,1],padding='VALID') - mu2_sq
    sigma12 = tf.nn.conv2d(img1*img2, window, strides=[1,1,1,1],padding='VALID') - mu1_mu2
    if cs_map:
        value = (((2*mu1_mu2 + C1)*(2*sigma12 + C2))/((mu1_sq + mu2_sq + C1)*
                            (sigma1_sq + sigma2_sq + C2)),
                        (2.0*sigma12 + C2)/(sigma1_sq + sigma2_sq + C2))
    else:
        value = ((2*mu1_mu2 + C1)*(2*sigma12 + C2))/((mu1_sq + mu2_sq + C1)*
                            (sigma1_sq + sigma2_sq + C2))

    if mean_metric:
        value = tf.reduce_mean(value)
    return value

def my_loss(y_true, y_pred):
    MAE_loss = K.mean(K.abs(y_pred - y_true))
    SSIM_loss = tf_ssim(tf.expand_dims(y_pred[:, :, :, 0], -1),tf.expand_dims(y_true[:, :, :, 0], -1)) + tf_ssim(
                tf.expand_dims(y_pred[:, :, :, 1], -1), tf.expand_dims(y_true[:, :, :, 1], -1)) + tf_ssim(
                tf.expand_dims(y_pred[:, :, :, 2], -1), tf.expand_dims(y_true[:, :, :, 2], -1))

    percent = 0.4
    index = int(h * w * percent - 1)
    gray1 = 0.39 * y_pred[:, :, :, 0] + 0.5 * y_pred[:, :, :, 1] + 0.11 * y_pred[:, :, :, 2]
    gray = tf.reshape(gray1, [-1, h * w])
    gray_sort = tf.nn.top_k(-gray, h * w)[0]
    yu = gray_sort[:, index]
    yu = tf.expand_dims(tf.expand_dims(yu, -1), -1)
    mask = tf.cast(gray1 <= yu,tf.float32)
    mask1 = tf.expand_dims(mask, -1)
    mask = tf.concat([mask1, mask1, mask1], -1)

    low_fake_clean = tf.multiply(mask, y_pred[:, :, :, :3])
    high_fake_clean = tf.multiply(1 - mask, y_pred[:, :, :, :3])
    low_clean = tf.multiply(mask, y_true[:, :, :, :])
    high_clean = tf.multiply(1 - mask, y_true[:, :, :, :])
    Region_loss = K.mean(K.abs(low_fake_clean - low_clean) * 4 + K.abs(high_fake_clean - high_clean))

    loss = MAE_loss + 2.5 - SSIM_loss + Region_loss
    
    return loss

# %%
from keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau

checkpoint=ModelCheckpoint('models/ref/MBLLEN_2.h5',
                            monitor='val_loss',
                            mode='min',
                            save_best_only=True,
                            verbose=1
                          )
earlystop=EarlyStopping(monitor='val_loss',
                        patience=6,
                        min_delta=0,
                        restore_best_weights=True,
                        verbose=1
                       )
reduce_lr=ReduceLROnPlateau(monitor='val_loss',
                            factor=0.2,
                            patience=6,
                            min_delta=0.001,
                            verbose=1
                           )
callbacks=[checkpoint,earlystop,reduce_lr]

model.compile(loss=my_loss,
              optimizer=keras.optimizers.Adam(learning_rate=0.001),
              metrics=['accuracy']
             )

history=model.fit(
    x=x_train,
    y=y_train,
    batch_size=16,
    shuffle=True,
    epochs=100,
    validation_data=(x_test, y_test),
    callbacks=callbacks
    )
# Out:
# Epoch 1/100
# 31/31 [==============================] - ETA: 0s - loss: 0.8680 - accuracy: 0.5077
# Epoch 00001: val_loss improved from inf to 0.56796, saving model to models/ref\MBLLEN_2.h5
# 31/31 [==============================] - 336s 11s/step - loss: 0.8680 - accuracy: 0.5077 - val_loss: 0.5680 - val_accuracy: 0.7562
# Epoch 2/100
# 31/31 [==============================] - ETA: 0s - loss: 0.5070 - accuracy: 0.6330
# Epoch 00002: val_loss improved from 0.56796 to 0.42145, saving model to models/ref\MBLLEN_2.h5
# 31/31 [==============================] - 332s 11s/step - loss: 0.5070 - accuracy: 0.6330 - val_loss: 0.4214 - val_accuracy: 0.7124
# Epoch 3/100
# 31/31 [==============================] - ETA: 0s - loss: 0.4484 - accuracy: 0.6597
# Epoch 00003: val_loss improved from 0.42145 to 0.37513, saving model to models/ref\MBLLEN_2.h5
# 31/31 [==============================] - 315s 10s/step - loss: 0.4484 - accuracy: 0.6597 - val_loss: 0.3751 - val_accuracy: 0.6997
# Epoch 4/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3929 - accuracy: 0.7001
# Epoch 00004: val_loss improved from 0.37513 to 0.33654, saving model to models/ref\MBLLEN_2.h5
# 31/31 [==============================] - 321s 10s/step - loss: 0.3929 - accuracy: 0.7001 - val_loss: 0.3365 - val_accuracy: 0.7406
# Epoch 5/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3753 - accuracy: 0.6747
# Epoch 00005: val_loss improved from 0.33654 to 0.31785, saving model to models/ref\MBLLEN_2.h5
# 31/31 [==============================] - 320s 10s/step - loss: 0.3753 - accuracy: 0.6747 - val_loss: 0.3178 - val_accuracy: 0.6808
# Epoch 6/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3549 - accuracy: 0.6898
# Epoch 00006: val_loss did not improve from 0.31785
# 31/31 [==============================] - 383s 12s/step - loss: 0.3549 - accuracy: 0.6898 - val_loss: 0.3760 - val_accuracy: 0.7161
# Epoch 7/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3525 - accuracy: 0.6739
# Epoch 00007: val_loss improved from 0.31785 to 0.31127, saving model to models/ref\MBLLEN_2.h5
# 31/31 [==============================] - 407s 13s/step - loss: 0.3525 - accuracy: 0.6739 - val_loss: 0.3113 - val_accuracy: 0.5053
# Epoch 8/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3380 - accuracy: 0.7015
# Epoch 00008: val_loss did not improve from 0.31127
# 31/31 [==============================] - 386s 12s/step - loss: 0.3380 - accuracy: 0.7015 - val_loss: 0.3251 - val_accuracy: 0.7596
# Epoch 9/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3330 - accuracy: 0.6864
# Epoch 00009: val_loss did not improve from 0.31127
# 31/31 [==============================] - 387s 12s/step - loss: 0.3330 - accuracy: 0.6864 - val_loss: 0.3195 - val_accuracy: 0.7094
# Epoch 10/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3317 - accuracy: 0.6828
# Epoch 00010: val_loss improved from 0.31127 to 0.29555, saving model to models/ref\MBLLEN_2.h5
# 31/31 [==============================] - 387s 12s/step - loss: 0.3317 - accuracy: 0.6828 - val_loss: 0.2956 - val_accuracy: 0.6006
# Epoch 11/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3159 - accuracy: 0.6434
# Epoch 00011: val_loss did not improve from 0.29555
# 31/31 [==============================] - 385s 12s/step - loss: 0.3159 - accuracy: 0.6434 - val_loss: 0.2959 - val_accuracy: 0.7183
# Epoch 12/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3092 - accuracy: 0.6982
# Epoch 00012: val_loss did not improve from 0.29555
# 31/31 [==============================] - 385s 12s/step - loss: 0.3092 - accuracy: 0.6982 - val_loss: 0.3049 - val_accuracy: 0.5982
# Epoch 13/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2990 - accuracy: 0.6969
# Epoch 00013: val_loss did not improve from 0.29555
# 31/31 [==============================] - 397s 13s/step - loss: 0.2990 - accuracy: 0.6969 - val_loss: 0.3155 - val_accuracy: 0.4102
# Epoch 14/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2829 - accuracy: 0.6831
# Epoch 00014: val_loss improved from 0.29555 to 0.27960, saving model to models/ref\MBLLEN_2.h5
# 31/31 [==============================] - 376s 12s/step - loss: 0.2829 - accuracy: 0.6831 - val_loss: 0.2796 - val_accuracy: 0.7485
# Epoch 15/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3027 - accuracy: 0.6472
# Epoch 00015: val_loss did not improve from 0.27960
# 31/31 [==============================] - 308s 10s/step - loss: 0.3027 - accuracy: 0.6472 - val_loss: 0.3175 - val_accuracy: 0.7714
# Epoch 16/100
# 31/31 [==============================] - ETA: 0s - loss: 0.3064 - accuracy: 0.6745
# Epoch 00016: val_loss improved from 0.27960 to 0.27812, saving model to models/ref\MBLLEN_2.h5
# 31/31 [==============================] - 378s 12s/step - loss: 0.3064 - accuracy: 0.6745 - val_loss: 0.2781 - val_accuracy: 0.6595
# Epoch 17/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2835 - accuracy: 0.6793
# Epoch 00017: val_loss did not improve from 0.27812
# 31/31 [==============================] - 385s 12s/step - loss: 0.2835 - accuracy: 0.6793 - val_loss: 0.3068 - val_accuracy: 0.4440
# Epoch 18/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2916 - accuracy: 0.6673
# Epoch 00018: val_loss did not improve from 0.27812
# 31/31 [==============================] - 385s 12s/step - loss: 0.2916 - accuracy: 0.6673 - val_loss: 0.2824 - val_accuracy: 0.7718
# Epoch 19/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2734 - accuracy: 0.6999
# Epoch 00019: val_loss did not improve from 0.27812
# 31/31 [==============================] - 386s 12s/step - loss: 0.2734 - accuracy: 0.6999 - val_loss: 0.2795 - val_accuracy: 0.7742
# Epoch 20/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2787 - accuracy: 0.6858
# Epoch 00020: val_loss did not improve from 0.27812
# 31/31 [==============================] - 385s 12s/step - loss: 0.2787 - accuracy: 0.6858 - val_loss: 0.2801 - val_accuracy: 0.7447
# Epoch 21/100
# 31/31 [==============================] - ETA: 0s - loss: 0.2814 - accuracy: 0.6794
# Epoch 00021: val_loss improved from 0.27812 to 0.26856, saving model to models/ref\MBLLEN_2.h5
# 31/31 [==============================] - 386s 12s/step - loss: 0.2814 - accuracy: 0.6794 - val_loss: 0.2686 - val_accuracy: 0.7584
# Epoch 22/100
# 21/31 [===================>..........] - ETA: 3:37:45 - loss: 0.2865 - accuracy: 0.7121

# %%
plt.grid()

plt.plot(history.history['loss'],'--^r',label="loss")
plt.plot(history.history['accuracy'],'--^g',label='accuracy')
plt.plot(history.history['val_loss'],'-or',label='val_loss')
plt.plot(history.history['val_accuracy'],'-og',label='val_accuracy')
plt.legend()

# %%
def check_result(n):
    fig=plt.figure(figsize=(16,16))
    fig.add_subplot(1,2,1).imshow(y_test[n])
    fig.add_subplot(1,2,2).imshow(model.predict(x_test)[n])

# %%
for i in range(10):
    check_result(i)

# %%
def plot_hist(img,f):
#     if(f==0):
    img=cv2.cvtColor(np.array(img*255,dtype=np.uint8),cv2.COLOR_RGB2HSV)/255.
#         clahe=cv2.createCLAHE(clipLimit=3.0, tileGridSize=(2,2))
#         img[:,:,2]=clahe.apply(img[:,:,2])
#         img=cv2.cvtColor(img,cv2.COLOR_HSV2RGB)/255.
    h,s,v=cv2.split(img)
    fig=plt.figure(figsize=(16,16))
    fig.add_subplot(4,2,1).imshow(img)
    fig.add_subplot(4,2,2).hist(img.ravel(), bins=256, range=(0.0, 1.0))
    #red
    fig.add_subplot(4,2,3).imshow(h)
    fig.add_subplot(4,2,4).hist(h.ravel(), bins=256, range=(0.0, 1.0))
    #green
    fig.add_subplot(4,2,5).imshow(s)
    fig.add_subplot(4,2,6).hist(s.ravel(), bins=256, range=(0.0, 1.0))
    #blue
#     v=np.power(v,1/3)
    fig.add_subplot(4,2,7).imshow(v)
    fig.add_subplot(4,2,8).hist(v.ravel(), bins=256, range=(0.0, 1.0))

# %%
plot_hist(x_test[1],1)

# %%
plot_hist(y_test[1],1)

# %%
plot_hist(model.predict(x_test)[1],1)
